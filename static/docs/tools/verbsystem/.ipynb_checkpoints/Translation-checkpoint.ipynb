# %%
import Theory
# Out:
# <style>
#
# div#notebook {
# 	background-color:LightYellow;
# }
#
# div.input_area {
# 	background-color:LemonChiffon;
# }
#
# h1, h2, h3, h4 {
# 	color:Gold;
# }
#
# div.text_cell_render {
# 	color:DarkBlue;
# }
#
# table.presentation, table.verbs, table.patterns, table.verbal_patterns {
#     margin-left: auto;
#     margin-right: auto;
# }
#
# table.presentation, table.presentation tr, table.presentation th, table.presentation td {
#     border-style:hidden;
#     color: Maroon;
# }
#
# table.verbs, table.verbs tr, table.verbs th, table.verbs td {
#     border-style: hidden;
#     color: Maroon;
# 	text-align: center;
# }
#
# table.patterns, table.patterns tr, table.patterns th, table.patterns td {
#     border-style:hidden;
#     color: Maroon;
#     font-size: small;
# }
#
# table.verbal_patterns, table.verbal_patterns tr, table.verbal_patterns th, table.verbal_patterns td {
#     border-style:hidden;
#     color: Maroon;
# }
#
# ...

# %% [markdown]
# # Translation

# %% [markdown]
# <p>The translations of the Psalms have all been generated automatically by our Java program. We have not translated the whole Hebrew text of the Psalms, but have included in our translations only the subjects, the objects, the predicate complements, and, of course, the verbal forms occurring in all clauses.</p>
# For the rendering of the non-verbal constituents, our program has made use of the lexicon included in the <abbr title="Eep Talstra Centre for Bible and Computer">ETCBC</abbr> database. The rendering of the verbal forms has a central position in our translation and is therefore printed in a different colour and in bold lettertype.</p>
# <p>The translation of the verbal lexeme is based on a list of all verbs and their translations which we have created ourselves. In this list, we have tried to account for Biblical Hebrew's use of different stem formations by providing passive renderings for Nifal forms and causative renderings for Hifil and some Piel forms.</p>
# <p>The translation of the actual verbal forms is designed to reflect as much as possible their <a href="DefaultDiscourseFunctions.ipynb" title="_blank">default discourse functions</a>. Below we provide an overview of our renderings (using the English verb 'to do') of the verbal forms in the different clause types.</p>
#
# <table class="presentation">
# <tr><th style="text-align: left;">Form</th><th style="text-align: left;">Translation</th></tr>
# <tr><td><em>imperative</em></td><td>do / you must do</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td>cohortative <em>yiqtol</em></td><td>let me/us do<br>(in some contexts the volitive meaning may be of a desiderative nature and so may require the translation 'I/we want to do')</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td>jussive <em>yiqtol</em></td><td>you should do<br>(in some contexts, especially if the addressee has a higher status than the speaker, the volitive meaning may be of a desiderative nature and so may require the translation 'may you do')</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td>volitive <em>yiqtol</em></td><td>let X do / X should do<br>(in some contexts, especially if the subject has a higher status than the speaker, the volitive meaning may be of a desiderative nature and so may require the translation 'may X do / X may do')</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td>prohibitive <em>yiqtol</em></td><td>let X not do / X should not do<br>(in some contexts, especially if the subject has a higher status than the speaker, the volitive meaning may be of a desiderative nature and so may require the translation 'may X not do / X may not do')</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td>final <em>weyiqtol</em></td><td>so that X may do</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td>non-volitive <em>yiqtol</em></td><td>X do/does</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td><em>wayyiqtol</em></td><td>X did</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td>discursive <em>qatal</em></td><td>X have/has done</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td>narrative <em>qatal</em></td><td>X had done</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td>anticipating <em>weqatal</em></td><td>X will do</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td>consecutive <em>weqatal</em></td><td>so that X will do</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td>discursive <em>participle</em></td><td>X am/is/are doing</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td>narrative <em>participle</em></td><td>X was/were doing</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td>discursive <em>nominal/adjective clause</em></td><td>X am/are/is</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td>narrative <em>nominal/adjective clause</em></td><td>X was/were</td></tr>
# </table>
#
# <p>We would like to emphasize once more that the translations are generated mechanically and therefore do not take into account any context-specific considerations. Our systematic renderings function as default representations of the volitive and discourse functionalities of the different clause types and are meant to help the reader get an initial idea of the meaning of the verbal forms.</p>

# %% [markdown]
# <div class="button"><form action="Index.ipynb">
#     <input type="submit" value="Go to Index">
# </form>
# </div>
