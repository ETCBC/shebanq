# %%
import Theory
# Out:
# <style>
#
# div#notebook {
# 	background-color:LightYellow;
# }
#
# div.input_area {
# 	background-color:LemonChiffon;
# }
#
# h1, h2, h3, h4 {
# 	color:Gold;
# }
#
# div.text_cell_render {
# 	color:DarkBlue;
# }
#
# table.presentation, table.verbs, table.patterns, table.verbal_patterns {
#     margin-left: auto;
#     margin-right: auto;
# }
#
# table.presentation, table.presentation tr, table.presentation th, table.presentation td {
#     border-style:hidden;
#     color: Maroon;
# }
#
# table.verbs, table.verbs tr, table.verbs th, table.verbs td {
#     border-style: hidden;
#     color: Maroon;
# 	text-align: center;
# }
#
# table.patterns, table.patterns tr, table.patterns th, table.patterns td {
#     border-style:hidden;
#     color: Maroon;
#     font-size: small;
# }
#
# table.verbal_patterns, table.verbal_patterns tr, table.verbal_patterns th, table.verbal_patterns td {
#     border-style:hidden;
#     color: Maroon;
# }
#
# ...

# %% [markdown]
# # Discourse Functions

# %% [markdown]
# ## 1. Discourse Functionalities in Clause Patterns

# %% [markdown]
# <p>Since patterns of mother and daughter clauses can be embedded in different communicative and linguistic domains, identical sequences of clauses do not always involve a similar concretatization of the <a href="DefaultDiscourseFunctions.ipynb" target="_blank">default discourse functions</a> of the verbal forms used in the clauses. It is, therefore, of the utmost importance to correctly identify the boundaries of communicative and linguistic domains on the basis of specific parameters and linguistic signals, such as the presence of conjunctions, <a href="MDModifier.ipynb" target="_blank">multiple-duty modifiers</a>, and developments in the set of <a href="Participants.ipynb" target="_blank">participants</a>. For a more elaborate discussion of markers of continuity and discontinuity in communicative and linguistic domains, we refer the reader to section 6.2 of the dissertation.</p>
# <p>On the basis of the distribution of discourse functionalities in sequences of mother and daughter clauses, the following categories and subcategories of clause sequences can be identified in the Psalms:</p>
#
# <table class="patterns">
# <tr><th>Category</th><th>Subcategory</th><th>Pattern numbers</th><th nowrap>Occurrences in Psalms</th></tr>
# <tr><td><strong>Patterns involving no communicative shifts</strong></td><td nowrap>Patterns involving continuation of discursive mainline</td><td>10-40, 100-150, 210-280, 390-420, 480-510, 570-600, 660-690</td><td>1741 (36.2%)</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td><strong>&nbsp;</strong></td><td nowrap>Patterns involving continuation of narrative mainline</td><td>1300-1310</td><td>148 (3.1%)</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td><strong>&nbsp;</strong></td><td nowrap>Patterns involving continuation of retrospective secondary line</td><td>790, 880, 970, 1060, 1150, 1460-1470</td><td>630 (13.1%)</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td><strong>&nbsp;</strong></td><td nowrap>Patterns involving continuation of anticipating secondary line</td><td>1500-1510</td><td>4 (0.0%)</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>----------</td></tr>
# <tr><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>2523 (52.5%)</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td><strong>Patterns involving shift in perspective and level of communication</strong></td><td nowrap>Patterns involving shift from antecedent information to discursive mainline</td><td>50, 160, 290-300, 430, 520, 610, 700</td><td>265 (5.5%)</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td><strong>&nbsp;</strong></td><td nowrap>Patterns involving shift from discursive mainline to antecedent information</td><td>750-780, 840-870, 930-960, 1020-1050, 1110-1140</td><td>334 (7.0%)</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td><strong>&nbsp;</strong></td><td nowrap>Patterns involving shift from antecedent information to narrative mainline</td><td>1280-1290</td><td>110 (2.3%)</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td><strong>&nbsp;</strong></td><td nowrap>Patterns involving shift from narrative mainline to antecedent information</td><td>800, 890, 980, 1070, 1160, 1490</td><td>49 (1.0%)</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td><strong>&nbsp;</strong></td><td nowrap>Patterns involving shift from discursive mainline to anticipating information</td><td>1390-1450</td><td>33 (0.7%)</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td><strong>&nbsp;</strong></td><td nowrap>Patterns involving shift from anticipating information to discursive mainline</td><td>540, 630, 720</td><td>5 (0.1%)</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>----------</td></tr>
# <tr><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>796 (16.6%)</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td><strong>Patterns involving shift in type of communication</strong></td><td nowrap>Patterns involving shift from discursive mainline to narrative mainline</td><td>1220-1270</td><td>39 (0.8%)</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td><strong>&nbsp;</strong></td><td nowrap>Patterns involving shift from narrative mainline to discursive mainline</td><td>170, 440, 530, 620, 710</td><td>54 (1.1%)</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>----------</td></tr>
# <tr><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>93 (1,9%)</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td><strong>Patterns with nominal and participle clauses</strong></td><td nowrap>Patterns with a nominal or participle mother clause</td><td>80-90, 190-200, 350-380, 470, 550-560, 640-650, 730-740, 820-830, 910-920, 1000-1010, 1090-1100, 1180-1190, 1340-1370, 1520-1550, 1630-1640, 1720-1730</td><td>917 (19.1%)</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td><strong>&nbsp;</strong></td><td nowrap>Patterns with a nominal or participle daughter clause<br>(excluding those with a nominal or participle mother)</td><td>1560-1640, 1650-1730</td><td>476 (9.9%)</td></tr>
# <tr><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>----------</td></tr>
# <tr><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>1393 (29.0%)</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td>&nbsp;</td><td>&nbsp;</td><td>&nbsp;</td><td>----------</td></tr>
# <tr><th>Total</th><td>&nbsp;</td><td>&nbsp;</td><td><strong>4805 (100.0%)</strong></td></tr>
# </table>
#
# <p>Each of these categories of patterns is extensively treated in section 6.3 of the dissertation.</p>

# %% [markdown]
# ## 2. Functional Labels

# %% [markdown]
# <p>In our analyses we have made use of the following set of functional labels to describe the concrete discourse functions fulfilled by clauses in their context:</p>
#
# <table class="patterns">
# <tr><th>Label</th><th>Description</th></tr>
# <tr><td class="head"><strong>Non-dependent Domains</strong></td></tr>
# <tr><td>(re)openMain</td><td>Open or Reopen Discursive Mainline</td></tr>
# <tr><td>opnNarrMn</td><td>Open Narrative Mainline</td></tr>
# <tr><td>opn2ndR</td><td>Open Retrospective Secondary Line</td></tr>
# <tr><td>opn2ndF</td><td>Open Anticipating Secondary Line</td></tr>
# <tr><td>opnNr2nd</td><td>Open Narrative Secondary Line</td></tr>
# <tr><td>cntMain</td><td>Continuation Discursive Mainline</td></tr>
# <tr><td>crdMain</td><td>Coordination Discursive Mainline</td></tr>
# <tr><td>cntMn>retro</td><td>Continuation Discursive Mainline; transition to or continuation of Retrospective Perspective</td></tr>
# <tr><td>crdMn>retro</td><td>Coordination Discursive Mainline; transition to or continuation of Retrospective Perspective</td></tr>
# <tr><td>cntMn>forwd</td><td>Continuation Discursive Mainline; transition to or continuation of Anticipating Perspective</td></tr>
# <tr><td>crdMn>forwd</td><td>Coordination Discursive Mainline; transition to or continuation of Anticipating Perspective</td></tr>
# <tr><td>cntMn>zero</td><td>Continuation Discursive Mainline; transition to Zero Perspective</td></tr>
# <tr><td>crdMn>zero</td><td>Coordination Discursive Mainline; transition to Zero Perspective</td></tr>
# <tr><td>cntNrMn</td><td>Continuation Narrative Mainline</td></tr>
# <tr><td>crdNrMn</td><td>Coordination Narrative Mainline</td></tr>
# <tr><td>cntFg</td><td>Continuation Discursive Foreground within Secondary Line</td></tr>
# <tr><td>crdFg</td><td>Coordination Discursive Foreground within Secondary Line</td></tr>
# <tr><td>cnt2ndR</td><td>Continuation Retrospective Secondary Line</td></tr>
# <tr><td>crd2ndR</td><td>Coordination Retrospective Secondary Line</td></tr>
# <tr><td>cnt2ndR>Fg</td><td>Continuation Retrospective Secondary Line; transition to Discursive Foreground</td></tr>
# <tr><td>crd2ndR>Fg</td><td>Coordination Retrospective Secondary Line; transition to Discursive Foreground</td></tr>
# <tr><td>ct2ndR>ParFg</td><td>Continuation Retrospective Secondary Line; transition to Parallel Foreground</td></tr>
# <tr><td>cd2ndR>ParFg</td><td>Coordination Retrospective Secondary Line; transition to Parallel Foreground</td></tr>
# <tr><td>cnt2ndR>NrFg</td><td>Continuation Retrospective Secondary Line; transition to Narrative Foreground</td></tr>
# <tr><td>crd2ndR>NrFg</td><td>Coordination Retrospective Secondary Line; transition to Narrative Foreground</td></tr>
# <tr><td>cnt2ndR>DsFg</td><td>Continuation Retrospective Secondary Line; transition from Narrative Line to Discursive Foreground</td></tr>
# <tr><td>crd2ndR>DsFg</td><td>Coordination Retrospective Secondary Line; transition from Narrative Line to Discursive Foreground</td></tr>
# <tr><td>cnt2ndF</td><td>Continuation Anticipating Secondary Line</td></tr>
# <tr><td>crd2ndF</td><td>Coordination Anticipating Secondary Line</td></tr>
# <tr><td>cnt2ndF>Fg</td><td>Continuation Anticipating Secondary Line; transition to Discursive Foreground</td></tr>
# <tr><td>crd2ndF>Fg</td><td>Coordination Anticipating Secondary Line; transition to Discursive Foreground</td></tr>
# <tr><td>cnt2nd</td><td>Continuation Secondary Line <em>(nominal and participle clauses with secondary-line mother)</em></td></tr>
# <tr><td>crd2nd</td><td>Coordination Secondary Line <em>(nominal and participle clauses with secondary-line mother)</em></td></tr>
# <tr><td>cntNr2nd</td><td>Continuation Narrative Secondary Line</td></tr>
# <tr><td>crdNr2nd</td><td>Coordination Narrative Secondary Line</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td class="head"><strong>Opening Direct Speech</strong></td></tr>
# <tr><td>opnDrSpMain</td><td>Open Direct Speech Discursive Mainline</td></tr>
# <tr><td>opnDrSp2ndR</td><td>Open Direct Speech Discursive Retrospective Secondary Line</td></tr>
# <tr><td>opnDrSpNr2nd</td><td>Open Direct Speech Narrative Secondary Line</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td class="head"><strong>Different Types of Communication</strong></td></tr>
# <tr><td>narr>disc</td><td>Transition from Narrative Mainline to Discursive Mainline</td></tr>
# <tr><td>cntDiscInNar</td><td>Continuation Discursive Mainline embedded in Narrative Domain</td></tr>
# <tr><td>crdDiscInNar</td><td>Coordination Discursive Mainline embedded in Narrative Domain</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td class="head"><strong>Argumentative Sections</strong></td></tr>
# <tr><td>precArgum</td><td>Open preceding Secondary Line Argumentative Section</td></tr>
# <tr><td>Argum>Mn</td><td>Transition from Secondary Line Argumentative Section to Discursive Mainline</td></tr>
# <tr><td>follArgum</td><td>Open following Secondary Line Argumentative Section</td></tr>
# <tr><td>cntArgum>Fg</td><td>Continuation Secondary Line Argumentative Section; transition to Discursive Foreground</td></tr>
# <tr><td>crdArgum>Fg</td><td>Coordination Secondary Line Argumentative Section; transition to Discursive Foreground</td></tr>
# <tr><td>cntArgum>NrFg</td><td>Continuation Secondary Line Argumentative Section; transition to Narrative Foreground</td></tr>
# <tr><td>crdArgum>NrFg</td><td>Coordination Secondary Line Argumentative Section; transition to Narrative Foreground</td></tr>
# <tr><td>cntArgum2ndR</td><td>Continuation Secondary Line Argumentative Section</td></tr>
# <tr><td>crdArgum2ndR</td><td>Coordination Secondary Line Argumentative Section</td></tr>
# <tr><td>cntArgum>2ndR</td><td>Continuation Secondary Line Argumentative Section; transition (back) to Retrospective Secondary Line</td></tr>
# <tr><td>crdArgum>2ndR</td><td>Coordination Secondary Line Argumentative Section; transition (back) to Retrospective Secondary Line</td></tr>
# <tr><td>cntArgum2nd</td><td>Continuation Secondary Line Argumentative Section <em>(nominal and participle clauses with secondary-line mother)</em></td></tr>
# <tr><td>crdArgum2nd</td><td>Coordination Secondary Line Argumentative Section <em>(nominal and participle clauses with secondary-line mother)</em></td></tr>
# <tr><td>cntArgumNr2nd</td><td>Continuation Narrative Secondary Line Argumentative Section</td></tr>
# <tr><td>crdArgumNr2nd</td><td>Coordination Narrative Secondary Line Argumentative Section</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td class="head"><strong>Explanatory/Frameworking Sections</strong></td><td><strong>(Given Information)</strong></td></tr>
# <tr><td>precGivInf</td><td>Open preceding Secondary Line Given Information Section</td></tr>
# <tr><td>precParGvInf</td><td>Open preceding Secondary Line Given Information Section <em>(semantically parallel to following discursive mainline daughter clause)</em></td></tr>
# <tr><td>GivInf>Mn</td><td>Transition from Secondary Line Given Information Section to Discursive Mainline</td></tr>
# <tr><td>GivInf>ParMn</td><td>Transition from Secondary Line Given Information Section to Discursive Mainline <em>(semantically parallel to secondary line mother clause)</em></td></tr>
# <tr><td>follGivInf</td><td>Open following Secondary Line Given Information Section</td></tr>
# <tr><td>cntGvInf>Fg</td><td>Continuation Secondary Line Given Information Section; transition to Discursive Foreground</td></tr>
# <tr><td>crdGvInf>Fg</td><td>Coordination Secondary Line Given Information Section; transition to Discursive Foreground</td></tr>
# <tr><td>ctGvInf>NrFg</td><td>Continuation Secondary Line Given Information Section; transition to Narrative Foreground</td></tr>
# <tr><td>cdGvInf>NrFg</td><td>Coordination Secondary Line Given Information Section; transition to Narrative Foreground</td></tr>
# <tr><td>cntGvInf2ndR</td><td>Continuation Secondary Line Given Information Section</td></tr>
# <tr><td>crdGvInf2ndR</td><td>Coordination Secondary Line Given Information Section</td></tr>
# <tr><td>ctGvInf>2ndR</td><td>Continuation Secondary Line Given Information Section; transition (back) to Retrospective Secondary Line</td></tr>
# <tr><td>cdGvInf>2ndR</td><td>Coordination Secondary Line Given Information Section; transition (back) to Retrospective Secondary Line</td></tr>
# <tr><td>cntGvInf2nd</td><td>Continuation Secondary Line Given Information Section <em>(nominal and participle clauses with secondary-line mother)</em></td></tr>
# <tr><td>crdGvInf2nd</td><td>Coordination Secondary Line Given Information Section <em>(nominal and participle clauses with secondary-line mother)</em></td></tr>
# <tr><td>cntGvInfNr2nd</td><td>Continuation Narrative Secondary Line Given Information Section</td></tr>
# <tr><td>crdGvInfNr2nd</td><td>Coordination Narrative Secondary Line Given Information Section</td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td class="head"><strong>Narrative Introducing Sections</strong></td><td><strong>(Anterior Information)</strong></td></tr>
# <tr><td>precAntInf</td><td>Open Secondary Line Narrative Introducing Section</td></tr>
# <tr><td>AntInf>Mn</td><td>Transition from Secondary Line Narrative Introducing Section to Discursive Mainline</td></tr>
# <tr><td>follAntInf</td><td>Open following Secondary Line Narrative 'Outtro' Section</td></tr>
# <tr><td>cntAtInf>Fg</td><td>Continuation Secondary Line Narrative Introducing Section; transition to Discursive Foreground</td></tr>
# <tr><td>crdAtInf>Fg</td><td>Coordination Secondary Line Narrative Introducing Section; transition to Discursive Foreground</td></tr>
# <tr><td>ctAtInf>NrFg</td><td>Continuation Secondary Line Narrative Introducing Section; transition to Narrative Foreground</td></tr>
# <tr><td>cdAtInf>NrFg</td><td>Coordination Secondary Line Narrative Introducing Section; transition to Narrative Foreground</td></tr>
# <tr><td>cntAtInf2ndR</td><td>Continuation Secondary Line Narrative Introducing Section</td></tr>
# <tr><td>crdAtInf2ndR</td><td>Coordination Secondary Line Narrative Introducing Section</td></tr>
# <tr><td>cntAtInf>2ndR</td><td>Continuation Secondary Line Narrative Introducing Section; transition (back) to Retrospective Secondary Line</td></tr>
# <tr><td>crdAtInf>2ndR</td><td>Coordination Secondary Line Narrative Introducing Section; transition (back) to Retrospective Secondary Line</td></tr>
# <tr><td>cntAtInf2nd</td><td>Continuation Secondary Line Narrative Introducing Section <em>(nominal and participle clauses with secondary-line mother)</em></td></tr>
# <tr><td>crdAtInf2nd</td><td>Coordination Secondary Line Narrative Introducing Section <em>(nominal and participle clauses with secondary-line mother)</em></td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td class="head"><strong>Dependent Domain</strong></td><td><strong>(clause(s) functioning as constituent in main clause)</strong></td></tr>
# <tr><td>opnDpLn</td><td>Open Dependent Domain <em>(by infinitive clauses)</em></td></tr>
# <tr><td>opnDpLnMain</td><td>Open Dependent Domain Discursive Mainline</td></tr>
# <tr><td>opnDpLn2ndR</td><td>Open Dependent Domain Discursive Retrospective Secondary Line</td></tr>
# <tr><td>coordDpLn</td><td>Coordination Dependent Domain <em>(by infinitive clauses)</em></td></tr>
# <tr><td>crdDpLnMain</td><td>Coordination Dependent Domain Discursive Mainline</td></tr>
# <tr><td>crdDpLn>Mn</td><td>Coordination Dependent Domain; transition from Secondary Line to Discursive Mainline</td></tr>
# <tr><td>crdDpLnNrMn</td><td>Coordination Dependent Domain Narrative Mainline</td></tr>
# <tr><td>crdDpLn>NrMn</td><td>Coordination Dependent Domain; transition from Secondary Line to Narrative Mainline</td></tr>
# <tr><td>crdDpLn2ndR</td><td>Coordination Dependent Domain Retrospective Secondary Line</td></tr>
# <tr><td>crdDpLn>2ndR</td><td>Coordination Dependent Domain; transition from Mainline to Retrospective Secondary Line</td></tr>
# <tr><td>crdDpLn2ndF</td><td>Coordination Dependent Domain Anticipating Secondary Line</td></tr>
# <tr><td>crdDpLn>2ndF</td><td>Coordination Dependent Domain; transition from Mainline to Anticipating Secondary Line</td></tr>
# <tr><td>crdDpLn2nd</td><td>Coordination Dependent Domain Secondary Line <em>(nominal and participle clauses with secondary-line mother)</em></td></tr>
# <tr><td>crdDpLn>Fg</td><td>Coordination Dependent Domain; transition to Discursive Foreground within Secondary Line</td></tr>
# <tr><td>crdDpLnNr2nd</td><td>Coordination Dependent Domain Narrative Secondary Line <em>(nominal and participle clauses with narrative mother)</em></td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td class="head"><strong>Attributive Domain</strong></td></tr>
# <tr><td>opnAttrMain</td><td>Open Attributive Domain Discursive Mainline</td></tr>
# <tr><td>opnAttr2ndR</td><td>Open Attributive Domain Discursive Retrospective Secondary Line</td></tr>
# <tr><td>crdAttrMain</td><td>Coordination Attributive Domain Discursive Mainline</td></tr>
# <tr><td>crdAttr>Mn</td><td>Coordination Attributive Domain; transition from Secondary Line to Discursive Mainline</td></tr>
# <tr><td>crdAttrNrMn</td><td>Coordination Attributive Domain Narrative Mainline</td></tr>
# <tr><td>crdAttr>NrMn</td><td>Coordination Attributive Domain; transition from Secondary Line to Narrative Mainline</td></tr>
# <tr><td>crdAttr2ndR</td><td>Coordination Attributive Domain Retrospective Secondary Line</td></tr>
# <tr><td>crdAttr>2ndR</td><td>Coordination Attributive Domain; transition from Mainline to Retrospective Secondary Line</td></tr>
# <tr><td>crdAttr2ndF</td><td>Coordination Attributive Domain Anticipating Secondary Line</td></tr>
# <tr><td>crdAttr>2ndF</td><td>Coordination Attributive Domain; transition from Mainline to Anticipating Secondary Line</td></tr>
# <tr><td>crdAttr2nd</td><td>Coordination Attributive Domain Secondary Line <em>(nominal and participle clauses with secondary-line mother)</em></td></tr>
# <tr><td>crdAttr>Fg</td><td>Coordination Attributive Domain; transition to Discursive Foreground within Secondary Line</td></tr>
# <tr><td>crdAttrNr2nd</td><td>Coordination Attributive Domain Narrative Secondary Line <em>(nominal and participle clauses with narrative mother)</em></td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td class="head"><strong>Subdomain</strong></td><td><strong>(clause(s) governed by subordinate conjunctions)</strong></td></tr>
# <tr><td>opnSbLnMain</td><td>Open Subdomain Discursive Mainline</td></tr>
# <tr><td>opnSbLn2ndR</td><td>Open Subdomain Discursive Retrospective Secondary Line</td></tr>
# <tr><td>crdSbLnMain</td><td>Coordination Subdomain Discursive Mainline</td></tr>
# <tr><td>crdSbLn>Mn</td><td>Coordination Subdomain; transition from Secondary Line to Discursive Mainline</td></tr>
# <tr><td>crdSbLnNrMn</td><td>Coordination Subdomain Narrative Mainline</td></tr>
# <tr><td>crdSbLn>NrMn</td><td>Coordination Subdomain; transition from Secondary Line to Narrative Mainline</td></tr>
# <tr><td>crdSbLn2ndR</td><td>Coordination Subdomain Retrospective Secondary Line</td></tr>
# <tr><td>crdSbLn>2ndR</td><td>Coordination Subdomain; transition from Mainline to Retrospective Secondary Line</td></tr>
# <tr><td>crdSbLn2ndF</td><td>Coordination Subdomain Anticipating Secondary Line</td></tr>
# <tr><td>crdSbLn>2ndF</td><td>Coordination Subdomain; transition from Mainline to Anticipating Secondary Line</td></tr>
# <tr><td>crdSbLn2nd</td><td>Coordination Subdomain Secondary Line <em>(nominal and participle clauses with secondary-line mother)</em></td></tr>
# <tr><td>crdSbLn>Fg</td><td>Coordination Subdomain; transition to Discursive Foreground within Secondary Line</td></tr>
# <tr><td>crdSbLnNr2nd</td><td>Coordination Subdomain Narrative Secondary Line <em>(nominal and participle clauses with narrative mother)</em></td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td class="head"><strong>Protasis</strong></td></tr>
# <tr><td>opnProtMain</td><td>Open Protasis Discursive Mainline</td></tr>
# <tr><td>opnProt2ndR</td><td>Open Protasis Discursive Retrospective Secondary Line</td></tr>
# <tr><td>opnProtNr2nd</td><td>Open Protasis Narrative Secondary Line</td></tr>
# <tr><td>crdProtMain</td><td>Coordination Protasis Discursive Mainline</td></tr>
# <tr><td>crdProt>Mn</td><td>Coordination Protasis; transition from Secondary Line to Discursive Mainline</td></tr>
# <tr><td>crdProtNrMn</td><td>Coordination Protasis Narrative Mainline</td></tr>
# <tr><td>crdProt>NrMn</td><td>Coordination Protasis; transition from Secondary Line to Narrative Mainline</td></tr>
# <tr><td>crdProt2ndR</td><td>Coordination Protasis Retrospective Secondary Line</td></tr>
# <tr><td>crdProt>2ndR</td><td>Coordination Protasis; transition from Mainline to Retrospective Secondary Line</td></tr>
# <tr><td>crdProt2ndF</td><td>Coordination Protasis Anticipating Secondary Line</td></tr>
# <tr><td>crdProt>2ndF</td><td>Coordination Protasis; transition from Mainline to Anticipating Secondary Line</td></tr>
# <tr><td>crdProt2nd</td><td>Coordination Protasis Secondary Line <em>(nominal and participle clauses with secondary-line mother)</em></td></tr>
# <tr><td>crdProtNr2nd</td><td>Coordination Protasis Narrative Secondary Line <em>(nominal and participle clauses with narrative mother)</em></td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td class="head"><strong>Apodosis</strong></td></tr>
# <tr><td>opnApodMain</td><td>Open Apodosis Discursive Mainline</td></tr>
# <tr><td>opnApodNrMn</td><td>Open Apodosis Narrative Mainline</td></tr>
# <tr><td>opnApod2ndR</td><td>Open Apodosis Discursive Retrospective Secondary Line</td></tr>
# <tr><td>opnApod2ndF</td><td>Open Apodosis Discursive Anticipating Secondary Line</td></tr>
# <tr><td>opnApodNr2nd</td><td>Open Apodosis Narrative Secondary Line</td></tr>
# <tr><td>crdApodMain</td><td>Coordination Apodosis Discursive Mainline</td></tr>
# <tr><td>crdApod>Mn</td><td>Coordination Apodosis; transition from Secondary Line to Discursive Mainline</td></tr>
# <tr><td>crdApodNrMn</td><td>Coordination Apodosis Narrative Mainline</td></tr>
# <tr><td>crdProt>NrMn</td><td>Coordination Apodosis; transition from Secondary Line to Narrative Mainline</td></tr>
# <tr><td>crdApod2ndR</td><td>Coordination Apodosis Retrospective Secondary Line</td></tr>
# <tr><td>crdApod>2ndR</td><td>Coordination Apodosis; transition from Mainline to Retrospective Secondary Line</td></tr>
# <tr><td>crdApod2ndF</td><td>Coordination Apodosis Anticipating Secondary Line</td></tr>
# <tr><td>crdApod>2ndF</td><td>Coordination Apodosis; transition from Mainline to Anticipating Secondary Line</td></tr>
# <tr><td>crdApod2nd</td><td>Coordination Apodosis Secondary Line <em>(nominal and participle clauses with secondary-line mother)</em></td></tr>
# <tr><td>crdApodNr2nd</td><td>Coordination Apodosis Narrative Secondary Line <em>(nominal and participle clauses with narrative mother)</em></td></tr>
# <tr><td>&nbsp;</td></tr>
# <tr><td class="head"><strong>Remaining Labels</strong></td></tr>
# <tr><td>parSit>2ndR</td><td>Transition from Discursive or Narrative Mainline to Retrospective Secondary Line <em>(in syndetic clause pairs)</em></td></tr>
# <tr><td>parSit>2nd</td><td>Transition from Discursive or Narrative Mainline to Secondary Line <em>(in syndetic clause pairs with nominal or participle daughter clause)</em></td></tr>
# <tr><td>coordVoc</td><td>Coordination of two Vocative Clauses</td></tr>
# </table>

# %% [markdown]
# ### References

# %% [markdown]
# <ul>
# <li>Kalkman, G.J., <em>Verbal Forms in Biblical Hebrew Poetry: Poetical Freedom or Linguistic System?</em> (dissertation, VU University Amsterdam, Faculty of Theology; 2015), ch.6</li>
# </ul>

# %% [markdown]
# <br>
# <br>
# <div class="button"><form action="Index.ipynb">
#     <input type="submit" value="Go to Index">
# </form>
# </div>
