# %%
import Theory
# Out:
# <style>
#
# div#notebook {
# 	background-color:LightYellow;
# }
#
# div.input_area {
# 	background-color:LemonChiffon;
# }
#
# h1, h2, h3, h4 {
# 	color:Gold;
# }
#
# table.presentation, table.verbs, table.patterns, table.verbal_patterns {
#     margin-left: auto;
#     margin-right: auto;
# }
#
# table.presentation, table.presentation tr, table.presentation th, table.presentation td {
#     border-style:hidden;
#     color: Maroon;
# }
#
# table.verbs, table.verbs tr, table.verbs th, table.verbs td {
#     border-style: hidden;
#     color: Maroon;
# 	text-align: center;
# }
#
# table.patterns, table.patterns tr, table.patterns th, table.patterns td {
#     border-style:hidden;
#     color: Maroon;
#     font-size: small;
# }
#
# table.verbal_patterns, table.verbal_patterns tr, table.verbal_patterns th, table.verbal_patterns td {
#     border-style:hidden;
#     color: Maroon;
# }
#
# table.presentation th, table.presentation td, table.patterns th, table.patterns td {
# ...

# %% [markdown]
# # Index of the Website

# %% [markdown]
# <p>This website consists of a large number of notebooks, which are listed below. The index list is subdivided into two sections. The first section contains links to the notebooks providing the theoretical background one will need in order to understand our presentations of the Psalms in the notebooks listed in the second section. The "theoretical notebooks" briefly summarize the hypotheses and conclusions drawn in the dissertation "Verbal Forms in Biblical Hebrew Poetry: Poetical Freedom or Linguistic System?", to which this website forms a complement. For a more elaborate discussion of the research and our theoretical framework, the reader is strongly recommended to consult this dissertation.</p>

# %% [markdown]
# ## 1. Theoretical Notebooks

# %% [markdown]
# <ul>
# <li><a href="Introduction.ipynb">Introduction</a></li>
# <li><a href="HebrewText.ipynb">The Hebrew Text</a></li>
# <li><a href="Translation.ipynb">Our Translation</a></li>
# <li><a href="ClauseLabels.ipynb">Labels of Clause Types</a></li>
# <li><a href="CCR.ipynb">Clause Constituent Relations</a></li>
# <li><a href="DefaultFunctions.ipynb">Default Functions of Clause Types in terms of volitivity and non-volitivity</a></li>
# <li><a href="Processes.ipynb">Mechanisms of Inheritance and Blocking Influencing the Distribution of (Non-)Volitive Functionality</a></li>
# <li><a href="FinalFunctions.ipynb">Final Functions of Clause Types in terms of volitivity and non-volitivity</a></li>
# <li><a href="MDModifier.ipynb">The Phenomenon of the Multiple-Duty Modifier</a></li>
# <li><a href="Participants.ipynb">Participants</a></li>
# <li><a href="DefaultDiscourseFunctions.ipynb">Default Discourse Functions of Clause Types</a></li>
# <li><a href="DiscourseFunctions.ipynb">Final Discourse Functions of Clause Types</a></li>
# <li><a href="ConcordanceOfPatterns.ipynb">The Concordance of Patterns: Overview of All Clause Patterns in the Psalms</a></li>
# <li><em><a href="Psalms.ipynb">Code written for Presentation of Psalm Notebooks</a></em></li>
# </ul>

# %% [markdown]
# ## 2. Notebooks of the Psalms

# %% [markdown]
# <table class="presentation">
# <tr>
# <td>
# <ul>
# <li><a href="Psalm001.ipynb" target="_blank">Psalm 1</a></li>
# <li><a href="Psalm002.ipynb" target="_blank">Psalm 2</a></li>
# <li><a href="Psalm003.ipynb" target="_blank">Psalm 3</a></li>
# <li><a href="Psalm004.ipynb" target="_blank">Psalm 4</a></li>
# <li><a href="Psalm005.ipynb" target="_blank">Psalm 5</a></li>
# <li><a href="Psalm006.ipynb" target="_blank">Psalm 6</a></li>
# <li><a href="Psalm007.ipynb" target="_blank">Psalm 7</a></li>
# <li><a href="Psalm008.ipynb" target="_blank">Psalm 8</a></li>
# <li><a href="Psalm009.ipynb" target="_blank">Psalm 9</a></li>
# <li><a href="Psalm010.ipynb" target="_blank">Psalm 10</a></li>
# <li><a href="Psalm011.ipynb" target="_blank">Psalm 11</a></li>
# <li><a href="Psalm012.ipynb" target="_blank">Psalm 12</a></li>
# <li><a href="Psalm013.ipynb" target="_blank">Psalm 13</a></li>
# <li><a href="Psalm014.ipynb" target="_blank">Psalm 14</a></li>
# <li><a href="Psalm015.ipynb" target="_blank">Psalm 15</a></li>
# <li><a href="Psalm016.ipynb" target="_blank">Psalm 16</a></li>
# <li><a href="Psalm017.ipynb" target="_blank">Psalm 17</a></li>
# <li><a href="Psalm018.ipynb" target="_blank">Psalm 18</a></li>
# <li><a href="Psalm019.ipynb" target="_blank">Psalm 19</a></li>
# <li><a href="Psalm020.ipynb" target="_blank">Psalm 20</a></li>
# <li><a href="Psalm021.ipynb" target="_blank">Psalm 21</a></li>
# <li><a href="Psalm022.ipynb" target="_blank">Psalm 22</a></li>
# <li><a href="Psalm023.ipynb" target="_blank">Psalm 23</a></li>
# <li><a href="Psalm024.ipynb" target="_blank">Psalm 24</a></li>
# <li><a href="Psalm025.ipynb" target="_blank">Psalm 25</a></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><a href="Psalm026.ipynb" target="_blank">Psalm 26</a></li>
# <li><a href="Psalm027.ipynb" target="_blank">Psalm 27</a></li>
# <li><a href="Psalm028.ipynb" target="_blank">Psalm 28</a></li>
# <li><a href="Psalm029.ipynb" target="_blank">Psalm 29</a></li>
# <li><a href="Psalm030.ipynb" target="_blank">Psalm 30</a></li>
# <li><a href="Psalm031.ipynb" target="_blank">Psalm 31</a></li>
# <li><a href="Psalm032.ipynb" target="_blank">Psalm 32</a></li>
# <li><a href="Psalm033.ipynb" target="_blank">Psalm 33</a></li>
# <li><a href="Psalm034.ipynb" target="_blank">Psalm 34</a></li>
# <li><a href="Psalm035.ipynb" target="_blank">Psalm 35</a></li>
# <li><a href="Psalm036.ipynb" target="_blank">Psalm 36</a></li>
# <li><a href="Psalm037.ipynb" target="_blank">Psalm 37</a></li>
# <li><a href="Psalm038.ipynb" target="_blank">Psalm 38</a></li>
# <li><a href="Psalm039.ipynb" target="_blank">Psalm 39</a></li>
# <li><a href="Psalm040.ipynb" target="_blank">Psalm 40</a></li>
# <li><a href="Psalm041.ipynb" target="_blank">Psalm 41</a></li>
# <li><a href="Psalm042.ipynb" target="_blank">Psalm 42</a></li>
# <li><a href="Psalm043.ipynb" target="_blank">Psalm 43</a></li>
# <li><a href="Psalm044.ipynb" target="_blank">Psalm 44</a></li>
# <li><a href="Psalm045.ipynb" target="_blank">Psalm 45</a></li>
# <li><a href="Psalm046.ipynb" target="_blank">Psalm 46</a></li>
# <li><a href="Psalm047.ipynb" target="_blank">Psalm 47</a></li>
# <li><a href="Psalm048.ipynb" target="_blank">Psalm 48</a></li>
# <li><a href="Psalm049.ipynb" target="_blank">Psalm 49</a></li>
# <li><a href="Psalm050.ipynb" target="_blank">Psalm 50</a></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><a href="Psalm051.ipynb" target="_blank">Psalm 51</a></li>
# <li><a href="Psalm052.ipynb" target="_blank">Psalm 52</a></li>
# <li><a href="Psalm053.ipynb" target="_blank">Psalm 53</a></li>
# <li><a href="Psalm054.ipynb" target="_blank">Psalm 54</a></li>
# <li><a href="Psalm055.ipynb" target="_blank">Psalm 55</a></li>
# <li><a href="Psalm056.ipynb" target="_blank">Psalm 56</a></li>
# <li><a href="Psalm057.ipynb" target="_blank">Psalm 57</a></li>
# <li><a href="Psalm058.ipynb" target="_blank">Psalm 58</a></li>
# <li><a href="Psalm059.ipynb" target="_blank">Psalm 59</a></li>
# <li><a href="Psalm060.ipynb" target="_blank">Psalm 60</a></li>
# <li><a href="Psalm061.ipynb" target="_blank">Psalm 61</a></li>
# <li><a href="Psalm062.ipynb" target="_blank">Psalm 62</a></li>
# <li><a href="Psalm063.ipynb" target="_blank">Psalm 63</a></li>
# <li><a href="Psalm064.ipynb" target="_blank">Psalm 64</a></li>
# <li><a href="Psalm065.ipynb" target="_blank">Psalm 65</a></li>
# <li><a href="Psalm066.ipynb" target="_blank">Psalm 66</a></li>
# <li><a href="Psalm067.ipynb" target="_blank">Psalm 67</a></li>
# <li><a href="Psalm068.ipynb" target="_blank">Psalm 68</a></li>
# <li><a href="Psalm069.ipynb" target="_blank">Psalm 69</a></li>
# <li><a href="Psalm070.ipynb" target="_blank">Psalm 70</a></li>
# <li><a href="Psalm071.ipynb" target="_blank">Psalm 71</a></li>
# <li><a href="Psalm072.ipynb" target="_blank">Psalm 72</a></li>
# <li><a href="Psalm073.ipynb" target="_blank">Psalm 73</a></li>
# <li><a href="Psalm074.ipynb" target="_blank">Psalm 74</a></li>
# <li><a href="Psalm075.ipynb" target="_blank">Psalm 75</a></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><a href="Psalm076.ipynb" target="_blank">Psalm 76</a></li>
# <li><a href="Psalm077.ipynb" target="_blank">Psalm 77</a></li>
# <li><a href="Psalm078.ipynb" target="_blank">Psalm 78</a></li>
# <li><a href="Psalm079.ipynb" target="_blank">Psalm 79</a></li>
# <li><a href="Psalm080.ipynb" target="_blank">Psalm 80</a></li>
# <li><a href="Psalm081.ipynb" target="_blank">Psalm 81</a></li>
# <li><a href="Psalm082.ipynb" target="_blank">Psalm 82</a></li>
# <li><a href="Psalm083.ipynb" target="_blank">Psalm 83</a></li>
# <li><a href="Psalm084.ipynb" target="_blank">Psalm 84</a></li>
# <li><a href="Psalm085.ipynb" target="_blank">Psalm 85</a></li>
# <li><a href="Psalm086.ipynb" target="_blank">Psalm 86</a></li>
# <li><a href="Psalm087.ipynb" target="_blank">Psalm 87</a></li>
# <li><a href="Psalm088.ipynb" target="_blank">Psalm 88</a></li>
# <li><a href="Psalm089.ipynb" target="_blank">Psalm 89</a></li>
# <li><a href="Psalm090.ipynb" target="_blank">Psalm 90</a></li>
# <li><a href="Psalm091.ipynb" target="_blank">Psalm 91</a></li>
# <li><a href="Psalm092.ipynb" target="_blank">Psalm 92</a></li>
# <li><a href="Psalm093.ipynb" target="_blank">Psalm 93</a></li>
# <li><a href="Psalm094.ipynb" target="_blank">Psalm 94</a></li>
# <li><a href="Psalm095.ipynb" target="_blank">Psalm 95</a></li>
# <li><a href="Psalm096.ipynb" target="_blank">Psalm 96</a></li>
# <li><a href="Psalm097.ipynb" target="_blank">Psalm 97</a></li>
# <li><a href="Psalm098.ipynb" target="_blank">Psalm 98</a></li>
# <li><a href="Psalm099.ipynb" target="_blank">Psalm 99</a></li>
# <li><a href="Psalm100.ipynb" target="_blank">Psalm 100</a></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><a href="Psalm101.ipynb" target="_blank">Psalm 101</a></li>
# <li><a href="Psalm102.ipynb" target="_blank">Psalm 102</a></li>
# <li><a href="Psalm103.ipynb" target="_blank">Psalm 103</a></li>
# <li><a href="Psalm104.ipynb" target="_blank">Psalm 104</a></li>
# <li><a href="Psalm105.ipynb" target="_blank">Psalm 105</a></li>
# <li><a href="Psalm106.ipynb" target="_blank">Psalm 106</a></li>
# <li><a href="Psalm107.ipynb" target="_blank">Psalm 107</a></li>
# <li><a href="Psalm108.ipynb" target="_blank">Psalm 108</a></li>
# <li><a href="Psalm109.ipynb" target="_blank">Psalm 109</a></li>
# <li><a href="Psalm110.ipynb" target="_blank">Psalm 110</a></li>
# <li><a href="Psalm111.ipynb" target="_blank">Psalm 111</a></li>
# <li><a href="Psalm112.ipynb" target="_blank">Psalm 112</a></li>
# <li><a href="Psalm113.ipynb" target="_blank">Psalm 113</a></li>
# <li><a href="Psalm114.ipynb" target="_blank">Psalm 114</a></li>
# <li><a href="Psalm115.ipynb" target="_blank">Psalm 115</a></li>
# <li><a href="Psalm116.ipynb" target="_blank">Psalm 116</a></li>
# <li><a href="Psalm117.ipynb" target="_blank">Psalm 117</a></li>
# <li><a href="Psalm118.ipynb" target="_blank">Psalm 118</a></li>
# <li><a href="Psalm119.ipynb" target="_blank">Psalm 119</a></li>
# <li><a href="Psalm120.ipynb" target="_blank">Psalm 120</a></li>
# <li><a href="Psalm121.ipynb" target="_blank">Psalm 121</a></li>
# <li><a href="Psalm122.ipynb" target="_blank">Psalm 122</a></li>
# <li><a href="Psalm123.ipynb" target="_blank">Psalm 123</a></li>
# <li><a href="Psalm124.ipynb" target="_blank">Psalm 124</a></li>
# <li><a href="Psalm125.ipynb" target="_blank">Psalm 125</a></li>
# </ul>
# </td>
# <td>
# <ul>
# <li><a href="Psalm126.ipynb" target="_blank">Psalm 126</a></li>
# <li><a href="Psalm127.ipynb" target="_blank">Psalm 127</a></li>
# <li><a href="Psalm128.ipynb" target="_blank">Psalm 128</a></li>
# <li><a href="Psalm129.ipynb" target="_blank">Psalm 129</a></li>
# <li><a href="Psalm130.ipynb" target="_blank">Psalm 130</a></li>
# <li><a href="Psalm131.ipynb" target="_blank">Psalm 131</a></li>
# <li><a href="Psalm132.ipynb" target="_blank">Psalm 132</a></li>
# <li><a href="Psalm133.ipynb" target="_blank">Psalm 133</a></li>
# <li><a href="Psalm134.ipynb" target="_blank">Psalm 134</a></li>
# <li><a href="Psalm135.ipynb" target="_blank">Psalm 135</a></li>
# <li><a href="Psalm136.ipynb" target="_blank">Psalm 136</a></li>
# <li><a href="Psalm137.ipynb" target="_blank">Psalm 137</a></li>
# <li><a href="Psalm138.ipynb" target="_blank">Psalm 138</a></li>
# <li><a href="Psalm139.ipynb" target="_blank">Psalm 139</a></li>
# <li><a href="Psalm140.ipynb" target="_blank">Psalm 140</a></li>
# <li><a href="Psalm141.ipynb" target="_blank">Psalm 141</a></li>
# <li><a href="Psalm142.ipynb" target="_blank">Psalm 142</a></li>
# <li><a href="Psalm143.ipynb" target="_blank">Psalm 143</a></li>
# <li><a href="Psalm144.ipynb" target="_blank">Psalm 144</a></li>
# <li><a href="Psalm145.ipynb" target="_blank">Psalm 145</a></li>
# <li><a href="Psalm146.ipynb" target="_blank">Psalm 146</a></li>
# <li><a href="Psalm147.ipynb" target="_blank">Psalm 147</a></li>
# <li><a href="Psalm148.ipynb" target="_blank">Psalm 148</a></li>
# <li><a href="Psalm149.ipynb" target="_blank">Psalm 149</a></li>
# <li><a href="Psalm150.ipynb" target="_blank">Psalm 150</a></li>
# </ul>
# </td>
# </tr>
# </table>

# %% [markdown]
# <br>
# <br>
# <br>
# <img src="Images/VU-ETCBC-small.png"/ style="width: 15%">
