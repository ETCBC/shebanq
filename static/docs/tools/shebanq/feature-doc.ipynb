# %% [markdown]
# <a href="http://laf-fabric.readthedocs.org/en/latest/" target="_blank"><img align="left" src="images/laf-fabric-xsmall.png"/></a>
# <a href="http://www.godgeleerdheid.vu.nl/etcbc" target="_blank"><img align="left" src="images/VU-ETCBC-xsmall.png"/></a>
# <a href="http://www.persistent-identifier.nl/?identifier=urn%3Anbn%3Anl%3Aui%3A13-048i-71" target="_blank"><img align="left"src="images/etcbc4easy-small.png"/></a>
# <a href="http://tla.mpi.nl" target="_blank"><img align="right" src="images/TLA-xsmall.png"/></a>
# <a href="http://www.dans.knaw.nl" target="_blank"><img align="right"src="images/DANS-xsmall.png"/></a>

# %% [markdown]
# # Feature docs

# %% [markdown]
# This is a general purpose tool to get acquainted with the features in the LAF version of the Hebrew Database

# %%
import sys
import collections

from laf.fabric import LafFabric
import etcbc
from etcbc.featuredoc import FeatureDoc

fabric = LafFabric()
# Out:
#   0.00s This is LAF-Fabric 4.8.3
# API reference: http://laf-fabric.readthedocs.org/en/latest/texts/API-reference.html
# Feature doc: https://shebanq.ancient-data.org/static/docs/featuredoc/texts/welcome.html

# %% [markdown]
# # Choose your source and features

# %% [markdown]
# Specifiy the features you want to study.
# This notebook only offers to study the features in the *ft* namespace.
#
# Do this by providing a list of features to the *study specification* below.
#
# The requested features will be loaded, on top of the base supply of features that we need for showing examples.

# %%
API = fabric.load('etcbc4', '--', 'feature-doc', {
    "xmlids": {"node": False, "edge": False},
    "features": ("",""),
    "primary": False,
})

doc = FeatureDoc(fabric, {
    'features': {
        'node': '''
            maxmonad
            minmonad
            monads
            oid
            otype
            clause_kind
            code
            det
            dist
            dist_unit
            domain
            function
            g_cons
            g_cons_utf8
            g_lex
            g_lex_utf8
            g_nme
            g_nme_utf8
            g_pfm
            g_pfm_utf8
            g_prs
            g_prs_utf8
            g_uvf
            g_uvf_utf8
            g_vbe
            g_vbe_utf8
            g_vbs
            g_vbs_utf8
            g_word
            g_word_utf8
            gn
            is_root
            language
            lex
            lex_utf8
            ls
            mother_object_type
            nme
            nu
            number
            pdp
            pfm
            prs
            ps
            rela
            sp
            st
            tab
            trailer_utf8
            txt
            typ
            uvf
            vbe
            vbs
            vs
            vt
            book
            chapter
            half_verse
            label
            verse
        ''',
        'edge': '''
            mother
            distributional_parent
            functional_parent
        ''',
    },
    'absence_values': set((
        'none',
        'unknown',
        'Unkn',
        'NA',
        '?',
        'n/a',
        'absent',
    )),
    'VALUE_THRESHOLD': 25,
    'vlabel': 'label',
})

exec(fabric.localnames.format(var='fabric'))
# Out:
#   0.00s LOADING API: please wait ...
#   0.00s INFO: USING DATA COMPILED AT: 2014-07-23T09-31-37
#   0.77s LOGFILE=/Users/dirk/laf-fabric-output/etcbc4/feature-doc/__log__feature-doc.txt
#   0.77s INFO: DATA LOADED FROM SOURCE etcbc4 AND ANNOX -- FOR TASK feature-doc AT 2014-10-15T08-25-43
#   0.00s LOADING API: please wait ...
#   0.00s DETAIL: COMPILING m: UP TO DATE
#   0.00s INFO: USING DATA COMPILED AT: 2014-07-23T09-31-37
#   0.00s DETAIL: COMPILING a: UP TO DATE
#   0.01s DETAIL: keep main: G.node_anchor_min
#   0.01s DETAIL: keep main: G.node_anchor_max
#   0.01s DETAIL: keep main: G.node_sort
#   0.01s DETAIL: keep main: G.node_sort_inv
#   0.01s DETAIL: keep main: G.edges_from
#   0.01s DETAIL: keep main: G.edges_to
#   0.01s DETAIL: load main: F.etcbc4_db_maxmonad [node]
#   1.04s DETAIL: load main: F.etcbc4_db_minmonad [node]
#   1.92s DETAIL: load main: F.etcbc4_db_monads [node]
#   2.78s DETAIL: load main: F.etcbc4_db_oid [node]
#   3.58s DETAIL: load main: F.etcbc4_db_otype [node]
#   4.39s DETAIL: load main: F.etcbc4_ft_clause_kind [node]
#   4.43s DETAIL: load main: F.etcbc4_ft_code [node]
#   4.49s DETAIL: load main: F.etcbc4_ft_det [node]
#   4.72s DETAIL: load main: F.etcbc4_ft_dist [node]
#   4.86s DETAIL: load main: F.etcbc4_ft_dist_unit [node]
#   5.19s DETAIL: load main: F.etcbc4_ft_domain [node]
#   5.22s DETAIL: load main: F.etcbc4_ft_function [node]
#   5.37s DETAIL: load main: F.etcbc4_ft_g_cons [node]
#   5.65s DETAIL: load main: F.etcbc4_ft_g_cons_utf8 [node]
#   5.96s DETAIL: load main: F.etcbc4_ft_g_lex [node]
#   6.21s DETAIL: load main: F.etcbc4_ft_g_lex_utf8 [node]
#   6.53s DETAIL: load main: F.etcbc4_ft_g_nme [node]
#   6.68s DETAIL: load main: F.etcbc4_ft_g_nme_utf8 [node]
#   6.87s DETAIL: load main: F.etcbc4_ft_g_pfm [node]
#   7.02s DETAIL: load main: F.etcbc4_ft_g_pfm_utf8 [node]
#   7.17s DETAIL: load main: F.etcbc4_ft_g_prs [node]
#   7.32s DETAIL: load main: F.etcbc4_ft_g_prs_utf8 [node]
#   7.48s DETAIL: load main: F.etcbc4_ft_g_uvf [node]
#   7.61s DETAIL: load main: F.etcbc4_ft_g_uvf_utf8 [node]
#   7.73s DETAIL: load main: F.etcbc4_ft_g_vbe [node]
#   7.87s DETAIL: load main: F.etcbc4_ft_g_vbe_utf8 [node]
#   8.00s DETAIL: load main: F.etcbc4_ft_g_vbs [node]
#   8.11s DETAIL: load main: F.etcbc4_ft_g_vbs_utf8 [node]
#   8.22s DETAIL: load main: F.etcbc4_ft_g_word [node]
#   8.50s DETAIL: load main: F.etcbc4_ft_g_word_utf8 [node]
#   8.96s DETAIL: load main: F.etcbc4_ft_gn [node]
#   9.18s DETAIL: load main: F.etcbc4_ft_is_root [node]
#   9.23s DETAIL: load main: F.etcbc4_ft_language [node]
#   9.47s DETAIL: load main: F.etcbc4_ft_lex [node]
#   9.69s DETAIL: load main: F.etcbc4_ft_lex_utf8 [node]
#     10s DETAIL: load main: F.etcbc4_ft_ls [node]
#     10s DETAIL: load main: F.etcbc4_ft_mother_object_type [node]
#     11s DETAIL: load main: F.etcbc4_ft_nme [node]
#     11s DETAIL: load main: F.etcbc4_ft_nu [node]
#     11s DETAIL: load main: F.etcbc4_ft_number [node]
#     12s DETAIL: load main: F.etcbc4_ft_pdp [node]
#     12s DETAIL: load main: F.etcbc4_ft_pfm [node]
#     12s DETAIL: load main: F.etcbc4_ft_prs [node]
#     12s DETAIL: load main: F.etcbc4_ft_ps [node]
#     13s DETAIL: load main: F.etcbc4_ft_rela [node]
#     13s DETAIL: load main: F.etcbc4_ft_sp [node]
#     13s DETAIL: load main: F.etcbc4_ft_st [node]
#     14s DETAIL: load main: F.etcbc4_ft_tab [node]
#     14s DETAIL: load main: F.etcbc4_ft_trailer_utf8 [node]
#     14s DETAIL: load main: F.etcbc4_ft_txt [node]
#     14s DETAIL: load main: F.etcbc4_ft_typ [node]
#     14s DETAIL: load main: F.etcbc4_ft_uvf [node]
#     15s DETAIL: load main: F.etcbc4_ft_vbe [node]
#     15s DETAIL: load main: F.etcbc4_ft_vbs [node]
#     15s DETAIL: load main: F.etcbc4_ft_vs [node]
#     15s DETAIL: load main: F.etcbc4_ft_vt [node]
#     16s DETAIL: load main: F.etcbc4_sft_book [node]
#     16s DETAIL: load main: F.etcbc4_sft_chapter [node]
#     16s DETAIL: load main: F.etcbc4_sft_half_verse [node]
#     16s DETAIL: load main: F.etcbc4_sft_label [node]
#     16s DETAIL: load main: F.etcbc4_sft_verse [node]
#     16s DETAIL: load main: F.etcbc4_ft_distributional_parent [e]
#     16s DETAIL: load main: F.etcbc4_ft_functional_parent [e]
#     16s DETAIL: load main: F.etcbc4_ft_mother [e]
#     16s DETAIL: load main: C.etcbc4_ft_distributional_parent ->
#     18s DETAIL: load main: C.etcbc4_ft_functional_parent ->
#     19s DETAIL: load main: C.etcbc4_ft_mother ->
#     19s DETAIL: load main: C.etcbc4_ft_distributional_parent <-
#     20s DETAIL: load main: C.etcbc4_ft_functional_parent <-
#     21s DETAIL: load main: C.etcbc4_ft_mother <-
#     21s INFO: DATA LOADED FROM SOURCE etcbc4 AND ANNOX -- FOR TASK feature-doc AT 2014-10-15T08-26-04

# %%
API = fabric.load('etcbc4b', '--', 'feature-doc', {
    "xmlids": {"node": False, "edge": False},
    "features": ("",""),
    "primary": False,
})

doc = FeatureDoc(fabric, {
    'features': {
        'node': '''
            maxmonad
            minmonad
            monads
            oid
            otype
            kind
            code
            det
            dist
            dist_unit
            domain
            function
            g_cons
            g_cons_utf8
            g_lex
            g_lex_utf8
            g_nme
            g_nme_utf8
            g_pfm
            g_pfm_utf8
            g_prs
            g_prs_utf8
            g_uvf
            g_uvf_utf8
            g_vbe
            g_vbe_utf8
            g_vbs
            g_vbs_utf8
            g_word
            g_word_utf8
            gn
            is_root
            language
            lex
            lex_utf8
            ls
            mother_object_type
            nme
            nu
            number
            pdp
            pfm
            prs
            ps
            rela
            sp
            st
            tab
            trailer_utf8
            txt
            typ
            uvf
            vbe
            vbs
            vs
            vt
            book
            chapter
            label
            verse
        ''',
        'edge': '''
            mother
            distributional_parent
            functional_parent
        ''',
    },
    'absence_values': set((
        'none',
        'unknown',
        'Unkn',
        'NA',
        '?',
        'n/a',
        'absent',
    )),
    'VALUE_THRESHOLD': 25,
    'vlabel': 'label',
})

exec(fabric.localnames.format(var='fabric'))
# Out:
#   0.00s LOADING API: please wait ...
#   0.00s BEGIN COMPILE m: etcbc4b
#   0.00s LOGFILE=/Users/dirk/SURFdrive/laf-fabric-data/etcbc4b/bin/__log__compile__.txt
#   0.00s PARSING ANNOTATION FILES
#   0.06s INFO: parsing etcbc4b_regions.xml
#   4.47s INFO: parsing etcbc4b_monads.xml
#     28s INFO: parsing etcbc4b_lingo.xml
#  1m 15s INFO: parsing etcbc4b_sections.xml
#  1m 22s INFO: parsing etcbc4b_monads.lex.xml
#  3m 17s INFO: parsing etcbc4b_lingo.c.xml
#  3m 35s INFO: parsing etcbc4b_lingo.p.xml
#  3m 53s INFO: parsing etcbc4b_lingo.pa.xml
#  4m 16s INFO: parsing etcbc4b_lingo.s.xml
#  4m 19s INFO: parsing etcbc4b_lingo.sp.xml
#  4m 23s INFO: END PARSING
#     800701 good   regions  and     0 faulty ones
#    1436858 linked nodes    and     0 unlinked ones
#    2225309 good   edges    and     0 faulty ones
#    5029703 good   annots   and     0 faulty ones
#   30757802 good   features and     0 faulty ones
#    9492571 distinct xml identifiers
#
#  4m 23s MODELING RESULT FILES
#  4m 23s INFO: XML-IDS (inverse mapping)
#  4m 25s INFO: NODES AND REGIONS
#  4m 25s INFO: NODES ANCHOR BOUNDARIES
#  4m 44s INFO: NODES SORTING BY REGIONS
#  4m 45s INFO: NODES EVENTS
#  5m 04s INFO: CONNECTIVITY
#  5m 07s WRITING RESULT FILES for m
#  6m 09s END   COMPILE m: etcbc4b
#  6m 09s INFO: USING DATA COMPILED AT: 2015-11-02T15-08-56
#  6m 12s LOGFILE=/Users/dirk/SURFdrive/laf-fabric-output/etcbc4b/feature-doc/__log__feature-doc.txt
#  6m 12s INFO: DATA LOADED FROM SOURCE etcbc4b AND ANNOX -- FOR TASK feature-doc AT 2015-11-02T15-08-58
#   0.00s LOADING API: please wait ...
#   0.00s DETAIL: COMPILING m: UP TO DATE
#   0.00s INFO: USING DATA COMPILED AT: 2015-11-02T15-08-56
#   0.00s DETAIL: COMPILING a: UP TO DATE
#   0.00s DETAIL: keep main: G.node_anchor_min
#   0.00s DETAIL: keep main: G.node_anchor_max
#   0.01s DETAIL: keep main: G.node_sort
#   0.01s DETAIL: keep main: G.node_sort_inv
#   0.01s DETAIL: keep main: G.edges_from
#   0.01s DETAIL: keep main: G.edges_to
#   0.01s DETAIL: load main: F.etcbc4_db_maxmonad [node]
#   0.83s DETAIL: load main: F.etcbc4_db_minmonad [node]
#   1.62s DETAIL: load main: F.etcbc4_db_monads [node]
#   2.53s DETAIL: load main: F.etcbc4_db_oid [node]
#   3.36s DETAIL: load main: F.etcbc4_db_otype [node]
#   4.13s DETAIL: load main: F.etcbc4_ft_code [node]
#   4.18s DETAIL: load main: F.etcbc4_ft_det [node]
#   4.41s DETAIL: load main: F.etcbc4_ft_dist [node]
#   4.60s DETAIL: load main: F.etcbc4_ft_dist_unit [node]
#   4.89s DETAIL: load main: F.etcbc4_ft_domain [node]
#   4.91s DETAIL: load main: F.etcbc4_ft_function [node]
#   5.02s DETAIL: load main: F.etcbc4_ft_g_cons [node]
#   5.26s DETAIL: load main: F.etcbc4_ft_g_cons_utf8 [node]
#   5.58s DETAIL: load main: F.etcbc4_ft_g_lex [node]
#   5.83s DETAIL: load main: F.etcbc4_ft_g_lex_utf8 [node]
#   6.16s DETAIL: load main: F.etcbc4_ft_g_nme [node]
#   6.30s DETAIL: load main: F.etcbc4_ft_g_nme_utf8 [node]
#   6.43s DETAIL: load main: F.etcbc4_ft_g_pfm [node]
#   6.56s DETAIL: load main: F.etcbc4_ft_g_pfm_utf8 [node]
#   6.70s DETAIL: load main: F.etcbc4_ft_g_prs [node]
#   6.85s DETAIL: load main: F.etcbc4_ft_g_prs_utf8 [node]
#   7.00s DETAIL: load main: F.etcbc4_ft_g_uvf [node]
#   7.11s DETAIL: load main: F.etcbc4_ft_g_uvf_utf8 [node]
#   7.24s DETAIL: load main: F.etcbc4_ft_g_vbe [node]
#   7.37s DETAIL: load main: F.etcbc4_ft_g_vbe_utf8 [node]
#   7.51s DETAIL: load main: F.etcbc4_ft_g_vbs [node]
#   7.72s DETAIL: load main: F.etcbc4_ft_g_vbs_utf8 [node]
#   7.87s DETAIL: load main: F.etcbc4_ft_g_word [node]
#   8.19s DETAIL: load main: F.etcbc4_ft_g_word_utf8 [node]
#   8.58s DETAIL: load main: F.etcbc4_ft_gn [node]
#   8.76s DETAIL: load main: F.etcbc4_ft_is_root [node]
#   8.82s DETAIL: load main: F.etcbc4_ft_kind [node]
#   8.87s DETAIL: load main: F.etcbc4_ft_language [node]
#   9.15s DETAIL: load main: F.etcbc4_ft_lex [node]
#   9.39s DETAIL: load main: F.etcbc4_ft_lex_utf8 [node]
#   9.72s DETAIL: load main: F.etcbc4_ft_ls [node]
#   9.96s DETAIL: load main: F.etcbc4_ft_mother_object_type [node]
#     10s DETAIL: load main: F.etcbc4_ft_nme [node]
#     10s DETAIL: load main: F.etcbc4_ft_nu [node]
#     11s DETAIL: load main: F.etcbc4_ft_number [node]
#     11s DETAIL: load main: F.etcbc4_ft_pdp [node]
#     12s DETAIL: load main: F.etcbc4_ft_pfm [node]
#     12s DETAIL: load main: F.etcbc4_ft_prs [node]
#     12s DETAIL: load main: F.etcbc4_ft_ps [node]
#     12s DETAIL: load main: F.etcbc4_ft_rela [node]
#     13s DETAIL: load main: F.etcbc4_ft_sp [node]
#     13s DETAIL: load main: F.etcbc4_ft_st [node]
#     13s DETAIL: load main: F.etcbc4_ft_tab [node]
#     14s DETAIL: load main: F.etcbc4_ft_trailer_utf8 [node]
#     14s DETAIL: load main: F.etcbc4_ft_txt [node]
#     14s DETAIL: load main: F.etcbc4_ft_typ [node]
#     14s DETAIL: load main: F.etcbc4_ft_uvf [node]
#     14s DETAIL: load main: F.etcbc4_ft_vbe [node]
#     15s DETAIL: load main: F.etcbc4_ft_vbs [node]
#     15s DETAIL: load main: F.etcbc4_ft_vs [node]
#     15s DETAIL: load main: F.etcbc4_ft_vt [node]
#     16s DETAIL: load main: F.etcbc4_sft_book [node]
#     16s DETAIL: load main: F.etcbc4_sft_chapter [node]
#     16s DETAIL: load main: F.etcbc4_sft_label [node]
#     16s DETAIL: load main: F.etcbc4_sft_verse [node]
#     16s DETAIL: load main: F.etcbc4_ft_distributional_parent [e]
#     16s DETAIL: load main: F.etcbc4_ft_functional_parent [e]
#     16s DETAIL: load main: F.etcbc4_ft_mother [e]
#     16s DETAIL: load main: C.etcbc4_ft_distributional_parent ->
#     17s DETAIL: load main: C.etcbc4_ft_functional_parent ->
#     19s DETAIL: load main: C.etcbc4_ft_mother ->
#     19s DETAIL: load main: C.etcbc4_ft_distributional_parent <-
#     19s DETAIL: load main: C.etcbc4_ft_functional_parent <-
#     20s DETAIL: load main: C.etcbc4_ft_mother <-
#     20s INFO: DATA LOADED FROM SOURCE etcbc4b AND ANNOX -- FOR TASK feature-doc AT 2015-11-02T15-09-18

# %%
API = fabric.load('etcbc4c', '--', 'feature-doc', {
    "xmlids": {"node": False, "edge": False},
    "features": ("",""),
    "primary": False,
})

doc = FeatureDoc(fabric, {
    'features': {
        'node': '''
            maxmonad
            minmonad
            monads
            oid
            otype
            code
            det
            dist
            dist_unit
            domain
            function
            g_cons
            g_cons_utf8
            g_lex
            g_lex_utf8
            g_nme
            g_nme_utf8
            g_pfm
            g_pfm_utf8
            g_prs
            g_prs_utf8
            g_uvf
            g_uvf_utf8
            g_vbe
            g_vbe_utf8
            g_vbs
            g_vbs_utf8
            g_voc_lex
            g_voc_lex_utf8
            g_word
            g_word_utf8
            gn
            is_root
            kind
            language
            lex
            lex_utf8
            ls
            mother_object_type
            nme
            nu
            number
            pdp
            pfm
            prs
            prs_gn
            prs_nu
            prs_ps
            ps
            qere
            qere_utf8
            rela
            sp
            st
            tab
            trailer
            trailer_utf8
            txt
            typ
            uvf
            vbe
            vbs
            vs
            vt
            book
            chapter
            label
            verse
        ''',
        'edge': '''
            distributional_parent
            functional_parent
            mother
        ''',
    },
    'absence_values': set((
        'none',
        'unknown',
        'Unkn',
        'NA',
        '?',
        'n/a',
        'absent',
    )),
    'VALUE_THRESHOLD': 25,
    'vlabel': 'label',
})

exec(fabric.localnames.format(var='fabric'))
# Out:
#   0.00s LOADING API: please wait ...
#   0.00s BEGIN COMPILE m: etcbc4c
#   0.01s LOGFILE=/Users/dirk/laf/laf-fabric-data/etcbc4c/bin/__log__compile__.txt
#   0.01s PARSING ANNOTATION FILES
#   0.15s INFO: parsing etcbc4c_regions.xml
#   4.74s INFO: parsing etcbc4c_monads.xml
#     27s INFO: parsing etcbc4c_lingo.xml
#  1m 20s INFO: parsing etcbc4c_sections.xml
#  1m 27s INFO: parsing etcbc4c_monads.lex.xml
#  4m 13s INFO: parsing etcbc4c_lingo.c.xml
#  4m 32s INFO: parsing etcbc4c_lingo.p.xml
#  4m 53s INFO: parsing etcbc4c_lingo.pa.xml
#  5m 17s INFO: parsing etcbc4c_lingo.s.xml
#  5m 20s INFO: parsing etcbc4c_lingo.sp.xml
#  5m 24s INFO: END PARSING
#     800724 good   regions  and     0 faulty ones
#    1436894 linked nodes    and     0 unlinked ones
#    2225333 good   edges    and     0 faulty ones
#    5029799 good   annots   and     0 faulty ones
#   34171309 good   features and     0 faulty ones
#    9492750 distinct xml identifiers
#
#  5m 24s MODELING RESULT FILES
#  5m 24s INFO: XML-IDS (inverse mapping)
#  5m 26s INFO: NODES AND REGIONS
#  5m 26s INFO: NODES ANCHOR BOUNDARIES
#  5m 45s INFO: NODES SORTING BY REGIONS
#  5m 46s INFO: NODES EVENTS
#  6m 06s INFO: CONNECTIVITY
#  6m 09s WRITING RESULT FILES for m: etcbc4c
#  6m 40s END   COMPILE m: etcbc4c
#  6m 40s USING main: etcbc4c DATA COMPILED AT: 2016-11-09T09-49-17
#  6m 42s LOGFILE=/Users/dirk/laf/laf-fabric-output/etcbc4c/feature-doc/__log__feature-doc.txt
#  6m 42s INFO: DATA LOADED FROM SOURCE etcbc4c AND ANNOX  FOR TASK feature-doc AT 2016-11-09T09-49-19
#   0.00s LOADING API: please wait ...
#   0.00s DETAIL: COMPILING m: etcbc4c: UP TO DATE
#   0.00s USING main: etcbc4c DATA COMPILED AT: 2016-11-09T09-49-17
#   0.01s DETAIL: keep main: G.node_anchor_min
#   0.01s DETAIL: keep main: G.node_anchor_max
#   0.01s DETAIL: keep main: G.node_sort
#   0.01s DETAIL: keep main: G.node_sort_inv
#   0.01s DETAIL: keep main: G.edges_from
#   0.01s DETAIL: keep main: G.edges_to
#   0.02s DETAIL: load main: F.etcbc4_db_maxmonad [node]
#   0.74s DETAIL: load main: F.etcbc4_db_minmonad [node]
#   1.34s DETAIL: load main: F.etcbc4_db_monads [node]
#   1.99s DETAIL: load main: F.etcbc4_db_oid [node]
#   2.60s DETAIL: load main: F.etcbc4_db_otype [node]
#   3.62s DETAIL: load main: F.etcbc4_ft_code [node]
#   3.71s DETAIL: load main: F.etcbc4_ft_det [node]
#   3.96s DETAIL: load main: F.etcbc4_ft_dist [node]
#   4.13s DETAIL: load main: F.etcbc4_ft_dist_unit [node]
#   4.37s DETAIL: load main: F.etcbc4_ft_domain [node]
#   4.39s DETAIL: load main: F.etcbc4_ft_function [node]
#   4.50s DETAIL: load main: F.etcbc4_ft_g_cons [node]
#   4.67s DETAIL: load main: F.etcbc4_ft_g_cons_utf8 [node]
#   4.91s DETAIL: load main: F.etcbc4_ft_g_lex [node]
#   5.10s DETAIL: load main: F.etcbc4_ft_g_lex_utf8 [node]
#   5.57s DETAIL: load main: F.etcbc4_ft_g_nme [node]
#   5.82s DETAIL: load main: F.etcbc4_ft_g_nme_utf8 [node]
#   6.08s DETAIL: load main: F.etcbc4_ft_g_pfm [node]
#   6.19s DETAIL: load main: F.etcbc4_ft_g_pfm_utf8 [node]
#   6.28s DETAIL: load main: F.etcbc4_ft_g_prs [node]
#   6.39s DETAIL: load main: F.etcbc4_ft_g_prs_utf8 [node]
#   6.49s DETAIL: load main: F.etcbc4_ft_g_uvf [node]
#   6.67s DETAIL: load main: F.etcbc4_ft_g_uvf_utf8 [node]
#   6.90s DETAIL: load main: F.etcbc4_ft_g_vbe [node]
#   7.15s DETAIL: load main: F.etcbc4_ft_g_vbe_utf8 [node]
#   7.36s DETAIL: load main: F.etcbc4_ft_g_vbs [node]
#   7.45s DETAIL: load main: F.etcbc4_ft_g_vbs_utf8 [node]
#   7.54s DETAIL: load main: F.etcbc4_ft_g_voc_lex [node]
#   7.73s DETAIL: load main: F.etcbc4_ft_g_voc_lex_utf8 [node]
#   7.98s DETAIL: load main: F.etcbc4_ft_g_word [node]
#   8.19s DETAIL: load main: F.etcbc4_ft_g_word_utf8 [node]
#   8.47s DETAIL: load main: F.etcbc4_ft_gn [node]
#   8.61s DETAIL: load main: F.etcbc4_ft_is_root [node]
#   8.65s DETAIL: load main: F.etcbc4_ft_kind [node]
#   8.70s DETAIL: load main: F.etcbc4_ft_language [node]
#   8.89s DETAIL: load main: F.etcbc4_ft_lex [node]
#   9.06s DETAIL: load main: F.etcbc4_ft_lex_utf8 [node]
#   9.30s DETAIL: load main: F.etcbc4_ft_ls [node]
#   9.48s DETAIL: load main: F.etcbc4_ft_mother_object_type [node]
#   9.57s DETAIL: load main: F.etcbc4_ft_nme [node]
#   9.72s DETAIL: load main: F.etcbc4_ft_nu [node]
#   9.89s DETAIL: load main: F.etcbc4_ft_number [node]
#     10s DETAIL: load main: F.etcbc4_ft_pdp [node]
#     10s DETAIL: load main: F.etcbc4_ft_pfm [node]
#     11s DETAIL: load main: F.etcbc4_ft_prs [node]
#     11s DETAIL: load main: F.etcbc4_ft_prs_gn [node]
#     11s DETAIL: load main: F.etcbc4_ft_prs_nu [node]
#     11s DETAIL: load main: F.etcbc4_ft_prs_ps [node]
#     11s DETAIL: load main: F.etcbc4_ft_ps [node]
#     12s DETAIL: load main: F.etcbc4_ft_qere [node]
#     12s DETAIL: load main: F.etcbc4_ft_qere_utf8 [node]
#     12s DETAIL: load main: F.etcbc4_ft_rela [node]
#     12s DETAIL: load main: F.etcbc4_ft_sp [node]
#     12s DETAIL: load main: F.etcbc4_ft_st [node]
#     12s DETAIL: load main: F.etcbc4_ft_tab [node]
#     13s DETAIL: load main: F.etcbc4_ft_trailer [node]
#     13s DETAIL: load main: F.etcbc4_ft_trailer_utf8 [node]
#     13s DETAIL: load main: F.etcbc4_ft_txt [node]
#     13s DETAIL: load main: F.etcbc4_ft_typ [node]
#     14s DETAIL: load main: F.etcbc4_ft_uvf [node]
#     14s DETAIL: load main: F.etcbc4_ft_vbe [node]
#     14s DETAIL: load main: F.etcbc4_ft_vbs [node]
#     15s DETAIL: load main: F.etcbc4_ft_vs [node]
#     15s DETAIL: load main: F.etcbc4_ft_vt [node]
#     15s DETAIL: load main: F.etcbc4_sft_book [node]
#     15s DETAIL: load main: F.etcbc4_sft_chapter [node]
#     15s DETAIL: load main: F.etcbc4_sft_label [node]
#     15s DETAIL: load main: F.etcbc4_sft_verse [node]
#     15s DETAIL: load main: F.etcbc4_ft_distributional_parent [e]
#     15s DETAIL: load main: F.etcbc4_ft_functional_parent [e]
#     16s DETAIL: load main: F.etcbc4_ft_mother [e]
#     16s DETAIL: load main: C.etcbc4_ft_distributional_parent ->
#     17s DETAIL: load main: C.etcbc4_ft_functional_parent ->
#     18s DETAIL: load main: C.etcbc4_ft_mother ->
#     18s DETAIL: load main: C.etcbc4_ft_distributional_parent <-
#     19s DETAIL: load main: C.etcbc4_ft_functional_parent <-
#     19s DETAIL: load main: C.etcbc4_ft_mother <-
#     19s NORMAL: DATA LOADED FROM SOURCE etcbc4c AND ANNOX  FOR TASK feature-doc AT 2016-11-09T09-49-39

# %%
API = fabric.load('calap', '--', 'feature-doc', {
    "xmlids": {"node": False, "edge": False},
    "features": ("",""),
    "primary": False,
})

doc = FeatureDoc(fabric, {
    'features': {
        'node': '''
            gender
            tense
            psp
            phrase_function
            phrase_type
            surface_consonants
        ''',
        'edge': '',
    },
    'absence_values': set((
        'none',
        'unknown',
        'Unkn',
    )),
    'VALUE_THRESHOLD': 50,
    'vlabel': 'verse_label',
})

exec(fabric.localnames.format(var='fabric'))

# %% [markdown]
# If you want to know the set of available features, you can inspect it by:

# %%
(API['F_all'], API['FE_all'])
# Out:
# ([('etcbc4',
#    ['db.maxmonad',
#     'db.minmonad',
#     'db.monads',
#     'db.oid',
#     'db.otype',
#     'ft.code',
#     'ft.det',
#     'ft.dist',
#     'ft.dist_unit',
#     'ft.domain',
#     'ft.function',
#     'ft.g_cons',
#     'ft.g_cons_utf8',
#     'ft.g_lex',
#     'ft.g_lex_utf8',
#     'ft.g_nme',
#     'ft.g_nme_utf8',
#     'ft.g_pfm',
#     'ft.g_pfm_utf8',
#     'ft.g_prs',
#     'ft.g_prs_utf8',
#     'ft.g_uvf',
#     'ft.g_uvf_utf8',
#     'ft.g_vbe',
#     'ft.g_vbe_utf8',
#     'ft.g_vbs',
#     'ft.g_vbs_utf8',
#     'ft.g_voc_lex',
#     'ft.g_voc_lex_utf8',
#     'ft.g_word',
#     'ft.g_word_utf8',
#     'ft.gn',
#     'ft.is_root',
#     'ft.kind',
#     'ft.language',
#     'ft.lex',
#     'ft.lex_utf8',
#     'ft.ls',
#     'ft.mother_object_type',
#     'ft.nme',
#     'ft.nu',
#     'ft.number',
#     'ft.pdp',
#     'ft.pfm',
#     'ft.prs',
#     'ft.prs_gn',
#     'ft.prs_nu',
#     'ft.prs_ps',
#     'ft.ps',
#     'ft.qere',
#     'ft.qere_utf8',
#     'ft.rela',
#     'ft.sp',
#     'ft.st',
#     'ft.tab',
#     'ft.trailer',
#     'ft.trailer_utf8',
#     'ft.txt',
#     'ft.typ',
#     'ft.uvf',
#     'ft.vbe',
#     'ft.vbs',
#     'ft.vs',
#     'ft.vt',
#     'sft.book',
#     'sft.chapter',
#     'sft.label',
#     'sft.verse'])],
#  [('etcbc4',
#    ['ft.distributional_parent', 'ft.functional_parent', 'ft.mother']),
#   ('laf', ['.x', '.y'])])

# %% [markdown]
# Now generate files with feature data.
# For each selected feature, you get a list with values, with for each value its number of occurrences.
# The values are divided into two sets: *defined values* and *absence values*.
# The latter are values such as ``none``, ``unknown``. You have to provide these values yourself by adapting the ``absence_values`` list in the study specification above.

# %%
doc.feature_doc()
# Out:
#  1m 41s Looking up feature values ...
#  1m 50s  100000 nodes done
#  1m 58s  200000 nodes done
#  2m 07s  300000 nodes done
#  2m 15s  400000 nodes done
#  2m 23s  500000 nodes done
#  2m 31s  600000 nodes done
#  2m 40s  700000 nodes done
#  2m 48s  800000 nodes done
#  2m 56s  900000 nodes done
#  3m 04s 1000000 nodes done
#  3m 12s 1100000 nodes done
#  3m 20s 1200000 nodes done
#  3m 29s 1300000 nodes done
#  3m 38s 1400000 nodes done
#  3m 41s 1436894 nodes done
#  3m 41s  100000 edges done
#  3m 42s  200000 edges done
#  3m 42s  300000 edges done
#  3m 43s  400000 edges done
#  3m 43s  500000 edges done
#  3m 43s  600000 edges done
#  3m 44s  700000 edges done
#  3m 44s  800000 edges done
#  3m 45s  900000 edges done
#  3m 45s 1000000 edges done
#  3m 46s 1100000 edges done
#  3m 46s 1200000 edges done
#  3m 47s 1300000 edges done
#  3m 47s 1400000 edges done
#  3m 48s 1500000 edges done
#  3m 49s 1600000 edges done
#  3m 49s 1700000 edges done
#  3m 50s 1800000 edges done
#  3m 50s 1900000 edges done
#  3m 50s 2000000 edges done
#  3m 51s 2100000 edges done
#  3m 51s 2200000 edges done
#  3m 52s 2225333 edges done
#  3m 52s Computing results ...
#  4m 19s Done

# %% [markdown]
# There is also a summary file.
#
# For each feature it has the following columns:
#
# **Feature** name of the feature
# **val (-)**, **val (+)** value of the feature; **val (-)** contains absence values, **val (+)** contains defined values.
# **#vals** number of distinct values of this feature, split between the absence values and the defined values
# **occs** number of occurrences of this value or this feature
# **clause**, **phrase**, etc: how often the feature occurs on which type of node.
