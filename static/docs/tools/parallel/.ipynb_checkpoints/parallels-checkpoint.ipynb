# %% [markdown]
# <a href="http://laf-fabric.readthedocs.org/en/latest/" target="_blank"><img align="left" src="images/laf-fabric-xsmall.png"/></a>
# <a href="http://www.persistent-identifier.nl/?identifier=urn%3Anbn%3Anl%3Aui%3A13-048i-71" target="_blank"><img align="left"src="images/etcbc4easy-small.png"/></a>
# <a href="http://www.godgeleerdheid.vu.nl/etcbc" target="_blank"><img align="right" src="images/VU-ETCBC-xsmall.png"/></a>
# <a href="https://www.academic-bible.com/en/online-bibles/biblia-hebraica-stuttgartensia-bhs/read-the-bible-text/" target="_blank"><img align="right" src="files/images/DBG-xsmall.png"/></a>

# %% [markdown]
# <img align="right" width="50%" src="files/images/parallel.png"/>
#
# # Parallel Passages in the MT
#
# We want to make a list of **all** parallel passages in the Masoretic Text (MT) of the Hebrew Bible.
# More precisely, we want to produce a set of *cliques*, a clique being a set of passages that are *quite* similar.
#
# Here is a quote that triggered Dirk to write this notebook:
#
# > Finally, the Old Testament Parallels module in Accordance is a helpful resource that enables the researcher to examine 435 sets of parallel texts, or in some cases very similar wording in different texts, in both the MT and translation, but the large number of sets of texts in this database should not fool one to think it is complete or even nearly complete for all parallel writings in the Hebrew Bible.
#
# Robert Rezetko and Ian Young.
#   Historical linguistics & Biblical Hebrew. Steps Toward an Integrated Approach.
#   *Ancient Near East Monographs, Number9*. SBL Press Atlanta. 2014.
#   [PDF Open access available](https://www.google.nl/url?sa=t&rct=j&q=&esrc=s&source=web&cd=2&ved=0CCgQFjAB&url=http%3A%2F%2Fwww.sbl-site.org%2Fassets%2Fpdfs%2Fpubs%2F9781628370461_OA.pdf&ei=2QSdVf-vAYSGzAPArJeYCg&usg=AFQjCNFA3TymYlsebQ0MwXq2FmJCSHNUtg&sig2=LaXuAC5k3V7fSXC6ZVx05w&bvm=bv.96952980,d.bGQ)
#
#
# # Authors
#
# [Dirk Roorda](mailto:dirk.roorda@dans.knaw.nl) while discussing ideas with
# [Martijn Naaijer](mailto:m.naaijer@vu.nl).
#
# # Status
#
# **Last modified: 2015-07-28**
#
# 126 experiments have been carried out, of which 9 with promising results.
# All results can be easily inspected, just by clicking in your browser.
# One of the experiments has been chosen as the basis for
# [crossref](https://shebanq.ancient-data.org/hebrew/note?version=4b&id=Mnxjcm9zc3JlZg__&tp=txt_tb1&nget=v)
# annotations in SHEBANQ.
#
# # Results
#
# Click in a green cell to see interesting results. The numbers in the cell indicate
#
# * the number of passages that have a variant elsewhere
# * the number of *cliques* they form (cliques are sets of similar passages)
# * the number of passages in the biggest clique
#
# Below the results is an account of the method that we used, followed by the actual code to produce these results.

# %%
# run this cell after all other cells
HTML(other_exps)
# Out:
# <table>
# <tr><td class="mis">no results available</td></tr>
# <tr><td class="rec">promising results: recommended</td></tr>
# <tr><td class="dep">messy results: deprecated</td></tr>
# <tr><td class="dub">mixed quality: take care</td></tr>
# <tr><td class="out">method deprecated</td></tr>
# <tr><td class="nor">unassessed quality: inspection needed</td></tr>
# </table>
#
# <table>
# <tr><th>chunk type</th><th>chunk size</th><th>similarity method</th><th>100</th><th>95</th><th>90</th><th>85</th><th>80</th><th>75</th><th>70</th><th>65</th><th>60</th></tr>
# <tr><td>fixed</td><td>100</td><td>SET</td>
# <td class="out" title="">
#     <span class="ps">2</span><br/>
#     <a target="_blank" href="files/experiments/F_100_SET_M50_S100.html"><span class="cl">1</span></a><br/>
#     <span class="mx">2</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">4</span><br/>
#     <a target="_blank" href="files/experiments/F_100_SET_M50_S95.html"><span class="cl">2</span></a><br/>
#     <span class="mx">2</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">18</span><br/>
#     <a target="_blank" href="files/experiments/F_100_SET_M50_S90.html"><span class="cl">9</span></a><br/>
#     <span class="mx">2</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">37</span><br/>
#     <a target="_blank" href="files/experiments/F_100_SET_M50_S85.html"><span class="cl">18</span></a><br/>
#     <span class="mx">3</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">64</span><br/>
#     <a target="_blank" href="files/experiments/F_100_SET_M50_S80.html"><span class="cl">30</span></a><br/>
#     <span class="mx">6</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">87</span><br/>
#     <a target="_blank" href="files/experiments/F_100_SET_M50_S75.html"><span class="cl">40</span></a><br/>
#     <span class="mx">9</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">113</span><br/>
#     <a target="_blank" href="files/experiments/F_100_SET_M50_S70.html"><span class="cl">52</span></a><br/>
#     <span class="mx">9</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">154</span><br/>
#     <a target="_blank" href="files/experiments/F_100_SET_M50_S65.html"><span class="cl">70</span></a><br/>
#     <span class="mx">9</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">208</span><br/>
#     <a target="_blank" href="files/experiments/F_100_SET_M50_S60.html"><span class="cl">94</span></a><br/>
#     <span class="mx">10</span>
#     </td></tr>
# <tr><td>fixed</td><td>100</td><td>LCS</td>
# <td class="out" title="">
#     <span class="ps">0</span><br/>
#     <a target="_blank" href="files/experiments/F_100_LCS_M60_S100.html"><span class="cl">0</span></a><br/>
#     <span class="mx">0</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">4</span><br/>
#     <a target="_blank" href="files/experiments/F_100_LCS_M60_S95.html"><span class="cl">2</span></a><br/>
#     <span class="mx">2</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">39</span><br/>
#     <a target="_blank" href="files/experiments/F_100_LCS_M60_S90.html"><span class="cl">19</span></a><br/>
#     <span class="mx">3</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">59</span><br/>
#     <a target="_blank" href="files/experiments/F_100_LCS_M60_S85.html"><span class="cl">29</span></a><br/>
#     <span class="mx">3</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">85</span><br/>
#     <a target="_blank" href="files/experiments/F_100_LCS_M60_S80.html"><span class="cl">41</span></a><br/>
#     <span class="mx">3</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">122</span><br/>
#     <a target="_blank" href="files/experiments/F_100_LCS_M60_S75.html"><span class="cl">56</span></a><br/>
#     <span class="mx">9</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">189</span><br/>
#     <a target="_blank" href="files/experiments/F_100_LCS_M60_S70.html"><span class="cl">88</span></a><br/>
#     <span class="mx">9</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">287</span><br/>
#     <a target="_blank" href="files/experiments/F_100_LCS_M60_S65.html"><span class="cl">132</span></a><br/>
#     <span class="mx">9</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">535</span><br/>
#     <a target="_blank" href="files/experiments/F_100_LCS_M60_S60.html"><span class="cl">214</span></a><br/>
#     <span class="mx">31</span>
#     </td></tr>
# <tr><td>fixed</td><td>50</td><td>SET</td>
# <td class="out" title="">
#     <span class="ps">0</span><br/>
#     <a target="_blank" href="files/experiments/F_50_SET_M50_S100.html"><span class="cl">0</span></a><br/>
#     <span class="mx">0</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">4</span><br/>
#     <a target="_blank" href="files/experiments/F_50_SET_M50_S95.html"><span class="cl">2</span></a><br/>
#     <span class="mx">2</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">24</span><br/>
#     <a target="_blank" href="files/experiments/F_50_SET_M50_S90.html"><span class="cl">12</span></a><br/>
#     <span class="mx">2</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">57</span><br/>
#     <a target="_blank" href="files/experiments/F_50_SET_M50_S85.html"><span class="cl">26</span></a><br/>
#     <span class="mx">5</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">114</span><br/>
#     <a target="_blank" href="files/experiments/F_50_SET_M50_S80.html"><span class="cl">52</span></a><br/>
#     <span class="mx">7</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">186</span><br/>
#     <a target="_blank" href="files/experiments/F_50_SET_M50_S75.html"><span class="cl">85</span></a><br/>
#     <span class="mx">8</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">271</span><br/>
#     <a target="_blank" href="files/experiments/F_50_SET_M50_S70.html"><span class="cl">124</span></a><br/>
#     <span class="mx">10</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">385</span><br/>
#     <a target="_blank" href="files/experiments/F_50_SET_M50_S65.html"><span class="cl">176</span></a><br/>
#     <span class="mx">12</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">535</span><br/>
#     <a target="_blank" href="files/experiments/F_50_SET_M50_S60.html"><span class="cl">235</span></a><br/>
#     <span class="mx">15</span>
#     </td></tr>
# <tr><td>fixed</td><td>50</td><td>LCS</td>
# <td class="out" title="">
#     <span class="ps">0</span><br/>
#     <a target="_blank" href="files/experiments/F_50_LCS_M60_S100.html"><span class="cl">0</span></a><br/>
#     <span class="mx">0</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">12</span><br/>
#     <a target="_blank" href="files/experiments/F_50_LCS_M60_S95.html"><span class="cl">6</span></a><br/>
#     <span class="mx">2</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">53</span><br/>
#     <a target="_blank" href="files/experiments/F_50_LCS_M60_S90.html"><span class="cl">25</span></a><br/>
#     <span class="mx">5</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">119</span><br/>
#     <a target="_blank" href="files/experiments/F_50_LCS_M60_S85.html"><span class="cl">53</span></a><br/>
#     <span class="mx">11</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">196</span><br/>
#     <a target="_blank" href="files/experiments/F_50_LCS_M60_S80.html"><span class="cl">89</span></a><br/>
#     <span class="mx">12</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">301</span><br/>
#     <a target="_blank" href="files/experiments/F_50_LCS_M60_S75.html"><span class="cl">135</span></a><br/>
#     <span class="mx">19</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">464</span><br/>
#     <a target="_blank" href="files/experiments/F_50_LCS_M60_S70.html"><span class="cl">205</span></a><br/>
#     <span class="mx">20</span>
#     </td>
# <td class="out" title="">
#     <span class="ps">761</span><br/>
#     <a target="_blank" href="files/experiments/F_50_LCS_M60_S65.html"><span class="cl">312</span></a

# %% [markdown]
# # Experiments and results
#
# We have conducted 126 experiments, all corresponding to a specific choice of parameters.
# Every experiment is an attempt to identify variants and collect them in *cliques*.
#
# The table gives an overview of the experiments conducted.
#
# Every *row* corresponds to a particular way of chunking and a method of measuring the similarity.
#
# There are *columns* for each similarity *threshold* that we have tried.
# The idea is that chunks are similar if their similarity is above the threshold.
#
# The outcomes of one experiment have been added to SHEBANQ as the note set
# [crossref](https://shebanq.ancient-data.org/hebrew/note?version=4b&id=Mnxjcm9zc3JlZg__&tp=txt_tb1&nget=v).
# The experiment chosen for this is currently
#
# * *chunking*: **object verse**
# * *similarity method*: **SET**
# * *similarity threshold*: **65**
#
#
# ## Assessing the outcomes
#
# Not all experiments lead to useful results.
# We have indicated the value of a result by a color coding, based on objective characteristics,
# such as the number of passages, the number of cliques, the size of the greatest clique, and the way of chunking.
# These numbers are shown in the cells.
#
# If you click on the hyperlink in the cell, you are taken to a page that gives you
# all the details of the results:
#
# 1. A link to a file with all *cliques* (which are the sets of similar passages)
# 1. A list of links to chapter-by-chapter diff files (for cliques with just two members), and only for
#    experiments with outcomes that are labeled as *promising* or *unassessed quality* or *mixed results*.
#
# To get into the variants quickly, inspect the list (2) and click through
# to see the actual variant material in chapter context.
#
# Not all variants occur here, so continue with (1) to see the remaining cliques.
#
# Sometimes in (2) a chapter diff file does not indicate clearly the relevant common part of both chapters.
# In that case you have to consult the big list (1)
#
# All these results can be downloaded from the
# [SHEBANQ github repo](https://github.com/ETCBC/shebanq/tree/master/static/docs/tools/parallel/files)
# After downloading the whole directory, open ``experiments.html`` in your browser.

# %% [markdown]
# # About
#
# This is an IPython notebook.
# It contains a working program to carry out the computations needed to obtain the results reported here.
#
# You can download this notebook and run it on your computer, provided you have
# [LAF-Fabric](http://laf-fabric.readthedocs.org/en/latest/texts/welcome.html) installed.
# An easy way to do that is describe [here](https://github.com/ETCBC/llshebanq).

# %% [markdown]
# # Method description
#
# Here we discuss the method we used to arrive at a list of parallel passages
# in the Masoretic Text (MT) of the Hebrew Bible.
#
# ## Similarity
#
# We have to find passages in the MT that are *similar*.
# Therefore we *chunk* the text in some way, and then compute the similarities between pairs of chunks.
#
# There are many ways to define and compute similarity between texts.
# Here, we have tried two methods ``SET`` and ``LCS``.
# Both methods define similarity as the fraction of common material with respect to the total material.
#
# ### SET
#
# The ``SET`` method reduces textual chunks to *sets* of *lexemes*.
# This method abstracts from the order and number of occurrences of words in chunks.
#
# We use as measure for the similarity of chunks $C_1$ and $C_2$ (taken as sets):
#
# $$ s_{\rm set}(C_1, C_2) = {\vert C_1 \cap C_2\vert \over \vert C_1 \cup C_2 \vert} $$
#
# where $\vert X \vert$ is the number of elements in set $X$.
#
# ### LCS
#
# The ``LCS`` method is less reductive: chunks are *strings* of *lexemes*,
# so the order and number of occurrences of words is retained.
#
# We use as measure for the similarity of chunks $C_1$ and $C_2$ (taken as strings):
#
# $$ s_{\rm lcs}(C_1, C_2) = {\vert {\rm LCS}(C_1,C_2)\vert \over \vert C_1\vert + \vert C_2 \vert -
# \vert {\rm LCS}(C_1,C_2)\vert} $$
#
# where ${\rm LCS}(C_1, C_2)$ is the
# [longest common subsequence](https://en.wikipedia.org/wiki/Longest_common_subsequence_problem)
# of $C_1$ and $C_2$ and
# $\vert X\vert$ is the length of sequence $X$.
#
# It remains to be seen whether we need the extra sophistication of ``LCS``.
# The risk is that ``LCS`` could fail to spot related passages when there is a large amount of transposition going on.
# The results should have the last word.
#
# We need to compute the LCS efficiently, and for this we used the python ``Levenshtein`` module:
#
# ``pip install python-Levenshtein``
#
# whose documentation is
# [here](http://www.coli.uni-saarland.de/courses/LT1/2011/slides/Python-Levenshtein.html).
#
# ## Performance
#
# Similarity computation is the part where the heavy lifting occurs.
# It is basically quadratic in the number of chunks, so if you have verses as chunks (~ 23,000),
# you need to do ~ 270,000,000 similarity computations, and if you use sentences (~ 64,000),
# you need to do ~ 2,000,000,000 ones!
# The computation of a single similarity should be *really* fast.
#
# Besides that, we use two ways to economize:
#
# * after having computed a matrix for a specific set of parameter values, we save the matrix to disk;
#   new runs can load the matrix from disk in a matter of seconds;
# * we do not store low similarity values in the matrix, low being < ``MATRIX_THRESHOLD``.
#
# The ``LCS`` method is more complicated.
# We have tried the ``ratio`` method from the ``difflib`` package that is present in the standard python distribution.
# This is unbearably slow for our purposes.
# The ``ratio`` method in the ``Levenshtein`` package is much quicker.
#
# See the table for an indication of the amount of work to create the similarity matrix
# and the performance per similarity method.
#
# The *matrix threshold* is the lower bound of similarities that are stored in the matrix.
# If a pair of chunks has a lower similarity, no entry will be made in the matrix.
#
# The computing has been done on a Macbook Air (11", mid 2012, 1.7 GHz Intel Core i5, 8GB RAM).
#
# |chunk type |chunk size|similarity method|matrix threshold|# of comparisons|size of matrix (KB)|computing time (min)|
# |:----------|---------:|----------------:|---------------:|---------------:|------------------:|-------------------:|
# |fixed      |100       |LCS              |60              |       9,003,646|                  7|                  ? |
# |fixed      |100       |SET              |50              |       9,003,646|                  7|                  ? |
# |fixed      |50        |LCS              |60              |      36,197,286|                 37|                  ? |
# |fixed      |50        |SET              |50              |      36,197,286|                 18|                  ? |
# |fixed      |20        |LCS              |60              |     227,068,705|              2,400|                  ? |
# |fixed      |20        |SET              |50              |     227,068,705|                113|                  ? |
# |fixed      |10        |LCS              |60              |     909,020,841|             59,000|                  ? |
# |fixed      |10        |SET              |50              |     909,020,841|              1,800|                  ? |
# |object     |verse     |LCS              |60              |     269,410,078|              2,300|                  31|
# |object     |verse     |SET              |50              |     269,410,078|                509|                  14|
# |object     |half_verse|LCS              |60              |   1,016,396,241|             40,000|                  50|
# |object     |half_verse|SET              |50              |   1,016,396,241|              3,600|                  41|
# |object     |sentence  |LCS              |60              |   2,055,975,750|            212,000|                  68|
# |object     |sentence  |SET              |50              |   2,055,975,750|             82,000|                  63|
#
#
# ## Chunking
#
# There are several ways to chunk the text:
#
# * fixed chunks of approximately ``CHUNK_SIZE`` words
# * by object, such as verse, sentence
#
# After chunking, we prepare the chunks for similarity measuring.
#
# ### Observations
#
# #### Fixed chunking
# Fixed chunking is unnatural, but if the chunk size is small, it can yield fair results.
# The results are somewhat difficult to inspect, because they generally do not respect constituent boundaries.
# It is to be expected that fixed chunks in variant passages will be mutually *out of phase*,
# meaning that the chunks involved in these passages are not aligned with each other.
# So they will have a lower similarity than they could have if they were aligned.
# This is a source of artificial noise in the outcome and/or missed cases.
#
# If the chunking respects "natural" boundaries in the text, there is far less misalignment.
#
# #### Object chunking
# We can also chunk by object, such as verse, half_verse or sentence.
#
# Chunking by *verse* is very much like chunking in fixed chunks of size 20, performance-wise.
#
# Chunking by *half_verse* is comparable to fixed chunks of size 10.
#
# Chunking by *sentence* will generate an enormous amount of
# false positives, because there are very many very short sentences (down to 1-word) in the text.
# Besides that, the performance overhead is huge.
#
# The *half_verses* seem to be a very interesting candidate.
# They are smaller than verses, but there are less *degenerate cases* compared to with sentences.
# From the table above it can be read that half verses require only half as many similarity computations as sentences.
#
#
# ## Preparing
#
# We prepare the chunks for the application of the chosen method of similarity computation (``SET`` or ``LCS``).
#
# In both cases we reduce the text to a sequence of transliterated consonantal *lexemes* without disambiguation.
# In fact, we go one step further: we remove the consonants (alef, wav, yod) that are often silent.
#
# For ``SET``, we represent each chunk as the set of its reduced lexemes.
#
# For ``LCS``, we represent each chunk as the string obtained by joining its reduced lexemes separated by white spaces.
#
# ## Cliques
#
# After having computed a sufficient part of the similarity matrix, we set a value for ``SIMILARITY_THRESHOLD``.
# All pairs of chunks having at least that similarity are deemed *interesting*.
#
# We organize the members of such pairs in *cliques*, groups of chunks of which each member is
# similar (*similarity* > ``SIMILARITY_THRESHOLD``) to at least one other member.
#
# We start with no cliques and walk through the pairs whose similarity is above ``SIMILARITY_THRESHOLD``,
# and try to put each member into a clique.
#
# If there is not yet a clique, we make the member in question into a new singleton clique.
#
# If there are cliques, we find the cliques that have a member similar to the member in question.
# If we find several, we merge them all into one clique.
#
# If there is no such clique, we put the member in a new singleton clique.
#
# NB: Cliques may *drift*, meaning that they contain members that are completely different from each other.
# They are in the same clique, because there is a path of pairwise similar members leading from the one chunk to the other.
#
# ### Organizing the cliques
# In order to accomodate cases where there are many corresponding verses in corresponding chapters, we produce
# chapter-by-chapter diffs in the following way.
#
# We make a list of all chapters that are involved in cliques.
# This yields a list of chapter cliques.
# For all *binary* chapters cliques, we generate a colorful diff rendering (as html) for the complete two chapters.
#
# We only do this for *promising* experiments.
#
# ### Evaluating clique sets
#
# Not all clique sets are equally worth while.
# For example, if we set the ``SIMILARITY_THRESHOLD`` too low, we might get one gigantic clique, especially
# in combination with a fine-grained chunking. In other words: we suffer from *clique drifting*.
#
# We detect clique drifting by looking at the size of the largest clique.
# If that is large compared to the total number of chunks, we deem the results unsatisfactory.
#
# On the other hand, when the ``SIMILARITY_THRESHOLD`` is too high, you might miss a lot of correspondences,
# especially when chunks are large, or when we have fixed-size chunks that are out of phase.
#
# We deem the results of experiments based on a partioning into fixed length chunks as unsatisfactory, although it
# might be interesting to inspect what exactly the damage is.
#
# At the moment, we have not yet analysed the relative merits of the similarity methods ``SET`` and ``LCS``.

# %% [markdown]
# # Firing up the engines
#
# The rest is code. From here we start computing.

# %%
import sys, os, re, collections, pickle, math, difflib, glob

from IPython.display import HTML, display
import matplotlib.pyplot as plt
# %matplotlib inline
PICKLE_PROTOCOL = 3

from difflib import SequenceMatcher
from Levenshtein import ratio

import laf
from laf.fabric import LafFabric
from etcbc.preprocess import prepare
fabric = LafFabric()
# Out:
#   0.00s This is LAF-Fabric 4.5.4
# API reference: http://laf-fabric.readthedocs.org/en/latest/texts/API-reference.html
# Feature doc: https://shebanq.ancient-data.org/static/docs/featuredoc/texts/welcome.html

# %% [markdown]
# # Loading the feature data

# %%
version = '4b'
API = fabric.load('etcbc{}'.format(version), '--', 'parallel', {
    "xmlids": {"node": False, "edge": False},
    "features": ('''
        otype
        lex g_word_utf8 trailer_utf8
        book chapter verse label number
    ''',
    ''),
    "prepare": prepare,
    "primary": False,
}, verbose='NORMAL')
exec(fabric.localnames.format(var='fabric'))
# Out:
#   0.00s LOADING API: please wait ...
#   0.00s INFO: USING DATA COMPILED AT: 2015-11-02T15-08-56
#   2.78s LOGFILE=/Users/dirk/SURFdrive/laf-fabric-output/etcbc4b/parallel/__log__parallel.txt
#     12s ETCBC reference: http://laf-fabric.readthedocs.org/en/latest/texts/ETCBC-reference.html
#   0.00s LOADING API with EXTRAs: please wait ...
#   0.00s INFO: USING DATA COMPILED AT: 2015-11-02T15-08-56
#   0.00s INFO: DATA LOADED FROM SOURCE etcbc4b AND ANNOX -- FOR TASK parallel AT 2015-11-02T18-53-36
#   0.00s INFO: DATA LOADED FROM SOURCE etcbc4b AND ANNOX -- FOR TASK parallel AT 2015-11-02T18-53-36

# %% [markdown]
# # Parameters
#
# Here are the parameters on which the results crucially depend.
#
# There are also parameters that control the reporting of the results.

# %%
# chunking
CHUNK_LABELS = {True: 'fixed', False: 'object'}
CHUNK_LBS = {True: 'F', False: 'O'}
CHUNK_SIZES = (100, 50, 20, 10)
CHUNK_OBJECTS = ('verse','half_verse','sentence')

# preparing
EXCLUDED_CONS = '[>WJ=/\[]'             # weed out weak consonants
EXCLUDED_PAT = re.compile(EXCLUDED_CONS)

# similarity
MATRIX_THRESHOLD = 50
SIM_METHODS = ('SET', 'LCS')
SIMILARITIES = (100, 95, 90, 85, 80, 75, 70, 65, 60)

# printing
DEP_CLIQUE_RATIO = 25
DUB_CLIQUE_RATIO = 15
REC_CLIQUE_RATIO =  5
LARGE_CLIQUE_SIZE = 50
CLIQUES_PER_FILE = 50

# assessing results
VALUE_LABELS = dict(
    mis='no results available',
    rec='promising results: recommended',
    dep='messy results: deprecated',
    dub='mixed quality: take care',
    out='method deprecated',
    nor='unassessed quality: inspection needed',
    lr='this experiment is the last one run',
)

# crossrefs for SHEBANQ
SHEBANQ_MATRIX = (False, 'verse', 'SET')
SHEBANQ_SIMILARITY = 65
SHEBANQ_TOOL = 'parallel'
CROSSREF_STATUS = '!'
CROSSREF_KEYWORD = 'crossref'

# progress indication
VERBOSE = False
MEGA = 1000000
KILO = 1000
SIMILARITY_PROGRESS = 5 * MEGA
CLIQUES_PROGRESS = 1 * KILO

# locations and hyperlinks
REMOTE_BASE = 'https://surfdrive.surf.nl/files/public.php?service=files&t=dedf27be7e171ab8a8b151f84ded93e8'
LOCAL_BASE_COMP = my_file('').rstrip('/')
LOCAL_BASE_OUTP = 'files'
EXPERIMENT_DIR = 'experiments'
EXPERIMENT_FILE = 'experiments'
EXPERIMENT_PATH = '{}/{}.txt'.format(LOCAL_BASE_OUTP, EXPERIMENT_FILE)
EXPERIMENT_HTML = '{}/{}.html'.format(LOCAL_BASE_OUTP, EXPERIMENT_FILE)
NOTES_FILE = 'crossref'
NOTES_PATH = '{}/{}.csv'.format(LOCAL_BASE_OUTP, NOTES_FILE)
STORED_CLIQUE_DIR = 'stored/cliques'
STORED_MATRIX_DIR = 'stored/matrices'
CHAPTER_DIR = 'chapters'
CROSSREF_DB_FILE = 'crossrefdb.csv'
CROSSREF_DB_PATH = '{}/{}'.format(LOCAL_BASE_OUTP, CROSSREF_DB_FILE)

def reset_params():
    global CHUNK_FIXED, CHUNK_SIZE, CHUNK_OBJECT, CHUNK_LB, CHUNK_DESC
    global SIMILARITY_METHOD, SIMILARITY_THRESHOLD, MATRIX_THRESHOLD
    global meta
    meta = collections.OrderedDict()
    
    # chunking
    CHUNK_FIXED = None                      # kind of chunking: fixed size or by object
    CHUNK_SIZE = None                       # only relevant for CHUNK_FIXED = True
    CHUNK_OBJECT = None                     # only relevant for CHUNK_FIXED = False; see CHUNK_OBJECTS in next cell
    CHUNK_LB = None                         # computed from CHUNK_FIXED, CHUNK_SIZE, CHUNK_OBJ
    CHUNK_DESC = None                       # computed from CHUNK_FIXED, CHUNK_SIZE, CHUNK_OBJ
    # similarity
    MATRIX_THRESHOLD = None                 # minimal similarity used to fill the matrix of similarities
    SIMILARITY_METHOD = None                # see SIM_METHODS in next cell
    SIMILARITY_THRESHOLD = None             # minimal similarity used to put elements together in cliques
    meta = collections.OrderedDict()

def set_matrix_threshold(sim_m=None):
    global MATRIX_THRESHOLD
    the_sim_m = SIMILARITY_METHOD if sim_m == None else sim_m
    MATRIX_THRESHOLD = 50 if the_sim_m == 'SET' else 60

def do_params(chunk_f, chunk_i, sim_m, sim_thr):
    global CHUNK_FIXED, CHUNK_SIZE, CHUNK_OBJECT, CHUNK_LB, CHUNK_DESC
    global SIMILARITY_METHOD, SIMILARITY_THRESHOLD, MATRIX_THRESHOLD
    global meta
    do_chunk = False
    do_prep = False
    do_sim = False
    do_clique = False
    meta = collections.OrderedDict()
    if chunk_f != CHUNK_FIXED or (chunk_f and chunk_i != CHUNK_SIZE) or (not chunk_f and chunk_i != CHUNK_OBJECT):
        do_chunk = True
        do_prep = True
        do_sim = True
        do_clique = True
        CHUNK_FIXED = chunk_f
        if chunk_f: CHUNK_SIZE = chunk_i
        else: CHUNK_OBJECT = chunk_i
    if sim_m != SIMILARITY_METHOD:
        do_prep = True
        do_sim = True
        do_clique = True
        SIMILARITY_METHOD = sim_m
    if sim_thr != SIMILARITY_THRESHOLD:
        do_clique = True
        SIMILARITY_THRESHOLD = sim_thr
    set_matrix_threshold()
    CHUNK_LB = CHUNK_LBS[CHUNK_FIXED]
    CHUNK_DESC = CHUNK_SIZE if CHUNK_FIXED else CHUNK_OBJECT

    meta['CHUNK TYPE'] = 'FIXED {}'.format(CHUNK_SIZE) if CHUNK_FIXED else 'OBJECT {}'.format(CHUNK_OBJECT)
    meta['MATRIX THRESHOLD'] = MATRIX_THRESHOLD
    meta['SIMILARITY METHOD'] = SIMILARITY_METHOD
    meta['SIMILARITY THRESHOLD'] = SIMILARITY_THRESHOLD
    
    
    for p in (
        '{}/{}'.format(LOCAL_BASE_OUTP, EXPERIMENT_DIR),
        '{}/{}'.format(LOCAL_BASE_OUTP, CHAPTER_DIR),
        '{}/{}'.format(LOCAL_BASE_COMP, STORED_CLIQUE_DIR),
        '{}/{}'.format(LOCAL_BASE_COMP, STORED_MATRIX_DIR),
    ):
        if not os.path.exists(p): os.makedirs(p)

    return (do_chunk, do_prep, do_sim, do_clique)

reset_params()

# %% [markdown]
# # Chunking

# %%
def chunking(do_chunk):
    global chunks, book_rank
    if not do_chunk:
        msg('CHUNKING ({} {}): already chunked into {} chunks'.format(CHUNK_LB, CHUNK_DESC, len(chunks)))
        meta['# CHUNKS'] = len(chunks)
        return
    msg('CHUNKING ({} {})'.format(CHUNK_LB, CHUNK_DESC))
    chunks = []
    book_rank = {}
    for b in F.otype.s('book'):
        book_name = F.book.v(b)
        book_rank[book_name] = b
        words = L.d('word', b)
        nwords = len(words)
        if CHUNK_FIXED:
            nchunks = nwords // CHUNK_SIZE
            if nchunks == 0: 
                nchunks = 1
                common_incr = nwords
                special_incr = 0
            else:            
                rem = nwords % CHUNK_SIZE
                common_incr = rem // nchunks
                special_incr = rem % nchunks
            word_in_chunk = -1
            cur_chunk = -1
            these_chunks = []

            for w in words:
                word_in_chunk += 1
                if word_in_chunk == 0 or (word_in_chunk >= CHUNK_SIZE + common_incr + (1 if cur_chunk < special_incr else 0)):
                    word_in_chunk = 0
                    these_chunks.append([])
                    cur_chunk += 1
                these_chunks[-1].append(w)
        else:
            these_chunks = [L.d('word', c) for c in L.d(CHUNK_OBJECT, b)]

        chunks.extend(these_chunks)

        chunkvolume = sum(len(c) for c in these_chunks)
        if VERBOSE:
            msg('CHUNKING ({} {}): {:<20s} {:>5} words; {:>5} chunks; sizes {:>5} to {:>5}; {:>5}'.format(
                CHUNK_LB, CHUNK_DESC,
                book_name, nwords, len(these_chunks), 
                min(len(c) for c in these_chunks), 
                max(len(c) for c in these_chunks),
                'OK' if chunkvolume == nwords else 'ERROR',
            ))
    meta['# CHUNKS'] = len(chunks)
    msg('CHUNKING ({} {}): Made {} chunks'.format(CHUNK_LB, CHUNK_DESC, len(chunks)))

# %% [markdown]
# # Preparing

# %%
def preparing(do_prepare):
    global chunk_data
    if not do_prepare:
        msg('PREPARING ({} {} {}): Already prepared'.format(CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD))
        return
    msg('PREPARING ({} {} {})'.format(CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD))
    chunk_data = []
    if SIMILARITY_METHOD == 'SET':
        for c in chunks:
            words = (EXCLUDED_PAT.sub('', F.lex.v(w).replace('<', 'O')) for w in c)
            clean_words = (w for w in words if w != '')
            this_data = frozenset(clean_words)
            chunk_data.append(this_data)
    else:
        for c in chunks:
            words = (EXCLUDED_PAT.sub('', F.lex.v(w).replace('<', 'O')) for w in c)
            clean_words = (w for w in words if w != '')
            this_data = ' '.join(clean_words)
            chunk_data.append(this_data)
    msg('PREPARING ({} {} {}): Done {} chunks.'.format(CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, len(chunk_data)))

# %% [markdown]
# # Similarity computation

# %%
def similarity_post():
    nequals = len({x for x in chunk_dist if chunk_dist[x] >= 100})
    cmin = min(chunk_dist.values()) if len(chunk_dist) else '!empty set!'
    cmax = max(chunk_dist.values()) if len(chunk_dist) else '!empty set!'
    meta['LOWEST  AVAILABLE SIMILARITY'] = cmin
    meta['HIGHEST AVAILABLE SIMILARITY'] = cmax
    meta['# EQUAL COMPARISONS'] = nequals
    msg('SIMILARITY ({} {} {} M>{}): similarities between {} and {}. {} are 100%'.format(
        CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD,
        cmin, cmax, nequals,
    ))
    
def similarity(do_sim):
    global chunk_dist
    total_chunks = len(chunks) 
    total_distances = total_chunks * (total_chunks - 1) // 2
    meta['# SIMILARITY COMPARISONS'] = total_distances
    
    SIMILARITY_PROGRESS = total_distances // 100
    if SIMILARITY_PROGRESS >= MEGA:
        sim_unit = MEGA
        sim_lb = 'M'
    else:
        sim_unit = KILO
        sim_lb = 'K'
    
    if not do_sim:
        msg('SIMILARITY ({} {} {} M>{}): Using {:>5} {} ({}) comparisons with {} entries in matrix'.format(
            CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD,
            total_distances // sim_unit, sim_lb, total_distances, len(chunk_dist),
        ))
        meta['# STORED SIMILARITIES'] = len(chunk_dist)
        similarity_post()
        return

    matrix_path = '{}/{}/matrix_{}_{}_{}_{}'.format(
        LOCAL_BASE_COMP, STORED_MATRIX_DIR,
        CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD,
    )

    if os.path.exists(matrix_path):
        with open(matrix_path, 'rb') as f: chunk_dist = pickle.load(f)
        msg('SIMILARITY ({} {} {} M>{}): Loaded: {:>5} {} ({}) comparisons with {} entries in matrix'.format(
            CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD,
            total_distances // sim_unit, sim_lb, total_distances, len(chunk_dist),
        ))
        meta['# STORED SIMILARITIES'] = len(chunk_dist)
        similarity_post()
        return

    msg('SIMILARITY ({} {} {} M>{}): Computing {:>5} {} ({}) comparisons and saving entries in matrix'.format(
        CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD,
        total_distances // sim_unit, sim_lb, total_distances
    ))

    chunk_dist = {}
    wc = 0
    wt = 0
    if SIMILARITY_METHOD == 'SET':
        # method SET: all chunks have been reduced to sets, ratio between lengths of intersection and union
        for i in range(total_chunks):
            c_i = chunk_data[i]
            for j in range(i + 1, total_chunks):
                c_j = chunk_data[j]
                u = len(c_i | c_j)
                d = 100 * len(c_i & c_j) / u if u != 0 else 0
                if d >= MATRIX_THRESHOLD:
                    chunk_dist[(i,j)] = d
                wc += 1
                wt += 1
                if wc == SIMILARITY_PROGRESS:
                    wc = 0
                    msg('SIMILARITY ({} {} {} M>{}): Computed {:>5} {} comparisons and saved {} entries in matrix'.format(
                        CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD,
                        wt // sim_unit, sim_lb, len(chunk_dist),
                    ))
    elif SIMILARITY_METHOD == 'LCS':
        # method LCS: chunks are sequence aligned, ratio between length of all common parts and total length
        for i in range(total_chunks):
            c_i = chunk_data[i]
            for j in range(i + 1, total_chunks):
                c_j = chunk_data[j]
                d = 100 * ratio(c_i, c_j)
                if d >= MATRIX_THRESHOLD:
                    chunk_dist[(i,j)] = d
                wc += 1
                wt += 1
                if wc == SIMILARITY_PROGRESS:
                    wc = 0
                    msg('SIMILARITY ({} {} {} M>{}): Computed {:>5} {} comparisons and saved {} entries in matrix'.format(
                        CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD,
                        wt // sim_unit, sim_lb, len(chunk_dist),
                    ))

    with  open(matrix_path, 'wb') as f: pickle.dump(chunk_dist, f, protocol=PICKLE_PROTOCOL)
        
    msg('SIMILARITY ({} {} {} M>{}): Computed {:>5} {} ({}) comparisons and saved {} entries in matrix'.format(
        CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD,
        wt // sim_unit, sim_lb, wt, len(chunk_dist),
    ))
    
    meta['# STORED SIMILARITIES'] = len(chunk_dist)
    similarity_post()

# %% [markdown]
# # Cliques
#
# Based on the value for the ``SIMILARITY_THRESHOLD`` we use the similarity matrix to pick the *interesting*
# similar pairs out of it. From these pairs we lump together our cliques.

# %%
def key_chunk(i):
    c = chunks[i]
    w = c[0]
    return  (-len(c), L.u('book', w), L.u('chapter', w), L.u('verse', w))

def meta_clique_pre():
    global similars, passages
    msg('CLIQUES ({} {} {} M>{} S>{}): inspecting the similarity matrix'.format(
        CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD, SIMILARITY_THRESHOLD,
    ))
    similars = {x for x in chunk_dist if chunk_dist[x] >= SIMILARITY_THRESHOLD}
    passage_set = set()
    for (i,j) in similars:
        passage_set.add(i)
        passage_set.add(j)
    passages = sorted(passage_set, key=key_chunk)

    meta['# SIMILAR COMPARISONS'] = len(similars)
    meta['# SIMILAR PASSAGES'] = len(passages)    

def meta_clique_pre2():
    msg('CLIQUES ({} {} {} M>{} S>{}): {} relevant similarities between {} passages'.format(
    CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD, SIMILARITY_THRESHOLD,
    len(similars), len(passages),
))


def meta_clique_post():
    global l_c_l
    meta['# CLIQUES'] = len(cliques)
    scliques = collections.Counter()
    for c in cliques:
        scliques[len(c)] += 1
    l_c_l = max(scliques.keys()) if len(scliques) > 0 else 0
    totmn = 0
    totcn = 0
    for (ln, n) in sorted(scliques.items(), key=lambda x: x[0]):
        totmn += ln * n
        totcn += n
        if VERBOSE:
            msg('CLIQUES ({} {} {} M>{} S>{}): {:>4} cliques of length {:>4}'.format(
                CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD, SIMILARITY_THRESHOLD,
                n, ln,
            ))
        meta['# CLIQUES of LENGTH {:>4}'.format(ln)] = n
    msg('CLIQUES ({} {} {} M>{} S>{}): {} members in {} cliques'.format(
        CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD, SIMILARITY_THRESHOLD,
        totmn, totcn,
    ))
    
def cliqueing(do_clique):
    global cliques
    if not do_clique:
        msg('CLIQUES ({} {} {} M>{} S>{}): Already loaded {} cliques out of {} candidates from {} comparisons'.format(
            CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD, SIMILARITY_THRESHOLD,
            len(cliques), len(passages), len(similars),            
        ))
        meta_clique_pre2()
        meta_clique_post()
        return
    msg('CLIQUES ({} {} {} M>{} S>{}): fetching similars and chunk candidates'.format(
        CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD, SIMILARITY_THRESHOLD,        
    ))
    meta_clique_pre()
    meta_clique_pre2()
    clique_path = '{}/{}/clique_{}_{}_{}_{}_{}'.format(
        LOCAL_BASE_COMP, STORED_CLIQUE_DIR,
        CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD, SIMILARITY_THRESHOLD,
    )
    if os.path.exists(clique_path):
        with open(clique_path, 'rb') as f: cliques = pickle.load(f)
        msg('CLIQUES ({} {} {} M>{} S>{}): Loaded: {:>5} cliques out of {:>6} chunks from {} comparisons'.format(
            CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD, SIMILARITY_THRESHOLD,
            len(cliques), len(passages), len(similars),            
        ))
        meta_clique_post()
        return

    msg('CLIQUES ({} {} {} M>{} S>{}): Composing cliques out of {:>6} chunks from {} comparisons'.format(
        CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD, SIMILARITY_THRESHOLD,
        len(passages), len(similars),            
    ))
    cliques_unsorted = []
    np = 0
    npc = 0
    for i in passages:
        added = None
        removable = set()
        for (k, c) in enumerate(cliques_unsorted):
            origc = tuple(c)
            for j in origc:            
                d = chunk_dist.get((i,j), 0) if i < j else chunk_dist.get((j,i), 0) if j < i else 0
                if d >= SIMILARITY_THRESHOLD:
                    if added == None:
                        c.add(i)
                        added = k
                    else:
                        cliques_unsorted[added] |= c
                        removable.add(k)
                    break
        if added == None:
            cliques_unsorted.append({i})
        else:
            if len(removable):
                cliques_unsorted = [c for (k,c) in enumerate(cliques_unsorted) if k not in removable]
        np += 1
        npc += 1
        if npc == CLIQUES_PROGRESS:
            npc = 0
            msg('CLIQUES ({} {} {} M>{} S>{}): Composed {:>5} cliques out of {:>6} chunks'.format(
                CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD, SIMILARITY_THRESHOLD,
                len(cliques_unsorted), np,
            ))
    cliques = sorted([tuple(sorted(c, key=key_chunk)) for c in cliques_unsorted])
    with  open(clique_path, 'wb') as f: pickle.dump(cliques, f, protocol=PICKLE_PROTOCOL)
    meta_clique_post()
    msg('CLIQUES ({} {} {} M>{} S>{}): Composed and saved {:>5} cliques out of {:>6} chunks from {} comparisons'.format(
        CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD, SIMILARITY_THRESHOLD,
        len(cliques), len(passages), len(similars),            
    ))

# %% [markdown]
# # Pretty output
#
# Here are the definitions for formatting the (HTML) output.

# %%
css = '''
td.vl {
    font-family: Verdana, Arial, sans-serif;
    font-size: small;
    text-align: right;
    color: #aaaaaa;
    width: 10%;
    direction: ltr;
    border-left: 2px solid #aaaaaa;
    border-right: 2px solid #aaaaaa;
}
td.ht {
    font-family: Ezra SIL, SBL Hebrew, Verdana, sans-serif;
    font-size: x-large;
    line-height: 1.7;
    text-align: right;
    direction: rtl;
}
table.ht {
    width: 100%;
    direction: rtl;
    border-collapse: collapse;
}
td.ht {
    border-left: 2px solid #aaaaaa;
    border-right: 2px solid #aaaaaa;
}
tr.ht.tb {
    border-top: 2px solid #aaaaaa;
    border-left: 2px solid #aaaaaa;
    border-right: 2px solid #aaaaaa;
}
tr.ht.bb {
    border-bottom: 2px solid #aaaaaa;
    border-left: 2px solid #aaaaaa;
    border-right: 2px solid #aaaaaa;
}
span.m {
    background-color: #aaaaff;
}
span.f {
    background-color: #ffaaaa;
}
span.x {
    background-color: #ffffaa;
    color: #bb0000;
}
span.delete {
    background-color: #ffaaaa;
}
span.insert {
    background-color: #aaffaa;
}
span.replace {
    background-color: #ffff00;
}

'''

diffhead = '''
<head>
    <meta http-equiv="Content-Type"
          content="text/html; charset=UTF-8" />
    <title></title>
    <style type="text/css">
        table.diff {
            font-family: Ezra SIL, SBL Hebrew, Verdana, sans-serif; 
            font-size: x-large;
            text-align: right;
        }
        .diff_header {background-color:#e0e0e0}
        td.diff_header {text-align:right}
        .diff_next {background-color:#c0c0c0}
        .diff_add {background-color:#aaffaa}
        .diff_chg {background-color:#ffff77}
        .diff_sub {background-color:#ffaaaa}
    </style>
</head>
'''

def xterse_chunk(i):
    chunk = chunks[i]
    fword = chunk[0]
    book = L.u('book', fword)
    chapter = L.u('chapter', fword)
    return (book, chapter)

def xterse_clique(ii):
    return tuple(sorted({xterse_chunk(i) for i in ii}))

def terse_chunk(i):
    chunk = chunks[i]
    fword = chunk[0]
    book = L.u('book', fword)
    chapter = L.u('chapter', fword)
    verse = L.u('verse', fword)
    return (book, chapter, verse)

def terse_clique(ii):
    return tuple(sorted({terse_chunk(i) for i in ii}))

def verse_chunk(i):
    (bk, ch, vs) = i
    book = F.book.v(bk)
    chapter = F.chapter.v(ch)
    verse = F.verse.v(vs)
    text = ''.join('{}{}'.format(F.g_word_utf8.v(w), F.trailer_utf8.v(w)) for w in L.d('word', vs))
    verse_label = '<td class="vl">{} {}:{}</td>'.format(book, chapter, verse)
    htext = '{}<td class="ht">{}</td>'.format(verse_label, text)
    return '<tr class="ht">{}</tr>'.format(htext)

def verse_clique(ii):
    return '<table class="ht">{}</table>\n'.format(''.join(verse_chunk(i) for i in sorted(ii)))

def condense(vlabels):
    cnd = ''
    (cur_b, cur_c) = (None, None)
    for (b, c, v) in vlabels:
        sep = '' if cur_b == None else '. ' if cur_b != b else '; ' if cur_c != c else ', '
        show_b = b+' ' if cur_b != b else ''
        show_c = c+':' if cur_b != b or cur_c != c else ''
        (cur_b, cur_c) = (b, c)
        cnd += '{}{}{}{}'.format(sep, show_b, show_c, v)
    return cnd

def print_diff(a, b):
    arep = ''
    brep = ''
    for (lb, ai, aj, bi, bj) in SequenceMatcher(isjunk=None, a=a, b=b, autojunk=False).get_opcodes():
        if lb == 'equal':
            arep += a[ai:aj]
            brep += b[bi:bj]
        elif lb == 'delete':
            arep += '<span class="{}">{}</span>'.format(lb, a[ai:aj])
        elif lb == 'insert':
            brep += '<span class="{}">{}</span>'.format(lb, b[bi:bj])
        else:
            arep += '<span class="{}">{}</span>'.format(lb, a[ai:aj])
            brep += '<span class="{}">{}</span>'.format(lb, b[bi:bj])
    return (arep, brep)
    
def print_chunk_fine(prev, text, verse_labels, prevlabels):
    if prev == None:
        return '''
<tr class="ht tb bb"><td class="vl">{}</td><td class="ht">{}</td></tr>
'''.format(
            condense(verse_labels), 
            text,
        )
    else:
        (prevline, textline) = print_diff(prev, text)
        return '''
<tr class="ht tb"><td class="vl">{}</td><td class="ht">{}</td></tr>
<tr class="ht bb"><td class="vl">{}</td><td class="ht">{}</td></tr>
'''.format(
    condense(prevlabels) if prevlabels != None else 'previous',
    prevline,
    condense(verse_labels), 
    textline,
)

def print_chunk_coarse(text, verse_labels):
    return '''
<tr class="ht tb bb"><td class="vl">{}</td><td class="ht">{}</td></tr>
'''.format(
            condense(verse_labels), 
            text,
        )

def print_clique(ii, ncliques):
    return print_clique_fine(ii) if len(ii) < ncliques * DEP_CLIQUE_RATIO / 100 else print_clique_coarse(ii)
    
def print_clique_fine(ii):
    condensed = collections.OrderedDict()
    for i in sorted(ii, key = lambda c: (-len(chunks[c]), c)):
        chunk = chunks[i]
        fword = chunk[0]
        book = F.book.v(L.u('book', fword))
        chapter = F.chapter.v(L.u('chapter', fword))
        verse = F.verse.v(L.u('verse', fword))
        text = ''.join('{}{}'.format(F.g_word_utf8.v(w), F.trailer_utf8.v(w)) for w in chunk)
        condensed.setdefault(text, []).append((book, chapter, verse))
    result = []
    nv = len(condensed.items())
    prev = None
    for (text, verse_labels) in condensed.items():
        if prev == None:
            if nv == 1: result.append(print_chunk_fine(None, text, verse_labels, None))
            else:
                prev = text
                prevlabels = verse_labels
                continue
        else:
            result.append(print_chunk_fine(prev, text, verse_labels, prevlabels))
            prev = text
            prevlabels = None
    return '<table class="ht">{}</table>\n'.format(''.join(result))

def print_clique_coarse(ii):
    condensed = collections.OrderedDict()
    for i in sorted(ii, key = lambda c: (-len(chunks[c]), c))[0:LARGE_CLIQUE_SIZE]:
        chunk = chunks[i]
        fword = chunk[0]
        book = F.book.v(L.u('book', fword))
        chapter = F.chapter.v(L.u('chapter', fword))
        verse = F.verse.v(L.u('verse', fword))
        text = ''.join('{}{}'.format(F.g_word_utf8.v(w), F.trailer_utf8.v(w)) for w in chunk)
        condensed.setdefault(text, []).append((book, chapter, verse))
    result = []
    nv = len(condensed.items())
    prev = None
    for (text, verse_labels) in condensed.items():
        result.append(print_chunk_coarse(text, verse_labels))
    if len(ii) > LARGE_CLIQUE_SIZE:
        result.append(print_chunk_coarse('+ {} ...'.format(len(ii) - LARGE_CLIQUE_SIZE),[]))
    return '<table class="ht">{}</table>\n'.format(''.join(result))

def index_clique(bnm, n, ii, ncliques):
    return index_clique_fine(bnm, n, ii) if len(ii) < ncliques * DEP_CLIQUE_RATIO / 100 else index_clique_coarse(bnm, n, ii)
    
def index_clique_fine(bnm, n, ii):
    verse_labels = []
    for i in sorted(ii, key = lambda c: (-len(chunks[c]), c)):
        chunk = chunks[i]
        fword = chunk[0]
        book = F.book.v(L.u('book', fword))
        chapter = F.chapter.v(L.u('chapter', fword))
        verse = F.verse.v(L.u('verse', fword))
        verse_labels.append((book, chapter, verse))
        reffl = '{}_{}'.format(bnm, n // CLIQUES_PER_FILE)
    return '<p><b>{}</b> <a href="{}.html#c_{}">{}</a></p>'.format(
        n, reffl, n, condense(verse_labels),
    )

def index_clique_coarse(bnm, n, ii):
    verse_labels = []
    for i in sorted(ii, key = lambda c: (-len(chunks[c]), c))[0:LARGE_CLIQUE_SIZE]:
        chunk = chunks[i]
        fword = chunk[0]
        book = F.book.v(L.u('book', fword))
        chapter = F.chapter.v(L.u('chapter', fword))
        verse = F.verse.v(L.u('verse', fword))
        verse_labels.append((book, chapter, verse))
        reffl = '{}_{}'.format(bnm, n // CLIQUES_PER_FILE)
    extra = '+ {} ...'.format(len(ii) - LARGE_CLIQUE_SIZE) if len(ii) > LARGE_CLIQUE_SIZE else ''
    return '<p><b>{}</b> <a href="{}.html#c_{}">{}{}</a></p>'.format(
        n, reffl, n, condense(verse_labels), extra,
    )

def lines_chapter(c):
    lines = []
    for v in L.d('verse', c):
        vl = F.verse.v(v)
        text = ''.join('{}{}'.format(F.g_word_utf8.v(w), F.trailer_utf8.v(w)) for w in L.d('word', v))
        lines.append('{} {}'.format(vl, text.replace('\n', ' ')))
    return lines

def compare_chapters(c1, c2, lb1, lb2):
    dh = difflib.HtmlDiff(wrapcolumn=80)
    table_html = dh.make_table(
        lines_chapter(c1), 
        lines_chapter(c2), 
        fromdesc=lb1, 
        todesc=lb2, 
        context=False, 
        numlines=5,
    )
    htext = '''<html>{}<body>{}</body></html>'''.format(diffhead, table_html)
    return htext

# %% [markdown]
# # Producing output

# %%
def assess_exp(cf, np, nc, ll):
    return 'out' if cf else \
    'rec' if ll > nc * REC_CLIQUE_RATIO / 100 and ll <= nc * DUB_CLIQUE_RATIO / 100 else \
    'dep' if ll > nc * DEP_CLIQUE_RATIO / 100 else \
    'dub' if ll > nc * DUB_CLIQUE_RATIO / 100 else \
    'nor'

def printing():
    global outputs, bin_cliques, base_name
    msg('PRINT ({} {} {} M>{} S>{}): sorting out cliques'.format(
        CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD, SIMILARITY_THRESHOLD,
    ))
    xt_cliques = {xterse_clique(c) for c in cliques}     # chapter cliques as tuples of (b, ch) tuples
    bin_cliques = {c for c in xt_cliques if len(c) == 2} # chapter cliques with exactly two chapters
    # all chapters that occur in binary chapter cliques
    bin_chapters = {c[0] for c in bin_cliques} | {c[1] for c in bin_cliques}
    meta['# BINARY CHAPTER DIFFS'] = len(bin_cliques)

    # We generate one kind of info for binary chapter cliques (the majority of cases).
    # The remaining cases are verse cliques that do not occur in such chapters, e.g. because they
    # have member chunks in the same chapter, or in multiple (more than two) chapters.
    
    ncliques = len(cliques)
    chapters_ok = assess_exp(CHUNK_FIXED, len(passages), ncliques, l_c_l) in {'rec', 'nor', 'dub'}
    cdoing = 'involving' if chapters_ok else 'skipping'

    msg('PRINT ({} {} {} M>{} S>{}): formatting {} cliques {} {} binary chapter diffs'.format(
        CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD, SIMILARITY_THRESHOLD,
        ncliques, cdoing, len(bin_cliques),
    ))
    meta_html = '\n'.join('{:<40} : {:>10}'.format(k, str(meta[k])) for k in meta)

    base_name = '{}_{}_{}_M{}_S{}'.format(
        CHUNK_LB,
        CHUNK_DESC,
        SIMILARITY_METHOD,
        MATRIX_THRESHOLD,
        SIMILARITY_THRESHOLD, 
    )
    param_spec = '''
<table>
<tr><th>chunking method</th><td>{}</td></tr>
<tr><th>chunking description</th><td>{}</td></tr>
<tr><th>similarity method</th><td>{}</td></tr>
<tr><th>similarity threshold</th><td>{}</td></tr>
</table>
    '''.format(
        CHUNK_LABELS[CHUNK_FIXED],
        CHUNK_DESC,
        SIMILARITY_METHOD, 
        SIMILARITY_THRESHOLD, 
    )
    param_lab = 'chunk-{}-{}-sim-{}-m{}-s{}'.format(
        CHUNK_LB,
        CHUNK_DESC,
        SIMILARITY_METHOD,
        MATRIX_THRESHOLD,
        SIMILARITY_THRESHOLD, 
    )
    index_name = base_name
    all_name = '{}_{}'.format('all', base_name)
    cliques_name = '{}_{}'.format('clique', base_name)

    clique_links = []
    clique_links.append(('{}/{}.html'.format(base_name, all_name), 'Big list of all cliques'))

    nexist = 0
    nnew = 0
    if chapters_ok:
        chapter_diffs = []
        msg('PRINT ({} {} {} M>{} S>{}): Chapter diffs needed: {}'.format(
            CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD, SIMILARITY_THRESHOLD,
            len(bin_cliques),
        ))

        bcc_text = '<p>These results look good, so a binary chapter comparison has been generated</p>'
        for cl in sorted(bin_cliques):
            lb1 = '{} {}'.format(F.book.v(cl[0][0]), F.chapter.v(cl[0][1]))
            lb2 = '{} {}'.format(F.book.v(cl[1][0]), F.chapter.v(cl[1][1]))
            hfilename = '{}_vs_{}.html'.format(lb1, lb2).replace(' ','_')
            hfilepath = '{}/{}/{}'.format(LOCAL_BASE_OUTP, CHAPTER_DIR, hfilename)
            chapter_diffs.append((lb1, cl[0][1], lb2, cl[1][1], '{}/{}/{}/{}'.format(
                SHEBANQ_TOOL, LOCAL_BASE_OUTP, CHAPTER_DIR, hfilename,
            )))
            if not os.path.exists(hfilepath):
                htext = compare_chapters(cl[0][1], cl[1][1], lb1, lb2)
                with open(hfilepath, 'w') as f: f.write(htext)
                if VERBOSE:
                    msg('PRINT ({} {} {} M>{} S>{}): written {}'.format(
                        CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD, SIMILARITY_THRESHOLD,
                        hfilename,
                    ))
                nnew += 1
            else:
                nexist += 1
            clique_links.append((
                '../{}/{}'.format(CHAPTER_DIR, hfilename), 
                '{} versus {}'.format(lb1, lb2),
            ))
        msg('PRINT ({} {} {} M>{} S>{}): Chapter diffs: {} newly created and {} already existing'.format(
            CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD, SIMILARITY_THRESHOLD,
            nnew, nexist,
        ))
    else:
        bcc_text = '<p>These results look dubious at best, so no binary chapter comparison has been generated</p>'


    allgeni_html = (index_clique(cliques_name, i, c, ncliques) for (i,c) in enumerate(cliques))
    
    allgen_htmls = []
    allgen_html = ''
    
    for (i, c) in enumerate(cliques):
        if i % CLIQUES_PER_FILE == 0:
            if i > 0:
                allgen_htmls.append(allgen_html)
            allgen_html = ''
        allgen_html += '<h3><a name="c_{}">Clique {}</a></h3>\n{}'.format(i, i, print_clique(c, ncliques))
    allgen_htmls.append(allgen_html)

    index_html_tpl = '''
{}
<h1>Binary chapter comparisons</h1>
{}
{}
    '''

    content_file_tpl = '''<html>
<head>
<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
<title>{}</title>
<style type="text/css">
{}
</style>
</head>
<body>
<h1>{}</h1>
{}
<p><a href="#meta">more parameters and stats</a></p>
{}
<h1><a name="meta">Parameters and stats</a></h1>
<pre>{}</pre>
</body>
</html>'''
    
    a_tpl_file = '<p><a target="_blank" href="{}">{}</a></p>'

    index_html_file = index_html_tpl.format(
        a_tpl_file.format(*clique_links[0]),
        bcc_text,
        '\n'.join(a_tpl_file.format(*c) for c in clique_links[1:]),
    )

    listing_html = '{}\n'.format(
        '\n'.join(allgeni_html),
    )

    for (subdir, fname, content_html, tit) in (
        (None, index_name, index_html_file, 'Index '+param_lab),
        (base_name, all_name, listing_html, 'Listing '+param_lab),
        (base_name, cliques_name, allgen_htmls, 'Cliques '+param_lab),
    ): 
        subdir = '' if subdir == None else (subdir + '/')
        subdirabs = '{}/{}/{}'.format(LOCAL_BASE_OUTP, EXPERIMENT_DIR, subdir)
        if not os.path.exists(subdirabs): os.makedirs(subdirabs)

        if type(content_html) is list:
            for (i, c_h) in enumerate(content_html):
                fn = '{}_{}'.format(fname, i)
                t = '{}_{}'.format(tit, i)
                with open('{}/{}/{}{}.html'.format(LOCAL_BASE_OUTP, EXPERIMENT_DIR, subdir, fn), 'w') as f: 
                    f.write(content_file_tpl.format(t, css, t, param_spec, c_h, meta_html))
        else:
            with open('{}/{}/{}{}.html'.format(LOCAL_BASE_OUTP, EXPERIMENT_DIR, subdir, fname), 'w') as f: 
                f.write(content_file_tpl.format(tit, css, tit, param_spec, content_html, meta_html))
    destination = outputs.setdefault(MATRIX_THRESHOLD, {})
    destination[(CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, SIMILARITY_THRESHOLD)] = (
        len(passages), len(cliques), l_c_l,
    )
    msg('PRINT ({} {} {} M>{} S>{}): formatted {} cliques ({} files) {} {} binary chapter diffs'.format(
        CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, MATRIX_THRESHOLD, SIMILARITY_THRESHOLD,
        len(cliques), len(allgen_htmls), cdoing, len(bin_cliques)
    ))

# %% [markdown]
# # Defining experiments

# %%
outputs = {}

def writeoutputs():
    global outputs
    with open(EXPERIMENT_PATH, 'wb') as f:
        pickle.dump(outputs, f, protocol=PICKLE_PROTOCOL)

def readoutputs():
    global outputs
    if not os.path.exists(EXPERIMENT_PATH):
        outputs = {}
    else:
        with open(EXPERIMENT_PATH, 'rb') as f:
            outputs = pickle.load(f)

ecss = '''
<style type="text/css">
.mis {background-color: #cccccc;}
.rec {background-color: #aaffaa;}
.dep {background-color: #ffaaaa;}
.dub {background-color: #ffddaa;}
.out {background-color: #ffddff;}
.nor {background-color: #fcfcff;}
.ps  {font-weight: normal;}
.mx  {font-style: italic;}
.cl  {font-weight: bold;}
.lr  {font-weight: bold; background-color: #ffffaa;}
p,td {font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; font-size: small;}
td   {border: 1pt solid #000000; padding: 4pt;}
table {border: 1pt solid #000000; border-collapse: collapse;}
</style>
'''

legend = '''
<table>
<tr><td class="mis">{mis}</td></tr>
<tr><td class="rec">{rec}</td></tr>
<tr><td class="dep">{dep}</td></tr>
<tr><td class="dub">{dub}</td></tr>
<tr><td class="out">{out}</td></tr>
<tr><td class="nor">{nor}</td></tr>
</table>
'''.format(**VALUE_LABELS)

def gen_html(standalone=False):
    global other_exps
    msg('EXPERIMENT: Generating html report{}'.format('(standalone)' if standalone else ''))
    stats = collections.Counter()
    pre = '''
<html>
<head>
<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
{}
</head>
<body>
'''.format(ecss) if standalone else ''
    
    post = '''
</body></html>
''' if standalone else ''

    experiments = '''
{}
{}
<table>
<tr><th>chunk type</th><th>chunk size</th><th>similarity method</th>{}</tr>
'''.format(pre, legend, ''.join('<th>{}</th>'.format(sim_thr) for sim_thr in SIMILARITIES))
    
    for chunk_f in (True, False):
        if chunk_f:
            chunk_items = CHUNK_SIZES
        else:
            chunk_items = CHUNK_OBJECTS
        chunk_lb = CHUNK_LBS[chunk_f]
        for chunk_i in chunk_items:
            for sim_m in SIM_METHODS:
                set_matrix_threshold(sim_m=sim_m)
                these_outputs = outputs.get(MATRIX_THRESHOLD, {})
                experiments += '<tr><td>{}</td><td>{}</td><td>{}</td>'.format(
                    CHUNK_LABELS[chunk_f], chunk_i, sim_m,
                )
                for sim_thr in SIMILARITIES:
                    okey = (chunk_lb, chunk_i, sim_m, sim_thr)
                    values = these_outputs.get(okey)
                    if values == None:
                        result = '<td class="mis">&nbsp;</td>'
                        stats['mis'] += 1
                    else:
                        (npassages, ncliques, longest_clique_len) = values
                        cls = assess_exp(chunk_f, npassages, ncliques, longest_clique_len)
                        stats[cls] += 1
                        (lr_el, lr_lb) = ('', '')
                        if (CHUNK_LB, CHUNK_DESC, SIMILARITY_METHOD, SIMILARITY_THRESHOLD) == (
                            chunk_lb, chunk_i, sim_m, sim_thr,
                        ):
                            lr_el = '<span class="lr">*</span>'
                            lr_lb = VALUE_LABELS['lr']
                        result = '''
<td class="{}" title="{}">{}
    <span class="ps">{}</span><br/>
    <a target="_blank" href="{}{}/{}_{}_{}_M{}_S{}.html"><span class="cl">{}</span></a><br/>
    <span class="mx">{}</span>
    </td>'''.format(
        cls, lr_lb, lr_el, npassages,
        '' if standalone else LOCAL_BASE_OUTP+'/', 
        EXPERIMENT_DIR, chunk_lb, chunk_i, sim_m, MATRIX_THRESHOLD, sim_thr,
        ncliques, longest_clique_len,
    )
                    experiments += result
                experiments += '</tr>\n'
    experiments += '</table>\n{}'.format(post)
    if standalone:
        with open(EXPERIMENT_HTML, 'w') as f:
            f.write(experiments)
    else:
        other_exps = experiments

    for stat in sorted(stats):
        msg('EXPERIMENT: {:>3} {}'.format(stats[stat], VALUE_LABELS[stat]))
    msg("EXPERIMENT: Generated html report")

def do_experiment(chunk_f, chunk_i, sim_m, sim_thr, do_index):
    if do_index:
        readoutputs()
    (do_chunk, do_prep, do_sim, do_clique) = do_params(chunk_f, chunk_i, sim_m, sim_thr)
    chunking(do_chunk)
    preparing(do_prep)
    similarity(do_sim)
    cliqueing(do_clique)
    printing()
    if do_index:
        writeoutputs()
        gen_html()
    
def reset_experiments():
    global outputs
    readoutputs()
    outputs = {}
    reset_params()
    writeoutputs()
    gen_html()

def do_all_experiments():
    global outputs
    reset_experiments()
    for chunk_f in (True, False):
        if chunk_f:
            chunk_items = CHUNK_SIZES
        else:
            chunk_items = CHUNK_OBJECTS
        for chunk_i in chunk_items:
            for sim_m in SIM_METHODS:
                for sim_thr in SIMILARITIES:
                    do_experiment(chunk_f, chunk_i, sim_m, sim_thr, False)
    writeoutputs()
    gen_html()
    gen_html(standalone=True)
    
def show_all_experiments():
    readoutputs()
    gen_html()
    gen_html(standalone=True)

# %% [markdown]
# # SHEBANQ references
#
# Based on selected similarity matrices, we produce a SHEBANQ note set of cross references for similar passages.

# %%
def get_verse(i, ca=False): return get_verse_w(chunks[i][0], ca=ca)

def get_verse_o(o, ca=False): return get_verse_w(L.d('word', o)[0], ca=ca)

def get_verse_w(w, ca=False):
    book = F.book.v(L.u('book', w))
    chapter = F.chapter.v(L.u('chapter', w))
    verse = F.verse.v(L.u('verse', w))
    if ca: ca = F.number.v(L.u('clause_atom', w))
    return (book, chapter, verse, ca) if ca else (book, chapter, verse)

def key_verse(x):
    return  (book_rank[x[0]], int(x[1]), int(x[2]))

MAX_REFS = 10

def condensex(vlabels):
    cnd = []
    (cur_b, cur_c) = (None, None)
    for (b, c, v, d) in vlabels:
        sep = '' if cur_b == None else '. ' if cur_b != b else '; ' if cur_c != c else ', '
        show_b = b+' ' if cur_b != b else ''
        show_c = c+':' if cur_b != b or cur_c != c else ''
        (cur_b, cur_c) = (b, c)
        cnd.append('{}{}{}{}{}'.format(sep, show_b, show_c, v, d))
    return cnd

dfields = '''
    book1
    chapter1
    verse1
    book2
    chapter2
    verse2
    similarity
'''.strip().split()

dfields_fmt = ('{}\t' * (len(dfields) - 1)) + '{}\n' 

def get_crossrefs():
    global crossrefs
    msg('CROSSREFS: Fetching crossrefs')
    crossrefs_proto = {}
    crossrefs = {}
    (chunk_f, chunk_i, sim_m) = SHEBANQ_MATRIX
    sim_thr = SHEBANQ_SIMILARITY
    msg('CROSSREFS ({} {} {} S>{})'.format(CHUNK_LBS[chunk_f], chunk_i, sim_m, sim_thr))
    (do_chunk, do_prep, do_sim, do_clique) = do_params(chunk_f, chunk_i, sim_m, sim_thr)
    crossrefs_proto = {x for x in chunk_dist.items() if x[1] >= sim_thr}
    msg('CROSSREFS ({} {} {} S>{}): found {} pairs'.format(
        CHUNK_LBS[chunk_f], chunk_i, sim_m, sim_thr,
        len(crossrefs_proto),
    ))
    f = open(CROSSREF_DB_PATH, 'w')
    f.write('{}\n'.format('\t'.join(dfields)))        
    for ((x,y), d) in crossrefs_proto:
        vx = get_verse(x)
        vy = get_verse(y)
        rd = int(round(d))
        crossrefs.setdefault(x, {})[vy] = rd
        crossrefs.setdefault(y, {})[vx] = rd
        f.write(dfields_fmt.format(*(vx+vy+(rd,))))
    total = sum(len(x) for x in crossrefs.values())
    f.close()
    msg('CROSSREFS: Found {} crossreferences and wrote {} pairs'.format(total, len(crossrefs_proto)))

def compile_refs():
    global refs_compiled
    refs_grouped = []
    for x in sorted(crossrefs):
        refs = crossrefs[x]
        vys = sorted(refs.keys(), key=key_verse)
        currefs = []
        for vy in vys:
            nr = len(currefs)
            if nr == MAX_REFS:
                refs_grouped.append((x, tuple(currefs)))
                currefs = []            
            currefs.append(vy)
        if len(currefs):
            refs_grouped.append((x, tuple(currefs)))
    refs_compiled = []
    for (x, vys) in refs_grouped:
        vysd = [(vy[0], vy[1], vy[2], ' ~{}%'.format(crossrefs[x][vy])) for vy in vys]
        vysl = condensex(vysd)
        these_refs = []
        for (i, vy) in enumerate(vysd):
            link_text = vysl[i]
            link_target = '{} {}:{}'.format(vy[0], vy[1], vy[2])
            these_refs.append('[{}]({})'.format(link_text, link_target))
        refs_compiled.append((x, ' '.join(these_refs)))
    msg('CROSSREFS: Compiled cross references into {} notes'.format(len(refs_compiled)))

def get_chapter_diffs():
    global chapter_diffs
    chapter_diffs = []
    for cl in sorted(bin_cliques):
        lb1 = '{} {}'.format(F.book.v(cl[0][0]), F.chapter.v(cl[0][1]))
        lb2 = '{} {}'.format(F.book.v(cl[1][0]), F.chapter.v(cl[1][1]))
        hfilename = '{}_vs_{}.html'.format(lb1, lb2).replace(' ','_')
        chapter_diffs.append((lb1, cl[0][1], lb2, cl[1][1], '{}/{}/{}/{}'.format(
            SHEBANQ_TOOL, LOCAL_BASE_OUTP, CHAPTER_DIR, hfilename,
        )))
    msg('CROSSREFS: Added {} chapter diffs'.format(2*len(chapter_diffs)))

        
def get_clique_refs():
    global clique_refs
    clique_refs = []
    for (i, c) in enumerate(cliques):
        for j in c:
            seq = i // CLIQUES_PER_FILE
            clique_refs.append((j, i, '{}/{}/{}/{}/clique_{}_{}.html#c_{}'.format(
                SHEBANQ_TOOL, LOCAL_BASE_OUTP, EXPERIMENT_DIR, base_name, base_name, seq, i,
            )))
    msg('CROSSREFS: Added {} clique references'.format(len(clique_refs)))

sfields = '''
    version
    book
    chapter
    verse
    clause_atom
    is_shared
    is_published
    status
    keywords
    ntext
'''.strip().split()

sfields_fmt = ('{}\t' * (len(sfields) - 1)) + '{}\n' 

def generate_notes():
    with open(NOTES_PATH, 'w') as f:
        f.write('{}\n'.format('\t'.join(sfields)))        
        x = next(F.otype.s('word'))
        (bk, ch, vs, ca) = get_verse(x, ca=True)
        f.write(sfields_fmt.format(
            version,
            bk,
            ch,
            vs,
            ca,
            'T',
            '',
            CROSSREF_STATUS,
            CROSSREF_KEYWORD,
            '''The crossref notes are the result of a computation without manual tweaks.
Parameters: chunk by verse, similarity method SET with threshold 65.
[Here](tool=parallel) is an account of the generation method.'''.replace('\n', ' ')
        ))
        for (lb1, ch1, lb2, ch2, fl) in chapter_diffs:
            (bk1, ch1, vs1, ca1) = get_verse_o(ch1, ca=True)
            (bk2, ch2, vs2, ca2) = get_verse_o(ch2, ca=True)
            f.write(sfields_fmt.format(
                version,
                bk1,
                ch1,
                vs1,
                ca1,
                'T',
                '',
                CROSSREF_STATUS,
                CROSSREF_KEYWORD,
                '[chapter diff with {}](tool:{})'.format(lb2, fl),
            ))
            f.write(sfields_fmt.format(
                version,
                bk2,
                ch2,
                vs2,
                ca2,
                'T',
                '',
                CROSSREF_STATUS,
                CROSSREF_KEYWORD,
                '[chapter diff with {}](tool:{})'.format(lb1, fl),
            ))
        for (x, refs) in refs_compiled:
            (bk, ch, vs, ca) = get_verse(x, ca=True)
            f.write(sfields_fmt.format(
                version,
                bk,
                ch,
                vs,
                ca,
                'T',
                '',
                CROSSREF_STATUS,
                CROSSREF_KEYWORD,
                refs,
            ))
        for (chunk, clique, fl) in clique_refs:
            (bk, ch, vs, ca) = get_verse(chunk, ca=True)
            f.write(sfields_fmt.format(
                version,
                bk,
                ch,
                vs,
                ca,
                'T',
                '',
                CROSSREF_STATUS,
                CROSSREF_KEYWORD,
                '[all variants (clique {})](tool:{})'.format(clique, fl),
            ))

    msg('CROSSREFS: Generated {} notes'.format(1+len(refs_compiled) + 2 * len(chapter_diffs) + len(clique_refs)))

def crossrefs2shebanq():
    expr = SHEBANQ_MATRIX + (SHEBANQ_SIMILARITY,)
    do_experiment(*(expr+(True,)))
    get_crossrefs()
    compile_refs()
    get_chapter_diffs()
    get_clique_refs()
    generate_notes()

# %% [markdown]
# # Performing experiments

# %%
reset_params()
#do_experiment(False, 'sentence', 'LCS', 60, False)
do_all_experiments()
crossrefs2shebanq()
show_all_experiments()
# Out:
#  1m 24s EXPERIMENT: Generating html report
#  1m 24s EXPERIMENT: 126 no results available
#  1m 24s EXPERIMENT: Generated html report
#  1m 24s CHUNKING (F 100)
#  1m 25s CHUNKING (F 100): Made 4244 chunks
#  1m 25s PREPARING (F 100 SET)
#  1m 26s PREPARING (F 100 SET): Done 4244 chunks.
#  1m 26s SIMILARITY (F 100 SET M>50): Computing  9003 K (9003646) comparisons and saving entries in matrix
#  1m 26s SIMILARITY (F 100 SET M>50): Computed    90 K comparisons and saved 1 entries in matrix
#  1m 27s SIMILARITY (F 100 SET M>50): Computed   180 K comparisons and saved 3 entries in matrix
#  1m 27s SIMILARITY (F 100 SET M>50): Computed   270 K comparisons and saved 4 entries in matrix
#  1m 28s SIMILARITY (F 100 SET M>50): Computed   360 K comparisons and saved 4 entries in matrix
#  1m 29s SIMILARITY (F 100 SET M>50): Computed   450 K comparisons and saved 4 entries in matrix
#  1m 29s SIMILARITY (F 100 SET M>50): Computed   540 K comparisons and saved 4 entries in matrix
#  1m 30s SIMILARITY (F 100 SET M>50): Computed   630 K comparisons and saved 4 entries in matrix
#  1m 31s SIMILARITY (F 100 SET M>50): Computed   720 K comparisons and saved 4 entries in matrix
#  1m 31s SIMILARITY (F 100 SET M>50): Computed   810 K comparisons and saved 4 entries in matrix
#  1m 32s SIMILARITY (F 100 SET M>50): Computed   900 K comparisons and saved 7 entries in matrix
#  1m 32s SIMILARITY (F 100 SET M>50): Computed   990 K comparisons and saved 9 entries in matrix
#  1m 33s SIMILARITY (F 100 SET M>50): Computed  1080 K comparisons and saved 9 entries in matrix
#  1m 33s SIMILARITY (F 100 SET M>50): Computed  1170 K comparisons and saved 10 entries in matrix
#  1m 34s SIMILARITY (F 100 SET M>50): Computed  1260 K comparisons and saved 10 entries in matrix
#  1m 34s SIMILARITY (F 100 SET M>50): Computed  1350 K comparisons and saved 11 entries in matrix
#  1m 35s SIMILARITY (F 100 SET M>50): Computed  1440 K comparisons and saved 11 entries in matrix
#  1m 35s SIMILARITY (F 100 SET M>50): Computed  1530 K comparisons and saved 12 entries in matrix
#  1m 36s SIMILARITY (F 100 SET M>50): Computed  1620 K comparisons and saved 14 entries in matrix
#  1m 36s SIMILARITY (F 100 SET M>50): Computed  1710 K comparisons and saved 20 entries in matrix
#  1m 37s SIMILARITY (F 100 SET M>50): Computed  1800 K comparisons and saved 40 entries in matrix
#  1m 37s SIMILARITY (F 100 SET M>50): Computed  1890 K comparisons and saved 44 entries in matrix
#  1m 38s SIMILARITY (F 100 SET M>50): Computed  1980 K comparisons and saved 45 entries in matrix
#  1m 38s SIMILARITY (F 100 SET M>50): Computed  2070 K comparisons and saved 45 entries in matrix
#  1m 39s SIMILARITY (F 100 SET M>50): Computed  2160 K comparisons and saved 53 entries in matrix
#  1m 39s SIMILARITY (F 100 SET M>50): Computed  2250 K comparisons and saved 54 entries in matrix
#  1m 40s SIMILARITY (F 100 SET M>50): Computed  2340 K comparisons and saved 63 entries in matrix
#  1m 40s SIMILARITY (F 100 SET M>50): Computed  2430 K comparisons and saved 73 entries in matrix
#  1m 41s SIMILARITY (F 100 SET M>50): Computed  2521 K comparisons and saved 73 entries in matrix
#  1m 41s SIMILARITY (F 100 SET M>50): Computed  2611 K comparisons and saved 78 entries in matrix
#  1m 42s SIMILARITY (F 100 SET M>50): Computed  2701 K comparisons and saved 79 entries in matrix
#  1m 42s SIMILARITY (F 100 SET M>50): Computed  2791 K comparisons and saved 91 entries in matrix
#  1m 43s SIMILARITY (F 100 SET M>50): Computed  2881 K comparisons and saved 134 entries in matrix
#  1m 43s SIMILARITY (F 100 SET M>50): Computed  2971 K comparisons and saved 141 entries in matrix
#  1m 44s SIMILARITY (F 100 SET M>50): Computed  3061 K comparisons and saved 142 entries in matrix
#  1m 45s SIMILARITY (F 100 SET M>50): Computed  3151 K comparisons and saved 143 entries in matrix
#  1m 45s SIMILARITY (F 100 SET M>50): Computed  3241 K comparisons and saved 144 entries in matrix
#  1m 46s SIMILARITY (F 100 SET M>50): Computed  3331 K comparisons and saved 164 entries in matrix
#  1m 46s SIMILARITY (F 100 SET M>50): Computed  3421 K comparisons and saved 178 entries in matrix
#  1m 47s SIMILARITY (F 100 SET M>50): Computed  3511 K comparisons and saved 179 entries in matrix
#  1m 47s SIMILARITY (F 100 SET M>50): Computed  3601 K comparisons and saved 180 entries in matrix
#  1m 48s SIMILARITY (F 100 SET M>50): Computed  3691 K comparisons and saved 180 entries in matrix
#  1m 49s SIMILARITY (F 100 SET M>50): Computed  3781 K comparisons and saved 180 entries in matrix
#  1m 49s SIMILARITY (F 100 SET M>50): Computed  3871 K comparisons and saved 180 entries in matrix
#  1m 50s SIMILARITY (F 100 SET M>50): Computed  3961 K comparisons and saved 181 entries in matrix
#  1m 50s SIMILARITY (F 100 SET M>50): Computed  4051 K comparisons and saved 181 entries in matrix
#  1m 51s SIMILARITY (F 100 SET M>50): Computed  4141 K comparisons and saved 181 entries in matrix
#  1m 51s SIMILARITY (F 100 SET M>50): Computed  4231 K comparisons and saved 182 entries in matrix
#  1m 52s SIMILARITY (F 100 SET M>50): Computed  4321 K comparisons and saved 182 entries in matrix
#  1m 52s SIMILARITY (F 100 SET M>50): Computed  4411 K comparisons and saved 186 entries in matrix
#  1m 53s SIMILARITY (F 100 SET M>50): Computed  4501 K comparisons and saved 187 entries in matrix
#  1m 54s SIMILARITY (F 100 SET M>50): Computed  4591 K comparisons and saved 188 entries in matrix
#  1m 54s SIMILARITY (F 100 SET M>50): Computed  4681 K comparisons and saved 188 entries in matrix
#  1m 55s SIMILARITY (F 100 SET M>50): Computed  4771 K comparisons and saved 188 entries in matrix
#  1m 55s SIMILARITY (F 100 SET M>50): Computed  4861 K comparisons and saved 188 entries in matrix
#  1m 56s SIMILARITY (F 100 SET M>50): Computed  4951 K comparisons and saved 188 entries in matrix
#  1m 57s SIMILARITY (F 100 SET M>50): Computed  5042 K comparisons and saved 188 entries in matrix
#  1m 57s SIMILARITY (F 100 SET M>50): Computed  5132 K comparisons and saved 188 entries in matrix
#  1m 58s SIMILARITY (F 100 SET M>50): Computed  5222 K comparisons and saved 188 entries in matrix
#  1m 59s SIMILARITY (F 100 SET M>50): Computed  5312 K comparisons and saved 188 entries in matrix
#  1m 59s SIMILARITY (F 100 SET M>50): Computed  5402 K comparisons and saved 188 entries in matrix
#  2m 00s SIMILARITY (F 100 SET M>50): Computed  5492 K comparisons and saved 188 entries in matrix
#  2m 00s SIMILARITY (F 100 SET M>50): Computed  5582 K comparisons and saved 190 entries in matrix
#  2m 01s SIMILARITY (F 100 SET M>50): Computed  5672 K comparisons and saved 202 entries in matrix
#  2m 01s SIMILARITY (F 100 SET M>50): Computed  5762 K comparisons and saved 202 entries in matrix
#  2m 02s SIMILARITY (F 100 SET M>50): Computed  5852 K comparisons and saved 202 entries in matrix
#  2m 02s SIMILARITY (F 100 SET M>50): Computed  5942 K comparisons and saved 212 entries in matrix
#  2m 03s SIMILARITY (F 100 SET M>50): Computed  6032 K comparisons and saved 212 entries in matrix
#  2m 04s SIMILARITY (F 100 SET M>50): Computed  6122 K comparisons and saved 238 entries in matrix
#  2m 04s SIMILARITY (F 100 SET M>50): Computed  6212 K comparisons and saved 252 entries in matrix
#  2m 05s SIMILARITY (F 100 SET M>50): Computed  6302 K comparisons and saved 256 entries in matrix
#  2m 05s SIMILARITY (F 100 SET M>50): Computed  6392 K comparisons and saved 267 entries in matrix
#  2m 06s SIMILARITY (F 100 SET M>50): Computed  6482 K comparisons and saved 268 entries in matrix
#  2m 07s SIMILARITY (F 100 SET M>50): Computed  6572 K comparisons and saved 284 entries in matrix
#  2m 08s SIMILARITY (F 100 SET M>50): Computed  6662 K comparisons and saved 299 entries in matrix
#  2m 09s SIMILARITY (F 100 SET M>50): Computed  6752 K comparisons and saved 320 entries in matrix
#  2m 10s SIMILARITY (F 100 SET M>50): Computed  6842 K comparisons and saved 320 entries in matrix
#  2m 10s SIMILARITY (F 100 SET M>50): Computed  6932 K comparisons and saved 320 entries in matrix
#  2m 11s SIMILARITY (F 100 SET M>50): Computed  7022 K comparisons and saved 320 entries in matrix
#  2m 12s SIMILARITY (F 100 SET M>50): Computed  7112 K comparisons and saved 320 entries in matrix
#  2m 12s SIMILARITY (F 100 SET M>50): Computed  7202 K comparisons and saved 320 entries in matrix
#  2m 13s SIMILARITY (F 100 SET M>50): Computed  7292 K comparisons and saved 322 entries in matrix
#  2m 13s SIMILARITY (F 100 SET M>50): Computed  7382 K comparisons and saved 322 entries in matrix
#  2m 14s SIMILARITY (F 100 SET M>50): Computed  7472 K comparisons and saved 323 entries in matrix
#  2m 14s SIMILARITY (F 100 SET M>50): Computed  7563 K comparisons and saved 325 entries in matrix
#  2m 15s SIMILARITY (F 100 SET M>50): Computed  7653 K comparisons and saved 327 entries in matrix
#  2m 16s SIMILARITY (F 100 SET M>50): Computed  7743 K comparisons and saved 328 entries in matrix
#  2m 16s SIMILARITY (F 100 SET M>50): Computed  7833 K comparisons and saved 330 entries in matrix
#  2m 17s SIMILARITY (F 100 SET M>50): Computed  7923 K comparisons and saved 336 entries in matrix
#  2m 17s SIMILARITY (F 100 SET M>50): Computed  8013 K comparisons and saved 338 entries in matrix
#  2m 18s SIMILARITY (F 100 SET M>50): Computed  8103 K comparisons and saved 345 entries in matrix
#  2m 19s SIMILARITY (F 100 SET M>50): Computed  8193 K comparisons and saved 345 entries in matrix
#  2m 19s SIMILARITY (F 100 SET M>50): Computed  8283 K comparisons and saved 346 entries in matrix
#  2m 20s SIMILARITY (F 100 SET M>50): Computed  8373 K comparisons and saved 346 entries in matrix
#  2m 21s SIMILARITY (F 100 SET M>50): Computed  8463 K comparisons and saved 346 entries in matrix
#  2m 21s SIMILARITY (F 100 SET M>50): Computed  8553 K comparisons and saved 349 entries in matrix
#  2m 22s SIMILARITY (F 100 SET M>50): Computed  8643 K comparisons and saved 350 entries in matrix
#  2m 22s SIMILARITY (F 100 SET M>50): Computed  8733 K comparisons and saved 350 entries in matrix
#  2m 23s SIMILARITY (F 100 SET M>50): Computed  8823 K comparisons and saved 351 entries in matrix
#  2m 23s SIMILARITY (F 100 SET M>50): Computed  8913 K comparisons and saved 358 entries in matrix
#  2m 24s SIMILARITY (F 100 SET M>50): Computed  9003 K comparisons and saved 359 entries in matrix
#  2m 24s SIMILARITY (F 100 SET M>50): Computed  9003 K (9003646) comparisons and saved 359 entries in matrix
#  2m 24s SIMILARITY (F 100 SET M>50): similarities between 50.0 and 100.0. 1 are 100%
#  2m 24s CLIQUES (F 100 SET M>50 S>100): fetching similars and chunk candidates
#  2m 24s CLIQUES (F 100 SET M>50 S>100): inspecting the similarity matrix
#  2m 24s CLIQUES (F 100 SET M>50 S>100): 1 relevant similarities between 2 passages
#  2m 24s CLIQUES (F 100 SET M>50 S>100): Composing cliques out of      2 chunks from 1 comparisons
#  2m 24s CLIQUES (F 100 SET M>50 S>100): 2 members in 1 cliques
#  2m 24s CLIQUES (F 100 SET M>50 S>100): Composed and saved     1 cliques out of      2 chunks from 1 comparisons
#  2m 24s PRINT (F 100 SET M>50 S>100): sorting out cliques
#  2m 24s PRINT (F 100 SET M>50 S>100): formatting 1 cliques skipping 1 binary chapter diffs
#  2m 24s PRINT (F 100 SET M>50 S>100): formatted 1 cliques (1 files) skipping 1 binary chapter diffs
#  2m 24s CHUNKING (F 100): already chunked into 4244 chunks
#  2m 24s PREPARING (F 100 SET): Already prepared
#  2m 24s SIMILARITY (F 100 SET M>50): Using  9003 K (9003646) comparisons with 359 entries in matrix
#  2m 24s SIMILARITY (F 100 SET M>50): similarities between 50.0 and 100.0. 1 are 100%
#  2m 24s CLIQUES (F 100 SET M>50 S>95): fetching similars and chunk candidates
#  2m 24s CLIQUES (F 100 SET M>50 S>95): inspecting the similarity matrix
#  2m 24s CLIQUES (F 100 SET M>50 S>95): 2 relevant similarities between 4 passages
#  2m 24s CLIQUES (F 100 SET M>50 S>95): Composing cliques out of      4 chunks from 2 comparisons
#  2m 24s CLIQUES (F 100 SET M>50 S>95): 4 members in 2 cliques
#  2m 24s CLIQUES (F 100 SET M>50 S>95): Composed and saved     2 cliques out of      4 chunks from 2 comparisons
#  2m 24s PRINT (F 100 SET M>50 S>95): sorting out cliques
#  2m 24s PRINT (F 100 SET M>50 S>95): formatting 2 cliques skipping 2 binary chapter diffs
#  2m 24s PRINT (F 100 SET M>50 S>95): formatted 2 cliques (1 files) skipping 2 binary chapter diffs
#  2m 24s CHUNKING (F 100): already chunked into 4244 chunks
#  2m 24s PREPARING (F 100 SET): Already prepared
#  2m 24s SIMILARITY (F 100 SET M>50): Using  9003 K (9003646) comparisons with 359 entries in matrix
#  2m 24s SIMILARITY (F 100 SET M>50): similarities between 50.0 and 100.0. 1 are 100%
#  2m 24s CLIQUES (F 100 SET M>50 S>90): fetching similars and chunk candidates
#  2m 24s CLIQUES (F 100 SET M>50 S>90): inspecting the similarity matrix
#  2m 24s CLIQUES (F 100 SET M>50 S>90): 9 relevant similarities between 18 passages
#  2m 24s CLIQUES (F 100 SET M>50 S>90): Composing cliques out of     18 chunks from 9 comparisons
#  2m 24s CLIQUES (F 100 SET M>50 S>90): 18 members in 9 cliques
#  2m 24s CLIQUES (F 100 SET M>50 S>90): Composed and saved     9 cliques out of     18 chunks from 9 comparisons
#  2m 24s PRINT (F 100 SET M>50 S>90): sorting out cliques
#  2m 24s PRINT (F 100 SET M>50 S>90): formatting 9 cliques skipping 3 binary chapter diffs
#  2m 24s PRINT (F 100 SET M>50 S>90): formatted 9 cliques (1 files) skipping 3 binary chapter diffs
#  2m 24s CHUNKING (F 100): already chunked into 4244 chunks
#  2m 24s PREPARING (F 100 SET): Already prepared
#  2m 24s SIMILARITY (F 100 SET M>50): Using  9003 K (9003646) comparisons with 359 entries in matrix
#  2m 24s SIMILARITY (F 100 SET M>50): similarities between 50.0 and 100.0. 1 are 100%
#  2m 24s CLIQUES (F 100 SET M>50 S>85): fetching similars and chunk candidates
#  2m 24s CLIQUES (F 100 SET M>50 S>85): inspecting the similarity matrix
#  2m 24s CLIQUES (F 100 SET M>50 S>85): 19 relevant similarities between 37 passages
#  2m 24s CLIQUES (F 100 SET M>50 S>85): Composing cliques out of     37 chunks from 19 comparisons
#  2m 24s CLIQUES (F 100 SET M>50 S>85): 37 members in 18 cliques
#  2m 24s CLIQUES (F 100 SET M>50 S>85): Composed and saved    18 cliques out of     37 chunks from 19 comparisons
#  2m 24s PRINT (F 100 SET M>50 S>85): sorting out cliques
#  2m 24s PRINT (F 100 SET M>50 S>85): formatting 18 cliques skipping 6 binary chapter diffs
#  2m 24s PRINT (F 100 SET M>50 S>85): formatted 18 cliques (1 files) skipping 6 binary chapter diffs
#  2m 24s CHUNKING (F 100): already chunked into 4244 chunks
#  2m 24s PREPARING (F 100 SET): Already prepared
#  2m 24s SIMILARITY (F 100 SET M>50): Using  9003 K (9003646) comparisons with 359 entries in matrix
#  2m 24s SIMILARITY (F 100 SET M>50): similarities between 50.0 and 100.0. 1 are 100%
#  2m 24s CLIQUES (F 100 SET M>50 S>80): fetching similars and chunk candidates
#  2m 24s CLIQUES (F 100 SET M>50 S>80): inspecting the similarity matrix
#  2m 24s CLIQUES (F 100 SET M>50 S>80): 35 relevant similarities between 64 passages
#  2m 24s CLIQUES (F 100 SET M>50 S>80): Composing cliques out of     64 chunks from 35 comparisons
#  2m 24s CLIQUES (F 100 SET M>50 S>80): 64 members in 30 cliques
#  2m 24s CLIQUES (F 100 SET M>50 S>80): Composed and saved    30 cliques out of     64 chunks from 35 comparisons
#  2m 24s PRINT (F 100 SET M>50 S>80): sorting out cliques
#  2m 24s PRINT (F 100 SET M>50 S>80): formatting 30 cliques skipping 10 binary chapter diffs
#  2m 25s PRINT (F 100 SET M>50 S>80): formatted 30 cliques (1 files) skipping 10 binary chapter diffs
#  2m 25s CHUNKING (F 100): already chunked into 4244 chunks
#  2m 25s PREPARING (F 100 SET): Already prepared
#  2m 25s SIMILARITY (F 100 SET M>50): Using  9003 K (9003646) comparisons with 359 entries in matrix
#  2m 25s SIMILARITY (F 100 SET M>50): similarities between 50.0 and 100.0. 1 are 100%
#  2m 25s CLIQUES (F 100 SET M>50 S>75): fetching similars and chunk candidates
#  2m 25s CLIQUES (F 100 SET M>50 S>75): inspecting the similarity matrix
#  2m 25s CLIQUES (F 100 SET M>50 S>75): 63 relevant similarities between 87 passages
#  2m 25s CLIQUES (F 100 SET M>50 S>75): Composing cliques out of     87 chunks from 63 comparisons
#  2m 25s CLIQUES (F 100 SET M>50 S>75): 87 members in 40 cliques
#  2m 25s CLIQUES (F 100 SET M>50 S>75): Composed and saved    40 cliques out of     87 chunks from 63 comparisons
#  2m 25s PRINT (F 100 SET M>50 S>75): sorting out cliques
#  2m 25s PRINT (F 100 SET M>50 S>75): formatting 40 cliques skipping 16 binary chapter diffs
#  2m 25s PRINT (F 100 SET M>50 S>75): formatted 40 cliques (1 files) skipping 16 binary chapter diffs
#  2m 25s CHUNKING (F 100): already chunked into 4244 chunks
#  2m 25s PREPARING (F 100 SET): Already prepared
#  2m 25s SIMILARITY (F 100 SET M>50): Using  9003 K (9003646) comparisons with 359 entries in matrix
#  2m 25s SIMILARITY (F 100 SET M>50): similarities between 50.0 and 100.0. 1 are 100%
#  2m 25s CLIQUES (F 100 SET M>50 S>70): fetching similars and chunk candidates
#  2m 25s CLIQUES (F 100 SET M>50 S>70): inspecting the similarity matrix
#  2m 25s CLIQUES (F 100 SET M>50 S>70): 87 relevant similarities between 113 passages
#  2m 25s CLIQUES (F 100 SET M>50 S>70): Composing cliques out of    113 chunks from 87 comparisons
#  2m 25s CLIQUES (F 100 SET M>50 S>70): 113 members in 52 cliques
#  2m 25s CLIQUES (F 100 SET M>50 S>70): Composed and saved    52 cliques out of    113 chunks from 87 comparisons
#  2m 25s PRINT (F 100 SET M>50 S>70): sorting out cliques
#  2m 25s PRINT (F 100 SET M>50 S>70): formatting 52 cliques skipping 21 binary chapter diffs
#  2m 26s PRINT (F 100 SET M>50 S>70): formatted 52 cliques (2 files) skipping 21 binary chapter diffs
#  2m 26s CHUNKING (F 100): already chunked into 4244 chunks
#  2m 26s PREPARING (F 100 SET): Already prepared
#  2m 26s SIMILARITY (F 100 SET M>50): Using  9003 K (9003646) comparisons with 359 entries in matrix
#  2m 26s SIMILARITY (F 100 SET M>50): similarities between 50.0 and 100.0. 1 are 100%
#  2m 26s CLIQUES (F 100 SET M>50 S>65): fetching similars and chunk candidates
#  2m 26s CLIQUES (F 100 SET M>50 S>65): inspecting the similarity matrix
#  2m 26s CLIQUES (F 100 SET M>50 S>65): 115 relevant similarities between 154 passages
#  2m 26s CLIQUES (F 100 SET M>50 S>65): Composing cliques out of    154 chunks from 115 comparisons
#  2m 26s CLIQUES (F 100 SET M>50 S>65): 154 members in 70 cliques
#  2m 26s CLIQUES (F 100 SET M>50 S>65): Composed and saved    70 cliques out of    154 chunks from 115 comparisons
#  2m 26s PRINT (F 100 SET M>50 S>65): sorting out cliques
#  2m 26s PRINT (F 100 SET M>50 S>65): formatting 70 cliques skipping 28 binary chapter diffs
#  2m 27s PRINT (F 100 SET M>50 S>65): formatted 70 cliques (2 files) skipping 28 binary chapter diffs
#  2m 27s CHUNKING (F 100): already chunked into 4244 chunks
#  2m 27s PREPARING (F 100 SET): Already prepared
#  2m 27s SIMILARITY (F 100 SET M>50): Using  9003 K (9003646) comparisons with 359 entries in matrix
#  2m 27s SIMILARITY (F 100 SET M>50): similarities between 50.0 and 100.0. 1 are 100%
#  2m 27s CLIQUES (F 100 SET M>50 S>60): fetching similars and chunk candidates
#  2m 27s CLIQUES (F 100 SET M>50 S>60): inspecting the similarity matrix
#  2m 27s CLIQUES (F 100 SET M>50 S>60): 148 relevant similarities between 208 passages
#  2m 27s CLIQUES (F 100 SET M>50 S>60): Composing cliques out of    208 chunks from 148 comparisons
#  2m 27s CLIQUES (F 100 SET M>50 S>60): 208 members in 94 cliques
#  2m 27s CLIQUES (F 100 SET M>50 S>60): Composed and saved    94 cliques out of    208 chunks from 148 comparisons
#  2m 27s PRINT (F 100 SET M>50 S>60): sorting out cliques
#  2m 27s PRINT (F 100 SET M>50 S>60): formatting 94 cliques skipping 35 binary chapter diffs
#  2m 29s PRINT (F 100 SET M>50 S>60): formatted 94 cliques (2 files) skipping 35 binary chapter diffs
#  2m 29s CHUNKING (F 100): already chunked into 4244 chunks
#  2m 29s PREPARING (F 100 LCS)
#  2m 30s PREPARING (F 100 LCS): Done 4244 chunks.
#  2m 30s SIMILARITY (F 100 LCS M>60): Computing  9003 K (9003646) comparisons and saving entries in matrix
#  2m 42s SIMILARITY (F 100 LCS M>60): Computed    90 K comparisons and saved 3 entries in matrix
#  2m 52s SIMILARITY (F 100 LCS M>60): Computed   180 K comparisons and saved 9 entries in matrix
#  3m 02s SIMILARITY (F 100 LCS M>60): Computed   270 K comparisons and saved 11 entries in matrix
#  3m 12s SIMILARITY (F 100 LCS M>60): Computed   360 K comparisons and saved 11 entries in matrix
#  3m 22s SIMILARITY (F 100 LCS M>60): Computed   450 K comparisons and saved 11 entries in matrix
#  3m 32s SIMILARITY (F 100 LCS M>60): Computed   540 K comparisons and saved 12 entries in matrix
#  3m 42s SIMILARITY (F 100 LCS M>60): Computed   630 K comparisons and saved 12 entries in matrix
#  3m 51s SIMILARITY (F 100 LCS M>60): Computed   720 K comparisons and saved 12 entries in matrix
#  4m 02s SIMILARITY (F 100 LCS M>60): Computed   810 K comparisons and saved 12 entries in matrix
#  4m 12s SIMILARITY (F 100 LCS M>60): Computed   900 K comparisons and saved 14 entries in matrix
#  4m 22s SIMILARITY (F 100 LCS M>60): Computed   990 K comparisons and saved 15 entries in matrix
#  4m 31s SIMILARITY (F 100 LCS M>60): Computed  1080 K comparisons and saved 15 entries in matrix
#  4m 41s SIMILARITY (F 100 LCS M>60): Computed  1170 K comparisons and saved 15 entries in matrix
#  4m 51s SIMILARITY (F 100 LCS M>60): Computed  1260 K comparisons and saved 15 entries in matrix
#  5m 02s SIMILARITY (F 100 LCS M>60): Computed  1350 K comparisons and saved 18 entries in matrix
#  5m 12s SIMILARITY (F 100 LCS M>60): Computed  1440 K comparisons and saved 20 entries in matrix
#  5m 22s SIMILARITY (F 100 LCS M>60): Computed  1530 K comparisons and saved 20 entries in matrix
#  5m 32s SIMILARITY (F 100 LCS M>60): Computed  1620 K comparisons and saved 23 entries in matrix
#  5m 43s SIMILARITY (F 100 LCS M>60): Computed  1710 K comparisons and saved 28 entries in matrix
#  5m 53s SIMILARITY (F 100 LCS M>60): Computed  1800 K comparisons and saved 41 entries in matrix
#  6m 03s SIMILARITY (F 100 LCS M>60): Computed  1890 K comparisons and saved 46 entries in matrix
#  6m 14s SIMILARITY (F 100 LCS M>60): Computed  1980 K comparisons and saved 51 entries in matrix
#  6m 25s SIMILARITY (F 100 LCS M>60): Computed  2070 K comparisons and saved 51 entries in matrix
#  6m 35s SIMILARITY (F 100 LCS M>60): Computed  2160 K comparisons and saved 63 entries in matrix
#  6m 45s SIMILARITY (F 100 LCS M>60): Computed  2250 K comparisons and saved 67 entries in matrix
#  6m 55s SIMILARITY (F 100 LCS M>60): Computed  2340 K comparisons and saved 73 entries in matrix
#  7m 05s SIMILARITY (F 100 LCS M>60): Computed  2430 K comparisons and saved 80 entries in matrix
#  7m 16s SIMILARITY (F 100 LCS M>60): Computed  2521 K comparisons and saved 81 entries in matrix
#  7m 26s SIMILARITY (F 100 LCS M>60): Computed  2611 K comparisons and saved 84 entries in matrix
#  7m 36s SIMILARITY (F 100 LCS M>60): Computed  2701 K comparisons and saved 84 entries in matrix
#  7m 47s SIMILARITY (F 100 LCS M>60): Computed  2791 K comparisons and saved 97 entries in matrix
#  7m 57s SIMILARITY (F 100 LCS M>60): Computed  2881 K comparisons and saved 131 entries in matrix
#  8m 09s SIMILARITY (F 100 LCS M>60): Computed  2971 K comparisons and saved 133 entries in matrix
#  8m 19s SIMILARITY (F 100 LCS M>60): Computed  3061 K comparisons and saved 133 entries in matrix
#  8m 29s SIMILARITY (F 100 LCS M>60): Computed  3151 K comparisons and saved 133 entries in matrix
#  8m 40s SIMILARITY (F 100 LCS M>60): Computed  3241 K comparisons and saved 133 entries in matrix
#  8m 52s SIMILARITY (F 100 LCS M>60): Computed  3331 K comparisons and saved 146 entries in matrix
#  9m 02s SIMILARITY (F 100 LCS M>60): Computed  3421 K comparisons and saved 157 entries in matrix
#  9m 13s SIMILARITY (F 100 LCS M>60): Computed  3511 K comparisons and saved 161 entries in matrix
#  9m 24s SIMILARITY (F 100 LCS M>60): Computed  3601 K comparisons and saved 161 entries in matrix
#  9m 34s SIMILARITY (F 100 LCS M>60): Computed  3691 K comparisons and saved 163 entries in matrix
#  9m 45s SIMILARITY (F 100 LCS M>60): Computed  3781 K comparisons and saved 165 entries in matrix
#  9m 55s SIMILARITY (F 100 LCS M>60): Computed  3871 K comparisons and saved 165 entries in matrix
# 10m 05s SIMILARITY (F 100 LCS M>60): Computed  3961 K comparisons and saved 165 entries in matrix
# 10m 16s SIMILARITY (F 100 LCS M>60): Computed  4051 K comparisons and saved 166 entries in matrix
# 10m 26s SIMILARITY (F 100 LCS M>60): Computed  4141 K comparisons and saved 167 entries in matrix
# 10m 37s SIMILARITY (F 100 LCS M>60): Computed  4231 K comparisons and saved 167 entries in matrix
# 10m 47s SIMILARITY (F 100 LCS M>60): Computed  4321 K comparisons and saved 167 entries in matrix
# 10m 58s SIMILARITY (F 100 LCS M>60): Computed  4411 K comparisons and saved 170 entries in matrix
# 11m 09s SIMILARITY (F 100 LCS M>60): Computed  4501 K comparisons and saved 171 entries in matrix
# 11m 19s SIMILARITY (F 100 LCS M>60): Computed  4591 K comparisons and saved 180 entries in matrix
# 11m 30s SIMILARITY (F 100 LCS M>60): Computed  4681 K comparisons and saved 180 entries in matrix
# 11m 40s SIMILARITY (F 100 LCS M>60): Computed  4771 K comparisons and saved 180 entries in matrix
# 11m 50s SIMILARITY (F 100 LCS M>60): Computed  4861 K comparisons and saved 181 entries in matrix
# 12m 00s SIMILARITY (F 100 LCS M>60): Computed  4951 K comparisons and saved 182 entries in matrix
# 12m 11s SIMILARITY (F 100 LCS M>60): Computed  5042 K comparisons and saved 182 entries in matrix
# 12m 21s SIMILARITY (F 100 LCS M>60): Computed  5132 K comparisons and saved 182 entries in matrix
# 12m 32s SIMILARITY (F 100 LCS M>60): Computed  5222 K comparisons and saved 182 entries in matrix
# 12m 42s SIMILARITY (F 100 LCS M>60): Computed  5312 K comparisons and saved 182 entries in matrix
# 12m 52s SIMILARITY (F 100 LCS M>60): Computed  5402 K comparisons and saved 182 entries in matrix
# 13m 02s SIMILARITY (F 100 LCS M>60): Computed  5492 K comparisons and saved 182 entries in matrix
# 13m 12s SIMILARITY (F 100 LCS M>60): Computed  5582 K comparisons and saved 184 entries in matrix
# 13m 22s SIMILARITY (F 100 LCS M>60): Computed  5672 K comparisons and saved 194 entries in matrix
# 13m 32s SIMILARITY (F 100 LCS M>60): Computed  5762 K comparisons and saved 195 entries in matrix
# 13m 42s SIMILARITY (F 100 LCS M>60): Computed  5852 K comparisons and saved 195 entries in matrix
# 13m 52s SIMILARITY (F 100 LCS M>60): Computed  5942 K comparisons and saved 208 entries in matrix
# 14m 03s SIMILARITY (F 100 LCS M>60): Computed  6032 K comparisons and saved 209 entries in matrix
# 14m 14s SIMILARITY (F 100 LCS M>60): Computed  6122 K comparisons and saved 235 entries in matrix
# 14m 24s SIMILARITY (F 100 LCS M>60): Computed  6212 K comparisons and saved 251 entries in matrix
# 14m 35s SIMILARITY (F 100 LCS M>60): Computed  6302 K comparisons and saved 262 entries in matrix
# 14m 45s SIMILARITY (F 100 LCS M>60): Computed  6392 K comparisons and saved 266 entries in matrix
# 14m 56s SIMILARITY (F 100 LCS M>60): Computed  6482 K comparisons and saved 274 entries in matrix
# 15m 06s SIMILARITY (F 100 LCS M>60): Computed  6572 K comparisons and saved 301 entries in matrix
# 15m 17s SIMILARITY (F 100 LCS M>60): Computed  6662 K comparisons and saved 324 entries in matrix
# 15m 28s SIMILARITY (F 100 LCS M>60): Computed  6752 K comparisons and saved 343 entries in matrix
# 15m 38s SIMILARITY (F 100 LCS M>60): Computed  6842 K comparisons and saved 343 entries in matrix
# 15m 49s SIMILARITY (F 100 LCS M>60): Computed  6932 K comparisons and saved 343 entries in matrix
# 16m 01s SIMILARITY (F 100 LCS M>60): Computed  7022 K comparisons and saved 343 entries in matrix
# 16m 12s SIMILARITY (F 100 LCS M>60): Computed  7112 K comparisons and saved 343 entries in matrix
# 16m 23s SIMILARITY (F 100 LCS M>60): Computed  7202 K comparisons and saved 343 entries in matrix
# 16m 34s SIMILARITY (F 100 LCS M>60): Computed  7292 K comparisons and saved 346 entries in matrix
# 16m 45s SIMILARITY (F 100 LCS M>60): Computed  7382 K comparisons and saved 349 entries in matrix
# 16m 55s SIMILARITY (F 100 LCS M>60): Computed  7472 K comparisons and saved 351 entries in matrix
# 17m 06s SIMILARITY (F 100 LCS M>60): Computed  7563 K comparisons and saved 352 entries in matrix
# 17m 17s SIMILARITY (F 100 LCS M>60): Computed  7653 K comparisons and saved 355 entries in matrix
# 17m 29s SIMILARITY (F 100 LCS M>60): Computed  7743 K comparisons and saved 356 entries in matrix
# 17m 42s SIMILARITY (F 100 LCS M>60): Computed  7833 K comparisons and saved 357 entries in matrix
# 17m 55s SIMILARITY (F 100 LCS M>60): Computed  7923 K comparisons and saved 357 entries in matrix
# 18m 08s SIMILARITY (F 100 LCS M>60): Computed  8013 K comparisons and saved 359 entries in matrix
# 18m 20s SIMILARITY (F 100 LCS M>60): Computed  8103 K comparisons and saved 362 entries in matrix
# 18m 31s SIMILARITY (F 100 LCS M>60): Computed  8193 K comparisons and saved 362 entries in matrix
# 18m 44s SIMILARITY (F 100 LCS M>60): Computed  8283 K comparisons and saved 363 entries in matrix
# 18m 56s SIMILARITY (F 100 LCS M>60): Computed  8373 K comparisons and saved 364 entries in matrix
# 19m 08s SIMILARITY (F 100 LCS M>60): Computed  8463 K comparisons and saved 366 entries in matrix
# 19m 20s SIMILARITY (F 100 LCS M>60): Computed  8553 K comparisons and saved 370 entries in matrix
# 19m 33s SIMILARITY (F 100 LCS M>60): Computed  8643 K comparisons and saved 372 entries in matrix
# 19m 44s SIMILARITY (F 100 LCS M>60): Computed  8733 K comparisons and saved 372 entries in matrix
# 19m 56s SIMILARITY (F 100 LCS M>60): Computed  8823 K comparisons and saved 373 entries in matrix
# 20m 09s SIMILARITY (F 100 LCS M>60): Computed  8913 K comparisons and saved 381 entries in matrix
# 20m 22s SIMILARITY (F 100 LCS M>60): Computed  9003 K comparisons and saved 393 entries in matrix
# 20m 22s SIMILARITY (F 100 LCS M>60): Computed  9003 K (9003646) comparisons and saved 393 entries in matrix
# 20m 22s SIMILARITY (F 100 LCS M>60): similarities between 60.0 and 97.6923076923077. 0 are 100%
# 20m 22s CLIQUES (F 100 LCS M>60 S>100): fetching similars and chunk candidates
# 20m 22s CLIQUES (F 100 LCS M>60 S>100): inspecting the similarity matrix
# 20m 22s CLIQUES (F 100 LCS M>60 S>100): 0 relevant similarities between 0 passages
# 20m 22s CLIQUES (F 100 LCS M>60 S>100): Composing cliques out of      0 chunks from 0 comparisons
# 20m 22s CLIQUES (F 100 LCS M>60 S>100): 0 members in 0 cliques
# 20m 22s CLIQUES (F 100 LCS M>60 S>100): Composed and saved     0 cliques out of      0 chunks from 0 comparisons
# 20m 22s PRINT (F 100 LCS M>60 S>100): sorting out cliques
# 20m 22s PRINT (F 100 LCS M>60 S>100): formatting 0 cliques skipping 0 binary chapter diffs
# 20m 22s PRINT (F 100 LCS M>60 S>100): formatted 0 cliques (1 files) skipping 0 binary chapter diffs
# 20m 22s CHUNKING (F 100): already chunked into 4244 chunks
# 20m 22s PREPARING (F 100 LCS): Already prepared
# 20m 22s SIMILARITY (F 100 LCS M>60): Using  9003 K (9003646) comparisons with 393 entries in matrix
# 20m 22s SIMILARITY (F 100 LCS M>60): similarities between 60.0 and 97.6923076923077. 0 are 100%
# 20m 22s CLIQUES (F 100 LCS M>60 S>95): fetching similars and chunk candidates
# 20m 22s CLIQUES (F 100 LCS M>60 S>95): inspecting the similarity matrix
# 20m 22s CLIQUES (F 100 LCS M>60 S>95): 2 relevant similarities between 4 passages
# 20m 22s CLIQUES (F 100 LCS M>60 S>95): Composing cliques out of      4 chunks from 2 comparisons
# 20m 22s CLIQUES (F 100 LCS M>60 S>95): 4 members in 2 cliques
# 20m 22s CLIQUES (F 100 LCS M>60 S>95): Composed and saved     2 cliques out of      4 chunks from 2 comparisons
# 20m 22s PRINT (F 100 LCS M>60 S>95): sorting out cliques
# 20m 22s PRINT (F 100 LCS M>60 S>95): formatting 2 cliques skipping 2 binary chapter diffs
# 20m 22s PRINT (F 100 LCS M>60 S>95): formatted 2 cliques (1 files) skipping 2 binary chapter diffs
# 20m 22s CHUNKING (F 100): already chunked into 4244 chunks
# 20m 22s PREPARING (F 100 LCS): Already prepared
# 20m 22s SIMILARITY (F 100 LCS M>60): Using  9003 K (9003646) comparisons with 393 entries in matrix
# 20m 22s SIMILARITY (F 100 LCS M>60): similarities between 60.0 and 97.6923076923077. 0 are 100%
# 20m 22s CLIQUES (F 100 LCS M>60 S>90): fetching similars and chunk candidates
# 20m 22s CLIQUES (F 100 LCS M>60 S>90): inspecting the similarity matrix
# 20m 22s CLIQUES (F 100 LCS M>60 S>90): 21 relevant similarities between 39 passages
# 20m 22s CLIQUES (F 100 LCS M>60 S>90): Composing cliques out of     39 chunks from 21 comparisons
# 20m 22s CLIQUES (F 100 LCS M>60 S>90): 39 members in 19 cliques
# 20m 22s CLIQUES (F 100 LCS M>60 S>90): Composed and saved    19 cliques out of     39 chunks from 21 comparisons
# 20m 22s PRINT (F 100 LCS M>60 S>90): sorting out cliques
# 20m 22s PRINT (F 100 LCS M>60 S>90): formatting 19 cliques skipping 4 binary chapter diffs
# 20m 22s PRINT (F 100 LCS M>60 S>90): formatted 19 cliques (1 files) skipping 4 binary chapter diffs
# 20m 22s CHUNKING (F 100): already chunked into 4244 chunks
# 20m 22s PREPARING (F 100 LCS): Already prepared
# 20m 22s SIMILARITY (F 100 LCS M>60): Using  9003 K (9003646) comparisons with 393 entries in matrix
# 20m 22s SIMILARITY (F 100 LCS M>60): similarities between 60.0 and 97.6923076923077. 0 are 100%
# 20m 22s CLIQUES (F 100 LCS M>60 S>85): fetching similars and chunk candidates
# 20m 22s CLIQUES (F 100 LCS M>60 S>85): inspecting the similarity matrix
# 20m 22s CLIQUES (F 100 LCS M>60 S>85): 31 relevant similarities between 59 passages
# 20m 22s CLIQUES (F 100 LCS M>60 S>85): Composing cliques out of     59 chunks from 31 comparisons
# 20m 22s CLIQUES (F 100 LCS M>60 S>85): 59 members in 29 cliques
# 20m 22s CLIQUES (F 100 LCS M>60 S>85): Composed and saved    29 cliques out of     59 chunks from 31 comparisons
# 20m 22s PRINT (F 100 LCS M>60 S>85): sorting out cliques
# 20m 22s PRINT (F 100 LCS M>60 S>85): formatting 29 cliques skipping 10 binary chapter diffs
# 20m 22s PRINT (F 100 LCS M>60 S>85): formatted 29 cliques (1 files) skipping 10 binary chapter diffs
# 20m 22s CHUNKING (F 100): already chunked into 4244 chunks
# 20m 22s PREPARING (F 100 LCS): Already prepared
# 20m 22s SIMILARITY (F 100 LCS M>60): Using  9003 K (9003646) comparisons with 393 entries in matrix
# 20m 22s SIMILARITY (F 100 LCS M>60): similarities between 60.0 and 97.6923076923077. 0 are 100%
# 20m 22s CLIQUES (F 100 LCS M>60 S>80): fetching similars and chunk candidates
# 20m 22s CLIQUES (F 100 LCS M>60 S>80): inspecting the similarity matrix
# 20m 22s CLIQUES (F 100 LCS M>60 S>80): 46 relevant similarities between 85 passages
# 20m 22s CLIQUES (F 100 LCS M>60 S>80): Composing cliques out of     85 chunks from 46 comparisons
# 20m 22s CLIQUES (F 100 LCS M>60 S>80): 85 members in 41 cliques
# 20m 22s CLIQUES (F 100 LCS M>60 S>80): Composed and saved    41 cliques out of     85 chunks from 46 comparisons
# 20m 22s PRINT (F 100 LCS M>60 S>80): sorting out cliques
# 20m 23s PRINT (F 100 LCS M>60 S>80): formatting 41 cliques skipping 16 binary chapter diffs
# 20m 23s PRINT (F 100 LCS M>60 S>80): formatted 41 cliques (1 files) skipping 16 binary chapter diffs
# 20m 23s CHUNKING (F 100): already chunked into 4244 chunks
# 20m 23s PREPARING (F 100 LCS): Already prepared
# 20m 23s SIMILARITY (F 100 LCS M>60): Using  9003 K (9003646) comparisons with 393 entries in matrix
# 20m 23s SIMILARITY (F 100 LCS M>60): similarities between 60.0 and 97.6923076923077. 0 are 100%
# 20m 23s CLIQUES (F 100 LCS M>60 S>75): fetching similars and chunk candidates
# 20m 23s CLIQUES (F 100 LCS M>60 S>75): inspecting the similarity matrix
# 20m 23s CLIQUES (F 100 LCS M>60 S>75): 77 relevant similarities between 122 passages
# 20m 23s CLIQUES (F 100 LCS M>60 S>75): Composing cliques out of    122 chunks from 77 comparisons
# 20m 23s CLIQUES (F 100 LCS M>60 S>75): 122 members in 56 cliques
# 20m 23s CLIQUES (F 100 LCS M>60 S>75): Composed and saved    56 cliques out of    122 chunks from 77 comparisons
# 20m 23s PRINT (F 100 LCS M>60 S>75): sorting out cliques
# 20m 23s PRINT (F 100 LCS M>60 S>75): formatting 56 cliques skipping 25 binary chapter diffs
# 20m 24s PRINT (F 100 LCS M>60 S>75): formatted 56 cliques (2 files) skipping 25 binary chapter diffs
# 20m 24s CHUNKING (F 100): already chunked into 4244 chunks
# 20m 24s PREPARING (F 100 LCS): Already prepared
# 20m 24s SIMILARITY (F 100 LCS M>60): Using  9003 K (9003646) comparisons with 393 entries in matrix
# 20m 24s SIMILARITY (F 100 LCS M>60): similarities between 60.0 and 97.6923076923077. 0 are 100%
# 20m 24s CLIQUES (F 100 LCS M>60 S>70): fetching similars and chunk candidates
# 20m 24s CLIQUES (F 100 LCS M>60 S>70): inspecting the similarity matrix
# 20m 24s CLIQUES (F 100 LCS M>60 S>70): 123 relevant similarities between 189 passages
# 20m 24s CLIQUES (F 100 LCS M>60 S>70): Composing cliques out of    189 chunks from 123 comparisons
# 20m 24s CLIQUES (F 100 LCS M>60 S>70): 189 members in 88 cliques
# 20m 24s CLIQUES (F 100 LCS M>60 S>70): Composed and saved    88 cliques out of    189 chunks from 123 comparisons
# 20m 24s PRINT (F 100 LCS M>60 S>70): sorting out cliques
# 20m 24s PRINT (F 100 LCS M>60 S>70): formatting 88 cliques skipping 38 binary chapter diffs
# 20m 26s PRINT (F 100 LCS M>60 S>70): formatted 88 cliques (2 files) skipping 38 binary chapter diffs
# 20m 26s CHUNKING (F 100): already chunked into 4244 chunks
# 20m 26s PREPARING (F 100 LCS): Already prepared
# 20m 26s SIMILARITY (F 100 LCS M>60): Using  9003 K (9003646) comparisons with 393 entries in matrix
# 20m 26s SIMILARITY (F 100 LCS M>60): similarities between 60.0 and 97.6923076923077. 0 are 100%
# 20m 26s CLIQUES (F 100 LCS M>60 S>65): fetching similars and chunk candidates
# 20m 26s CLIQUES (F 100 LCS M>60 S>65): inspecting the similarity matrix
# 20m 26s CLIQUES (F 100 LCS M>60 S>65): 182 relevant similarities between 287 passages
# 20m 26s CLIQUES (F 100 LCS M>60 S>65): Composing cliques out of    287 chunks from 182 comparisons
# 20m 26s CLIQUES (F 100 LCS M>60 S>65): 287 members in 132 cliques
# 20m 26s CLIQUES (F 100 LCS M>60 S>65): Composed and saved   132 cliques out of    287 chunks from 182 comparisons
# 20m 26s PRINT (F 100 LCS M>60 S>65): sorting out cliques
# 20m 26s PRINT (F 100 LCS M>60 S>65): formatting 132 cliques skipping 55 binary chapter diffs
# 20m 29s PRINT (F 100 LCS M>60 S>65): formatted 132 cliques (3 files) skipping 55 binary chapter diffs
# 20m 29s CHUNKING (F 100): already chunked into 4244 chunks
# 20m 29s PREPARING (F 100 LCS): Already prepared
# 20m 29s SIMILARITY (F 100 LCS M>60): Using  9003 K (9003646) comparisons with 393 entries in matrix
# 20m 29s SIMILARITY (F 100 LCS M>60): similarities between 60.0 and 97.6923076923077. 0 are 100%
# 20m 29s CLIQUES (F 100 LCS M>60 S>60): fetching similars and chunk candidates
# 20m 29s CLIQUES (F 100 LCS M>60 S>60): inspecting the similarity matrix
# 20m 29s CLIQUES (F 100 LCS M>60 S>60): 393 relevant similarities between 535 passages
# 20m 29s CLIQUES (F 100 LCS M>60 S>60): Composing cliques out of    535 chunks from 393 comparisons
# 20m 29s CLIQUES (F 100 LCS M>60 S>60): 535 members in 214 cliques
# 20m 29s CLIQUES (F 100 LCS M>60 S>60): Composed and saved   214 cliques out of    535 chunks from 393 comparisons
# 20m 29s PRINT (F 100 LCS M>60 S>60): sorting out cliques
# 20m 29s PRINT (F 100 LCS M>60 S>60): formatting 214 cliques skipping 100 binary chapter diffs
# 20m 35s PRINT (F 100 LCS M>60 S>60): formatted 214 cliques (5 files) skipping 100 binary chapter diffs
# 20m 35s CHUNKING (F 50)
# 20m 37s CHUNKING (F 50): Made 8509 chunks
# 20m 37s PREPARING (F 50 SET)
# 20m 37s PREPARING (F 50 SET): Done 8509 chunks.
# 20m 37s SIMILARITY (F 50 SET M>50): Computing 36197 K (36197286) comparisons and saving entries in matrix
# 20m 39s SIMILARITY (F 50 SET M>50): Computed   361 K comparisons and saved 2 entries in matrix
# 20m 41s SIMILARITY (F 50 SET M>50): Computed   723 K comparisons and saved 20 entries in matrix
# 20m 42s SIMILARITY (F 50 SET M>50): Computed  1085 K comparisons and saved 27 entries in matrix
# 20m 44s SIMILARITY (F 50 SET M>50): Computed  1447 K comparisons and saved 29 entries in matrix
# 20m 45s SIMILARITY (F 50 SET M>50): Computed  1809 K comparisons and saved 30 entries in matrix
# 20m 47s SIMILARITY (F 50 SET M>50): Computed  2171 K comparisons and saved 32 entries in matrix
# 20m 48s SIMILARITY (F 50 SET M>50): Computed  2533 K comparisons and saved 34 entries in matrix
# 20m 50s SIMILARITY (F 50 SET M>50): Computed  2895 K comparisons and saved 34 entries in matrix
# 20m 51s SIMILARITY (F 50 SET M>50): Computed  3257 K comparisons and saved 34 entries in matrix
# 20m 53s SIMILARITY (F 50 SET M>50): Computed  3619 K comparisons and saved 39 entries in matrix
# 20m 54s SIMILARITY (F 50 SET M>50): Computed  3981 K comparisons and saved 41 entries in matrix
# 20m 56s SIMILARITY (F 50 SET M>50): Computed  4343 K comparisons and saved 42 entries in matrix
# 20m 57s SIMILARITY (F 50 SET M>50): Computed  4705 K comparisons and saved 43 entries in matrix
# 20m 59s SIMILARITY (F 50 SET M>50): Computed  5067 K comparisons and saved 43 entries in matrix
# 21m 00s SIMILARITY (F 50 SET M>50): Computed  5429 K comparisons and saved 50 entries in matrix
# 21m 02s SIMILARITY (F 50 SET M>50): Computed  5791 K comparisons and saved 52 entries in matrix
# 21m 04s SIMILARITY (F 50 SET M>50): Computed  6153 K comparisons and saved 57 entries in matrix
# 21m 05s SIMILARITY (F 50 SET M>50): Computed  6515 K comparisons and saved 61 entries in matrix
# 21m 07s SIMILARITY (F 50 SET M>50): Computed  6877 K comparisons and saved 70 entries in matrix
# 21m 08s SIMILARITY (F 50 SET M>50): Computed  7239 K comparisons and saved 108 entries in matrix
# 21m 10s SIMILARITY (F 50 SET M>50): Computed  7601 K comparisons and saved 122 entries in matrix
# 21m 11s SIMILARITY (F 50 SET M>50): Computed  7963 K comparisons and saved 129 entries in matrix
# 21m 13s SIMILARITY (F 50 SET M>50): Computed  8325 K comparisons and saved 131 entries in matrix
# 21m 14s SIMILARITY (F 50 SET M>50): Computed  8687 K comparisons and saved 157 entries in matrix
# 21m 16s SIMILARITY (F 50 SET M>50): Computed  9049 K comparisons and saved 162 entries in matrix
# 21m 17s SIMILARITY (F 50 SET M>50): Computed  9411 K comparisons and saved 186 entries in matrix
# 21m 18s SIMILARITY (F 50 SET M>50): Computed  9773 K comparisons and saved 215 entries in matrix
# 21m 20s SIMILARITY (F 50 SET M>50): Computed 10135 K comparisons and saved 219 entries in matrix
# 21m 22s SIMILARITY (F 50 SET M>50): Computed 10497 K comparisons and saved 226 entries in matrix
# 21m 23s SIMILARITY (F 50 SET M>50): Computed 10859 K comparisons and saved 230 entries in matrix
# 21m 25s SIMILARITY (F 50 SET M>50): Computed 11221 K comparisons and saved 264 entries in matrix
# 21m 26s SIMILARITY (F 50 SET M>50): Computed 11583 K comparisons and saved 348 entries in matrix
# 21m 28s SIMILARITY (F 50 SET M>50): Computed 11945 K comparisons and saved 355 entries in matrix
# 21m 30s SIMILARITY (F 50 SET M>50): Computed 12307 K comparisons and saved 363 entries in matrix
# 21m 32s SIMILARITY (F 50 SET M>50): Computed 12669 K comparisons and saved 363 entries in matrix
# 21m 34s SIMILARITY (F 50 SET M>50): Computed 13030 K comparisons and saved 366 entries in matrix
# 21m 36s SIMILARITY (F 50 SET M>50): Computed 13392 K comparisons and saved 393 entries in matrix
# 21m 37s SIMILARITY (F 50 SET M>50): Computed 13754 K comparisons and saved 426 entries in matrix
# 21m 39s SIMILARITY (F 50 SET M>50): Computed 14116 K comparisons and saved 432 entries in matrix
# 21m 41s SIMILARITY (F 50 SET M>50): Computed 14478 K comparisons and saved 435 entries in matrix
# 21m 43s SIMILARITY (F 50 SET M>50): Computed 14840 K comparisons and saved 447 entries in matrix
# 21m 46s SIMILARITY (F 50 SET M>50): Computed 15202 K comparisons and saved 454 entries in matrix
# 21m 48s SIMILARITY (F 50 SET M>50): Computed 15564 K comparisons and saved 455 entries in matrix
# 21m 50s SIMILARITY (F 50 SET M>50): Computed 15926 K comparisons and saved 457 entries in matrix
# 21m 52s SIMILARITY (F 50 SET M>50): Computed 16288 K comparisons and saved 463 entries in matrix
# 21m 53s SIMILARITY (F 50 SET M>50): Computed 16650 K comparisons and saved 464 entries in matrix
# 21m 56s SIMILARITY (F 50 SET M>50): Computed 17012 K comparisons and saved 467 entries in matrix
# 21m 57s SIMILARITY (F 50 SET M>50): Computed 17374 K comparisons and saved 467 entries in matrix
# 21m 59s SIMILARITY (F 50 SET M>50): Computed 17736 K comparisons and saved 480 entries in matrix
# 22m 01s SIMILARITY (F 50 SET M>50): Computed 18098 K comparisons and saved 488 entries in matrix
# 22m 02s SIMILARITY (F 50 SET M>50): Computed 18460 K comparisons and saved 491 entries in matrix
# 22m 04s SIMILARITY (F 50 SET M>50): Computed 18822 K comparisons and saved 492 entries in matrix
# 22m 06s SIMILARITY (F 50 SET M>50): Computed 19184 K comparisons and saved 493 entries in matrix
# 22m 07s SIMILARITY (F 50 SET M>50): Computed 19546 K comparisons and saved 493 entries in matrix
# 22m 09s SIMILARITY (F 50 SET M>50): Computed 19908 K comparisons and saved 494 entries in matrix
# 22m 11s SIMILARITY (F 50 SET M>50): Computed 20270 K comparisons and saved 494 entries in matrix
# 22m 12s SIMILARITY (F 50 SET M>50): Computed 20632 K comparisons and saved 496 entries in matrix
# 22m 14s SIMILARITY (F 50 SET M>50): Computed 20994 K comparisons and saved 496 entries in matrix
# 22m 15s SIMILARITY (F 50 SET M>50): Computed 21356 K comparisons and saved 498 entries in matrix
# 22m 17s SIMILARITY (F 50 SET M>50): Computed 21718 K comparisons and saved 498 entries in matrix
# 22m 19s SIMILARITY (F 50 SET M>50): Computed 22080 K comparisons and saved 498 entries in matrix
# 22m 20s SIMILARITY (F 50 SET M>50): Computed 22442 K comparisons and saved 511 entries in matrix
# 22m 22s SIMILARITY (F 50 SET M>50): Computed 22804 K comparisons and saved 543 entries in matrix
# 22m 24s SIMILARITY (F 50 SET M>50): Computed 23166 K comparisons and saved 545 entries in matrix
# 22m 25s SIMILARITY (F 50 SET M>50): Computed 23528 K comparisons and saved 545 entries in matrix
# 22m 27s SIMILARITY (F 50 SET M>50): Computed 23890 K comparisons and saved 562 entries in matrix
# 22m 29s SIMILARITY (F 50 SET M>50): Computed 24252 K comparisons and saved 567 entries in matrix
# 22m 30s SIMILARITY (F 50 SET M>50): Computed 24614 K comparisons and saved 624 entries in matrix
# 22m 32s SIMILARITY (F 50 SET M>50): Computed 24976 K comparisons and saved 665 entries in matrix
# 22m 34s SIMILARITY (F 50 SET M>50): Computed 25338 K comparisons and saved 677 entries in matrix
# 22m 35s SIMILARITY (F 50 SET M>50): Computed 25700 K comparisons and saved 703 entries in matrix
# 22m 37s SIMILARITY (F 50 SET M>50): Computed 26061 K comparisons and saved 711 entries in matrix
# 22m 38s SIMILARITY (F 50 SET M>50): Computed 26423 K comparisons and saved 749 entries in matrix
# 22m 40s SIMILARITY (F 50 SET M>50): Computed 26785 K comparisons and saved 789 entries in matrix
# 22m 42s SIMILARITY (F 50 SET M>50): Computed 27147 K comparisons and saved 827 entries in matrix
# 22m 43s SIMILARITY (F 50 SET M>50): Computed 27509 K comparisons and saved 827 entries in matrix
# 22m 45s SIMILARITY (F 50 SET M>50): Computed 27871 K comparisons and saved 827 entries in matrix
# 22m 47s SIMILARITY (F 50 SET M>50): Computed 28233 K comparisons and saved 828 entries in matrix
# 22m 48s SIMILARITY (F 50 SET M>50): Computed 28595 K comparisons and saved 828 entries in matrix
# 22m 50s SIMILARITY (F 50 SET M>50): Computed 28957 K comparisons and saved 828 entries in matrix
# 22m 52s SIMILARITY (F 50 SET M>50): Computed 29319 K comparisons and saved 831 entries in matrix
# 22m 53s SIMILARITY (F 50 SET M>50): Computed 29681 K comparisons and saved 833 entries in matrix
# 22m 55s SIMILARITY (F 50 SET M>50): Computed 30043 K comparisons and saved 838 entries in matrix
# 22m 57s SIMILARITY (F 50 SET M>50): Computed 30405 K comparisons and saved 840 entries in matrix
# 22m 58s SIMILARITY (F 50 SET M>50): Computed 30767 K comparisons and saved 845 entries in matrix
# 23m 00s SIMILARITY (F 50 SET M>50): Computed 31129 K comparisons and saved 850 entries in matrix
# 23m 01s SIMILARITY (F 50 SET M>50): Computed 31491 K comparisons and saved 854 entries in matrix
# 23m 03s SIMILARITY (F 50 SET M>50): Computed 31853 K comparisons and saved 861 entries in matrix
# 23m 05s SIMILARITY (F 50 SET M>50): Computed 32215 K comparisons and saved 866 entries in matrix
# 23m 06s SIMILARITY (F 50 SET M>50): Computed 32577 K comparisons and saved 877 entries in matrix
# ...
#  6h 21m 16s CLIQUES (O sentence LCS M>60 S>65): Composed  1160 cliques out of   5000 chunks
#  6h 21m 19s CLIQUES (O sentence LCS M>60 S>65): Composed  1210 cliques out of   6000 chunks
#  6h 21m 22s CLIQUES (O sentence LCS M>60 S>65): Composed  1181 cliques out of   7000 chunks
#  6h 21m 25s CLIQUES (O sentence LCS M>60 S>65): Composed  1238 cliques out of   8000 chunks
#  6h 21m 28s CLIQUES (O sentence LCS M>60 S>65): Composed  1155 cliques out of   9000 chunks
#  6h 21m 31s CLIQUES (O sentence LCS M>60 S>65): Composed  1155 cliques out of  10000 chunks
#  6h 21m 35s CLIQUES (O sentence LCS M>60 S>65): Composed  1076 cliques out of  11000 chunks
#  6h 21m 38s CLIQUES (O sentence LCS M>60 S>65): Composed  1013 cliques out of  12000 chunks
#  6h 21m 42s CLIQUES (O sentence LCS M>60 S>65): Composed   999 cliques out of  13000 chunks
#  6h 21m 45s CLIQUES (O sentence LCS M>60 S>65): Composed   976 cliques out of  14000 chunks
#  6h 21m 49s CLIQUES (O sentence LCS M>60 S>65): Composed   933 cliques out of  15000 chunks
#  6h 21m 53s CLIQUES (O sentence LCS M>60 S>65): Composed   896 cliques out of  16000 chunks
#  6h 21m 57s CLIQUES (O sentence LCS M>60 S>65): Composed   887 cliques out of  17000 chunks
#  6h 22m 01s CLIQUES (O sentence LCS M>60 S>65): Composed   836 cliques out of  18000 chunks
#  6h 22m 05s CLIQUES (O sentence LCS M>60 S>65): Composed   816 cliques out of  19000 chunks
#  6h 22m 09s CLIQUES (O sentence LCS M>60 S>65): Composed   797 cliques out of  20000 chunks
#  6h 22m 14s CLIQUES (O sentence LCS M>60 S>65): Composed   800 cliques out of  21000 chunks
#  6h 22m 18s CLIQUES (O sentence LCS M>60 S>65): Composed   774 cliques out of  22000 chunks
#  6h 22m 24s CLIQUES (O sentence LCS M>60 S>65): Composed   764 cliques out of  23000 chunks
#  6h 22m 28s CLIQUES (O sentence LCS M>60 S>65): Composed   742 cliques out of  24000 chunks
#  6h 22m 32s CLIQUES (O sentence LCS M>60 S>65): Composed   716 cliques out of  25000 chunks
#  6h 22m 37s CLIQUES (O sentence LCS M>60 S>65): Composed   706 cliques out of  26000 chunks
#  6h 22m 41s CLIQUES (O sentence LCS M>60 S>65): Composed   691 cliques out of  27000 chunks
#  6h 22m 47s CLIQUES (O sentence LCS M>60 S>65): Composed   682 cliques out of  28000 chunks
#  6h 22m 52s CLIQUES (O sentence LCS M>60 S>65): Composed   651 cliques out of  29000 chunks
#  6h 22m 58s CLIQUES (O sentence LCS M>60 S>65): Composed   639 cliques out of  30000 chunks
#  6h 23m 04s CLIQUES (O sentence LCS M>60 S>65): Composed   624 cliques out of  31000 chunks
#  6h 23m 10s CLIQUES (O sentence LCS M>60 S>65): Composed   597 cliques out of  32000 chunks
#  6h 23m 14s CLIQUES (O sentence LCS M>60 S>65): Composed   585 cliques out of  33000 chunks
#  6h 23m 19s CLIQUES (O sentence LCS M>60 S>65): Composed   580 cliques out of  34000 chunks
#  6h 23m 23s CLIQUES (O sentence LCS M>60 S>65): Composed   571 cliques out of  35000 chunks
#  6h 23m 28s CLIQUES (O sentence LCS M>60 S>65): Composed   563 cliques out of  36000 chunks
#  6h 23m 34s CLIQUES (O sentence LCS M>60 S>65): Composed   553 cliques out of  37000 chunks
#  6h 23m 39s CLIQUES (O sentence LCS M>60 S>65): Composed   539 cliques out of  38000 chunks
#  6h 23m 45s CLIQUES (O sentence LCS M>60 S>65): Composed   528 cliques out of  39000 chunks
#  6h 23m 52s CLIQUES (O sentence LCS M>60 S>65): Composed   511 cliques out of  40000 chunks
#  6h 23m 58s CLIQUES (O sentence LCS M>60 S>65): Composed   496 cliques out of  41000 chunks
#  6h 24m 03s CLIQUES (O sentence LCS M>60 S>65): Composed   497 cliques out of  42000 chunks
#  6h 24m 08s CLIQUES (O sentence LCS M>60 S>65): Composed   496 cliques out of  43000 chunks
#  6h 24m 13s CLIQUES (O sentence LCS M>60 S>65): Composed   492 cliques out of  44000 chunks
#  6h 24m 18s CLIQUES (O sentence LCS M>60 S>65): Composed   488 cliques out of  45000 chunks
#  6h 24m 24s CLIQUES (O sentence LCS M>60 S>65): Composed   481 cliques out of  46000 chunks
#  6h 24m 30s CLIQUES (O sentence LCS M>60 S>65): Composed   476 cliques out of  47000 chunks
#  6h 24m 35s CLIQUES (O sentence LCS M>60 S>65): Composed   469 cliques out of  48000 chunks
#  6h 24m 42s CLIQUES (O sentence LCS M>60 S>65): Composed   464 cliques out of  49000 chunks
#  6h 24m 47s CLIQUES (O sentence LCS M>60 S>65): Composed   463 cliques out of  50000 chunks
#  6h 24m 53s CLIQUES (O sentence LCS M>60 S>65): Composed   463 cliques out of  51000 chunks
#  6h 24m 58s CLIQUES (O sentence LCS M>60 S>65): Composed   463 cliques out of  52000 chunks
#  6h 25m 03s CLIQUES (O sentence LCS M>60 S>65): Composed   464 cliques out of  53000 chunks
#  6h 25m 09s CLIQUES (O sentence LCS M>60 S>65): Composed   463 cliques out of  54000 chunks
#  6h 25m 15s CLIQUES (O sentence LCS M>60 S>65): Composed   463 cliques out of  55000 chunks
#  6h 25m 21s CLIQUES (O sentence LCS M>60 S>65): Composed   462 cliques out of  56000 chunks
#  6h 25m 27s CLIQUES (O sentence LCS M>60 S>65): Composed   461 cliques out of  57000 chunks
#  6h 25m 33s CLIQUES (O sentence LCS M>60 S>65): Composed   460 cliques out of  58000 chunks
#  6h 25m 39s CLIQUES (O sentence LCS M>60 S>65): 58863 members in 460 cliques
#  6h 25m 39s CLIQUES (O sentence LCS M>60 S>65): Composed and saved   460 cliques out of  58863 chunks from 4831555 comparisons
#  6h 25m 39s PRINT (O sentence LCS M>60 S>65): sorting out cliques
#  6h 25m 39s PRINT (O sentence LCS M>60 S>65): formatting 460 cliques skipping 207 binary chapter diffs
#  6h 25m 40s PRINT (O sentence LCS M>60 S>65): formatted 460 cliques (10 files) skipping 207 binary chapter diffs
#  6h 25m 40s CHUNKING (O sentence): already chunked into 63586 chunks
#  6h 25m 40s PREPARING (O sentence LCS): Already prepared
#  6h 25m 40s SIMILARITY (O sentence LCS M>60): Using  2021 M (2021557905) comparisons with 10271722 entries in matrix
#  6h 25m 50s SIMILARITY (O sentence LCS M>60): similarities between 60.0 and 100.0. 903811 are 100%
#  6h 25m 50s CLIQUES (O sentence LCS M>60 S>60): fetching similars and chunk candidates
#  6h 25m 50s CLIQUES (O sentence LCS M>60 S>60): inspecting the similarity matrix
#  6h 26m 07s CLIQUES (O sentence LCS M>60 S>60): 10271722 relevant similarities between 62379 passages
#  6h 26m 07s CLIQUES (O sentence LCS M>60 S>60): Composing cliques out of  62379 chunks from 10271722 comparisons
#  6h 26m 08s CLIQUES (O sentence LCS M>60 S>60): Composed   316 cliques out of   1000 chunks
#  6h 26m 08s CLIQUES (O sentence LCS M>60 S>60): Composed   370 cliques out of   2000 chunks
#  6h 26m 09s CLIQUES (O sentence LCS M>60 S>60): Composed   396 cliques out of   3000 chunks
#  6h 26m 10s CLIQUES (O sentence LCS M>60 S>60): Composed   374 cliques out of   4000 chunks
#  6h 26m 11s CLIQUES (O sentence LCS M>60 S>60): Composed   368 cliques out of   5000 chunks
#  6h 26m 12s CLIQUES (O sentence LCS M>60 S>60): Composed   343 cliques out of   6000 chunks
#  6h 26m 14s CLIQUES (O sentence LCS M>60 S>60): Composed   302 cliques out of   7000 chunks
#  6h 26m 15s CLIQUES (O sentence LCS M>60 S>60): Composed   292 cliques out of   8000 chunks
#  6h 26m 16s CLIQUES (O sentence LCS M>60 S>60): Composed   267 cliques out of   9000 chunks
#  6h 26m 18s CLIQUES (O sentence LCS M>60 S>60): Composed   240 cliques out of  10000 chunks
#  6h 26m 19s CLIQUES (O sentence LCS M>60 S>60): Composed   238 cliques out of  11000 chunks
#  6h 26m 21s CLIQUES (O sentence LCS M>60 S>60): Composed   215 cliques out of  12000 chunks
#  6h 26m 22s CLIQUES (O sentence LCS M>60 S>60): Composed   208 cliques out of  13000 chunks
#  6h 26m 24s CLIQUES (O sentence LCS M>60 S>60): Composed   204 cliques out of  14000 chunks
#  6h 26m 25s CLIQUES (O sentence LCS M>60 S>60): Composed   185 cliques out of  15000 chunks
#  6h 26m 27s CLIQUES (O sentence LCS M>60 S>60): Composed   170 cliques out of  16000 chunks
#  6h 26m 28s CLIQUES (O sentence LCS M>60 S>60): Composed   163 cliques out of  17000 chunks
#  6h 26m 30s CLIQUES (O sentence LCS M>60 S>60): Composed   157 cliques out of  18000 chunks
#  6h 26m 31s CLIQUES (O sentence LCS M>60 S>60): Composed   154 cliques out of  19000 chunks
#  6h 26m 33s CLIQUES (O sentence LCS M>60 S>60): Composed   145 cliques out of  20000 chunks
#  6h 26m 35s CLIQUES (O sentence LCS M>60 S>60): Composed   135 cliques out of  21000 chunks
#  6h 26m 36s CLIQUES (O sentence LCS M>60 S>60): Composed   127 cliques out of  22000 chunks
#  6h 26m 38s CLIQUES (O sentence LCS M>60 S>60): Composed   128 cliques out of  23000 chunks
#  6h 26m 40s CLIQUES (O sentence LCS M>60 S>60): Composed   126 cliques out of  24000 chunks
#  6h 26m 43s CLIQUES (O sentence LCS M>60 S>60): Composed   120 cliques out of  25000 chunks
#  6h 26m 45s CLIQUES (O sentence LCS M>60 S>60): Composed   118 cliques out of  26000 chunks
#  6h 26m 47s CLIQUES (O sentence LCS M>60 S>60): Composed   114 cliques out of  27000 chunks
#  6h 26m 50s CLIQUES (O sentence LCS M>60 S>60): Composed   113 cliques out of  28000 chunks
#  6h 26m 52s CLIQUES (O sentence LCS M>60 S>60): Composed   113 cliques out of  29000 chunks
#  6h 26m 55s CLIQUES (O sentence LCS M>60 S>60): Composed   112 cliques out of  30000 chunks
#  6h 26m 57s CLIQUES (O sentence LCS M>60 S>60): Composed   111 cliques out of  31000 chunks
#  6h 27m 00s CLIQUES (O sentence LCS M>60 S>60): Composed   110 cliques out of  32000 chunks
#  6h 27m 03s CLIQUES (O sentence LCS M>60 S>60): Composed   110 cliques out of  33000 chunks
#  6h 27m 06s CLIQUES (O sentence LCS M>60 S>60): Composed   111 cliques out of  34000 chunks
#  6h 27m 09s CLIQUES (O sentence LCS M>60 S>60): Composed   111 cliques out of  35000 chunks
#  6h 27m 12s CLIQUES (O sentence LCS M>60 S>60): Composed   111 cliques out of  36000 chunks
#  6h 27m 15s CLIQUES (O sentence LCS M>60 S>60): Composed   111 cliques out of  37000 chunks
#  6h 27m 18s CLIQUES (O sentence LCS M>60 S>60): Composed   110 cliques out of  38000 chunks
#  6h 27m 22s CLIQUES (O sentence LCS M>60 S>60): Composed   110 cliques out of  39000 chunks
#  6h 27m 25s CLIQUES (O sentence LCS M>60 S>60): Composed   110 cliques out of  40000 chunks
#  6h 27m 29s CLIQUES (O sentence LCS M>60 S>60): Composed   110 cliques out of  41000 chunks
#  6h 27m 32s CLIQUES (O sentence LCS M>60 S>60): Composed   108 cliques out of  42000 chunks
#  6h 27m 36s CLIQUES (O sentence LCS M>60 S>60): Composed   107 cliques out of  43000 chunks
#  6h 27m 40s CLIQUES (O sentence LCS M>60 S>60): Composed   105 cliques out of  44000 chunks
#  6h 27m 44s CLIQUES (O sentence LCS M>60 S>60): Composed   105 cliques out of  45000 chunks
#  6h 27m 48s CLIQUES (O sentence LCS M>60 S>60): Composed   105 cliques out of  46000 chunks
#  6h 27m 51s CLIQUES (O sentence LCS M>60 S>60): Composed   105 cliques out of  47000 chunks
#  6h 27m 55s CLIQUES (O sentence LCS M>60 S>60): Composed   105 cliques out of  48000 chunks
#  6h 28m 00s CLIQUES (O sentence LCS M>60 S>60): Composed   105 cliques out of  49000 chunks
#  6h 28m 04s CLIQUES (O sentence LCS M>60 S>60): Composed   106 cliques out of  50000 chunks
#  6h 28m 08s CLIQUES (O sentence LCS M>60 S>60): Composed   106 cliques out of  51000 chunks
#  6h 28m 13s CLIQUES (O sentence LCS M>60 S>60): Composed   106 cliques out of  52000 chunks
#  6h 28m 17s CLIQUES (O sentence LCS M>60 S>60): Composed   106 cliques out of  53000 chunks
#  6h 28m 22s CLIQUES (O sentence LCS M>60 S>60): Composed   106 cliques out of  54000 chunks
#  6h 28m 26s CLIQUES (O sentence LCS M>60 S>60): Composed   106 cliques out of  55000 chunks
#  6h 28m 31s CLIQUES (O sentence LCS M>60 S>60): Composed   107 cliques out of  56000 chunks
#  6h 28m 36s CLIQUES (O sentence LCS M>60 S>60): Composed   106 cliques out of  57000 chunks
#  6h 28m 41s CLIQUES (O sentence LCS M>60 S>60): Composed   106 cliques out of  58000 chunks
#  6h 28m 46s CLIQUES (O sentence LCS M>60 S>60): Composed   106 cliques out of  59000 chunks
#  6h 28m 51s CLIQUES (O sentence LCS M>60 S>60): Composed   106 cliques out of  60000 chunks
#  6h 28m 56s CLIQUES (O sentence LCS M>60 S>60): Composed   105 cliques out of  61000 chunks
#  6h 29m 02s CLIQUES (O sentence LCS M>60 S>60): Composed   105 cliques out of  62000 chunks
#  6h 29m 04s CLIQUES (O sentence LCS M>60 S>60): 62379 members in 105 cliques
#  6h 29m 04s CLIQUES (O sentence LCS M>60 S>60): Composed and saved   105 cliques out of  62379 chunks from 10271722 comparisons
#  6h 29m 04s PRINT (O sentence LCS M>60 S>60): sorting out cliques
#  6h 29m 05s PRINT (O sentence LCS M>60 S>60): formatting 105 cliques skipping 55 binary chapter diffs
#  6h 29m 05s PRINT (O sentence LCS M>60 S>60): formatted 105 cliques (3 files) skipping 55 binary chapter diffs
#  6h 29m 05s EXPERIMENT: Generating html report
#  6h 29m 05s EXPERIMENT:  21 messy results: deprecated
#  6h 29m 05s EXPERIMENT:  17 mixed quality: take care
#  6h 29m 05s EXPERIMENT:   7 unassessed quality: inspection needed
#  6h 29m 05s EXPERIMENT:  72 method deprecated
#  6h 29m 05s EXPERIMENT:   9 promising results: recommended
#  6h 29m 05s EXPERIMENT: Generated html report
#  6h 29m 05s EXPERIMENT: Generating html report(standalone)
#  6h 29m 05s EXPERIMENT:  21 messy results: deprecated
#  6h 29m 05s EXPERIMENT:  17 mixed quality: take care
#  6h 29m 05s EXPERIMENT:   7 unassessed quality: inspection needed
#  6h 29m 05s EXPERIMENT:  72 method deprecated
#  6h 29m 05s EXPERIMENT:   9 promising results: recommended
#  6h 29m 05s EXPERIMENT: Generated html report
#  6h 29m 05s CHUNKING (O verse)
#  6h 29m 06s CHUNKING (O verse): Made 23213 chunks
#  6h 29m 06s PREPARING (O verse SET)
#  6h 29m 07s PREPARING (O verse SET): Done 23213 chunks.
#  6h 29m 08s SIMILARITY (O verse SET M>50): Loaded:   269 M (269410078) comparisons with 24832 entries in matrix
#  6h 29m 08s SIMILARITY (O verse SET M>50): similarities between 50.0 and 100.0. 4506 are 100%
#  6h 29m 08s CLIQUES (O verse SET M>50 S>65): fetching similars and chunk candidates
#  6h 29m 08s CLIQUES (O verse SET M>50 S>65): inspecting the similarity matrix
#  6h 29m 11s CLIQUES (O verse SET M>50 S>65): 14353 relevant similarities between 3139 passages
#  6h 29m 11s CLIQUES (O verse SET M>50 S>65): Loaded:  1235 cliques out of   3139 chunks from 14353 comparisons
#  6h 29m 11s CLIQUES (O verse SET M>50 S>65): 3139 members in 1235 cliques
#  6h 29m 11s PRINT (O verse SET M>50 S>65): sorting out cliques
#  6h 29m 11s PRINT (O verse SET M>50 S>65): formatting 1235 cliques involving 284 binary chapter diffs
#  6h 29m 11s PRINT (O verse SET M>50 S>65): Chapter diffs needed: 284
#  6h 29m 11s PRINT (O verse SET M>50 S>65): Chapter diffs: 0 newly created and 284 already existing
#  6h 29m 13s PRINT (O verse SET M>50 S>65): formatted 1235 cliques (25 files) involving 284 binary chapter diffs
#  6h 29m 13s EXPERIMENT: Generating html report
#  6h 29m 13s EXPERIMENT:  21 messy results: deprecated
#  6h 29m 13s EXPERIMENT:  17 mixed quality: take care
#  6h 29m 13s EXPERIMENT:   7 unassessed quality: inspection needed
#  6h 29m 13s EXPERIMENT:  72 method deprecated
#  6h 29m 13s EXPERIMENT:   9 promising results: recommended
#  6h 29m 13s EXPERIMENT: Generated html report
#  6h 29m 13s CROSSREFS: Fetching crossrefs
#  6h 29m 13s CROSSREFS (O verse SET S>65)
#  6h 29m 13s CROSSREFS (O verse SET S>65): found 14353 pairs
#  6h 29m 13s CROSSREFS: Found 28706 crossreferences and wrote 14353 pairs
#  6h 29m 13s CROSSREFS: Compiled cross references into 5493 notes
#  6h 29m 13s CROSSREFS: Added 568 chapter diffs
#  6h 29m 13s CROSSREFS: Added 3139 clique references
#  6h 29m 14s CROSSREFS: Generated 9201 notes
#  6h 29m 14s EXPERIMENT: Generating html report
#  6h 29m 14s EXPERIMENT:  21 messy results: deprecated
#  6h 29m 14s EXPERIMENT:  17 mixed quality: take care
#  6h 29m 14s EXPERIMENT:   7 unassessed quality: inspection needed
#  6h 29m 14s EXPERIMENT:  72 method deprecated
#  6h 29m 14s EXPERIMENT:   9 promising results: recommended
#  6h 29m 14s EXPERIMENT: Generated html report
#  6h 29m 14s EXPERIMENT: Generating html report(standalone)
#  6h 29m 14s EXPERIMENT:  21 messy results: deprecated
#  6h 29m 14s EXPERIMENT:  17 mixed quality: take care
#  6h 29m 14s EXPERIMENT:   7 unassessed quality: inspection needed
#  6h 29m 14s EXPERIMENT:  72 method deprecated
#  6h 29m 14s EXPERIMENT:   9 promising results: recommended
#  6h 29m 14s EXPERIMENT: Generated html report

# %%
HTML(ecss)
# Out:
# <style type="text/css">
# .mis {background-color: #cccccc;}
# .rec {background-color: #aaffaa;}
# .dep {background-color: #ffaaaa;}
# .dub {background-color: #ffddaa;}
# .out {background-color: #ffddff;}
# .nor {background-color: #fcfcff;}
# .ps  {font-weight: normal;}
# .mx  {font-style: italic;}
# .cl  {font-weight: bold;}
# .lr  {font-weight: bold; background-color: #ffffaa;}
# p,td {font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; font-size: small;}
# td   {border: 1pt solid #000000; padding: 4pt;}
# table {border: 1pt solid #000000; border-collapse: collapse;}
# </style>

# %% [markdown]
# # Extra
#
# This is sample code for plotting characteristics of the similarity matrix.
# It does not have a role in the experiments or the assessments of the results.
#
# # Overview of the similarities
#
# Here is a plot of the similarity matrix.
# Horizontally you see the degree of similarity from 0 to 100%, vertically the number of pairs that have that (rounded) similarity. This axis is logarithmic.

# %%
# run this cell after the cells below
distances = collections.Counter()
for (x, d) in chunk_dist.items():
    distances[int(round(d))] += 1

x = range(MATRIX_THRESHOLD, 101)
fig = plt.figure(figsize=[15, 4])
plt.plot(x, [math.log(max((1, distances[y]))) for y in x], 'b-')
plt.axis([MATRIX_THRESHOLD, 101, 0, 15])
plt.xlabel('similarity as %')
plt.ylabel('log # similarities')
plt.xticks(x, x, rotation='vertical')
plt.margins(0.2)
plt.subplots_adjust(bottom=0.15);
plt.title('distances');
